# %%
from sklearn.model_selection import train_test_split
import tensorflow as tf

import numpy as np
from keras.datasets import cifar10
from random import randrange
import time
import pickle

import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline
plt.rcParams['figure.figsize'] = (15, 12) # set default size of plots
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ### Load data

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

y_train = np.squeeze(y_train)
y_test = np.squeeze(y_test)

# %%
# print (x_train.shape)
# print (y_train.shape)

# all_aug_x = pickle.load(open('aug_image/x_images.p','rb'))
# all_aug_y = pickle.load(open('aug_image/y_images.p','rb'))


# x_train = np.concatenate([x_train,all_aug_x])
# y_train = np.concatenate([y_train,all_aug_y])

# print (x_train.shape)
# print (y_train.shape)

# %% [markdown]
# Визуализируем классы

# %%
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
num_classes = len(classes)
samples_per_class = 10
for y, cls in enumerate(classes):
    idxs = np.flatnonzero(y_train == y)
    idxs = np.random.choice(idxs, samples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt_idx = i * num_classes + y + 1
        plt.subplot(samples_per_class, num_classes, plt_idx)
        plt.imshow(x_train[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls)
plt.show()

# %%
# Preprocessing: вычитаем среднее
# 1: Находим среднее изображение
mean_image = np.mean(x_train, axis=0)
plt.figure(figsize=(4,4))
plt.imshow(mean_image.reshape((32,32,3)).astype('uint8')) # визуализируем полученное среднее
plt.show()

# %%
# 2: вычитаем среднее из изображений обучающей и тестовых выборок
x_train = x_train/127.5
x_test = x_test/127.5

mean_image = np.mean(x_train, axis=0)

x_train = x_train - mean_image
x_test = x_test - mean_image

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=1000,stratify=y_train)

# %% [markdown]
# Пожалуйста, ознакомьтесь с другими возможностями, которые предоставляет tf для описания модели.
#
# * Layers, Activations, Loss functions : https://www.tensorflow.org/api_guides/python/nn
# * Optimizers: https://www.tensorflow.org/api_guides/python/train#Optimizers
# * BatchNorm: https://www.tensorflow.org/api_docs/python/tf/layers/BatchNormalization

# %% [markdown]
# Теперь мы можем двигаться дальше и протестировать получившуюся модель. Для этого реализуем тренировочный цикл

# %% [markdown]
# Принимаются работы с точностью **не менее 84%**.
#
# Полезные ссылки:
#   - [ResNet](https://arxiv.org/abs/1512.03385).
#   - [DenseNet](https://arxiv.org/abs/1608.06993).
#   - [This blog has an in-depth overview](https://chatbotslife.com/resnets-highwaynets-and-densenets-oh-my-9bb15918ee32)

# %% [markdown]
# Напишите ваш код под текстом задания

# %% [markdown]
# ### My network

# %%
### For data augmentation
from keras.preprocessing.image import ImageDataGenerator

# %%
def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w
            r = np.random.uniform(r_1, r_2)
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img

    return eraser

# %%
import math

## https://gist.github.com/vertix/d2b1256003e9ffca8e7fc36ba1ba4eb3


def augment(images, labels,
            resize=None, # (width, height) tuple or None
            horizontal_flip=False,
            vertical_flip=False,
            rotate=0, # Maximum rotation angle in degrees
            crop_probability=0, # How often we do crops
            crop_min_percent=0.6, # Minimum linear dimension of a crop
            crop_max_percent=1.,  # Maximum linear dimension of a crop
            mixup=0):  # Mixup coeffecient, see https://arxiv.org/abs/1710.09412.pdf
  if resize is not None:
    images = tf.image.resize_bilinear(images, resize)
  
  # My experiments showed that casting on GPU improves training performance
  if images.dtype != tf.float32:
    images = tf.image.convert_image_dtype(images, dtype=tf.float32)
    images = tf.subtract(images, 0.5)
    images = tf.multiply(images, 2.0)
  labels = tf.to_float(labels)

  with tf.name_scope('augmentation'):
    shp = tf.shape(images)
    batch_size, height, width = shp[0], shp[1], shp[2]
    width = tf.cast(width, tf.float32)
    height = tf.cast(height, tf.float32)

    # The list of affine transformations that our image will go under.
    # Every element is Nx8 tensor, where N is a batch size.
    transforms = []
    identity = tf.constant([1, 0, 0, 0, 1, 0, 0, 0], dtype=tf.float32)
    if horizontal_flip:
      coin = tf.less(tf.random_uniform([batch_size], 0, 1.0), 0.5)
      flip_transform = tf.convert_to_tensor(
          [-1., 0., width, 0., 1., 0., 0., 0.], dtype=tf.float32)
      transforms.append(
          tf.where(coin,
                   tf.tile(tf.expand_dims(flip_transform, 0), [batch_size, 1]),
                   tf.tile(tf.expand_dims(identity, 0), [batch_size, 1])))

    if vertical_flip:
      coin = tf.less(tf.random_uniform([batch_size], 0, 1.0), 0.5)
      flip_transform = tf.convert_to_tensor(
          [1, 0, 0, 0, -1, height, 0, 0], dtype=tf.float32)
      transforms.append(
          tf.where(coin,
                   tf.tile(tf.expand_dims(flip_transform, 0), [batch_size, 1]),
                   tf.tile(tf.expand_dims(identity, 0), [batch_size, 1])))

    if rotate > 0:
      angle_rad = rotate / 180 * math.pi
      angles = tf.random_uniform([batch_size], -angle_rad, angle_rad)
      transforms.append(
          tf.contrib.image.angles_to_projective_transforms(
              angles, height, width))

    if crop_probability > 0:
      crop_pct = tf.random_uniform([batch_size], crop_min_percent,
                                   crop_max_percent)
      left = tf.random_uniform([batch_size], 0, width * (1 - crop_pct))
      top = tf.random_uniform([batch_size], 0, height * (1 - crop_pct))
      crop_transform = tf.stack([
          crop_pct,
          tf.zeros([batch_size]), top,
          tf.zeros([batch_size]), crop_pct, left,
          tf.zeros([batch_size]),
          tf.zeros([batch_size])
      ], 1)

      coin = tf.less(
          tf.random_uniform([batch_size], 0, 1.0), crop_probability)
      transforms.append(
          tf.where(coin, crop_transform,
                   tf.tile(tf.expand_dims(identity, 0), [batch_size, 1])))

    if transforms:
      images = tf.contrib.image.transform(
          images,
          tf.contrib.image.compose_transforms(*transforms),
          interpolation='BILINEAR') # or 'NEAREST'

    def cshift(values): # Circular shift in batch dimension
      return tf.concat([values[-1:, ...], values[:-1, ...]], 0)

    if mixup > 0:
      mixup = 1.0 * mixup # Convert to float, as tf.distributions.Beta requires floats.
      beta = tf.distributions.Beta(mixup, mixup)
      lam = beta.sample(batch_size)
      ll = tf.expand_dims(tf.expand_dims(tf.expand_dims(lam, -1), -1), -1)
      images = ll * images + (1 - ll) * cshift(images)
      labels = lam * labels + (1 - lam) * cshift(labels)

  return images, labels

# %%
## https://gist.github.com/xmfbit/67c407e34cbaf56e7820f09e774e56d8
## Resnet 164

def my_resnet_single(single_name, x, is_training, in_filters, out_filters, keep_prob, stride = 1  ):

    USE_L2_REG = 'L2_REG'
    expansion = 4
    
    bottleneck_planes = out_filters / expansion
    
    with tf.variable_scope(single_name):
        
        
        # conv 1x1
        with tf.variable_scope(single_name+"_bn1"):
            x_res = tf.layers.batch_normalization(x, training=is_training)  
        x_res = tf.nn.relu(x_res)

        Wconv1 = tf.get_variable("Wconv1", shape=[1, 1, in_filters, bottleneck_planes])
        bconv1 = tf.get_variable("bconv1", shape=[bottleneck_planes])
        x_res = tf.nn.conv2d(x_res, Wconv1, strides=[1,stride,stride,1], padding='SAME') + bconv1

#         x_res = tf.nn.dropout(x_res, keep_prob=keep_prob)
        
        # conv 3x3
        with tf.variable_scope(single_name+"_bn2"):
            x_res = tf.layers.batch_normalization(x_res, training=is_training)  
            
        x_res = tf.nn.relu(x_res)
                
        Wconv2 = tf.get_variable("Wconv2", shape=[3, 3, bottleneck_planes, bottleneck_planes])
        bconv2 = tf.get_variable("bconv2", shape=[bottleneck_planes])
        x_res = tf.nn.conv2d(x_res, Wconv2, strides=[1,1,1,1], padding='SAME') + bconv2
        
        
        # conv 1x1
        with tf.variable_scope(single_name+"_bn3"):
            x_res = tf.layers.batch_normalization(x_res, training=is_training)  
            
        x_res = tf.nn.relu(x_res)
                
        Wconv3 = tf.get_variable("Wconv3", shape=[1, 1, bottleneck_planes, out_filters])
        bconv3 = tf.get_variable("bconv3", shape=[out_filters])
        x_res = tf.nn.conv2d(x_res, Wconv3, strides=[1,1,1,1], padding='SAME') + bconv3
        
        
        tf.add_to_collection(USE_L2_REG, Wconv1)
        tf.add_to_collection(USE_L2_REG, bconv1)
        
        tf.add_to_collection(USE_L2_REG, Wconv2)
        tf.add_to_collection(USE_L2_REG, bconv2)
        
        tf.add_to_collection(USE_L2_REG, Wconv3)
        tf.add_to_collection(USE_L2_REG, bconv3)        

    ## shortcut
    with tf.variable_scope(single_name+"_sc"): 
        
        x_sc = x
        
        ## shortcut
        if in_filters != out_filters or stride!=1:

            Wconv = tf.get_variable("Wconv", shape=[1, 1, in_filters, out_filters])
            bconv = tf.get_variable("bconv", shape=[out_filters])
            
            x_sc = tf.nn.conv2d(x_sc, Wconv, strides=[1,stride,stride,1], padding='SAME') + bconv
            
            tf.add_to_collection(USE_L2_REG, Wconv)
            tf.add_to_collection(USE_L2_REG, bconv)

            
    out = x_sc + x_res
    
    return out
    
def my_resnet_group(block_name, x, is_training, nstage, in_filters, out_filters, keep_prob, stride = 1):
    
    x_out = x

    x_out = my_resnet_single(block_name+"_"+str(0), x_out, is_training, in_filters, out_filters, keep_prob, stride = stride  )

    for i in range(1, nstage):
        x_out = my_resnet_single(block_name+"_"+str(i), x_out, is_training, out_filters, out_filters, 
                                 keep_prob, stride = 1 )

    return x_out
            


def my_resnet164(depth = 164, keep_prob = 0.7):

    n = int((depth - 2) / 9)
    nstages = [16, 64, 128, 256]
    
    x = tf.placeholder(tf.float32, [None, 32, 32, 3])
    y = tf.placeholder(tf.int64, [None])
    
    x, _ = augment(x, y,
            resize=None, # (width, height) tuple or None
            horizontal_flip=True,
            vertical_flip=True,
            rotate=15, # Maximum rotation angle in degrees
            crop_probability=0.1, # How often we do crops
            crop_min_percent=0.0, # Minimum linear dimension of a crop
            crop_max_percent=0.3,  # Maximum linear dimension of a crop
            mixup=0)
    
    is_training = tf.placeholder(tf.bool)
    l2_reg = tf.placeholder(tf.float32)

    USE_L2_REG = 'L2_REG' 
    
    ## ---  WideResNet 
    ##
    

    x_res = x
    
    with tf.variable_scope("res_start"):
        
        Wconv = tf.get_variable("Wconv", shape=[3, 3, 3, nstages[0]])
        bconv = tf.get_variable("bconv", shape=[nstages[0]])
        x_res = tf.nn.conv2d(x_res, Wconv, strides=[1,1,1,1], padding='SAME') + bconv
        
        tf.add_to_collection(USE_L2_REG, Wconv)
        tf.add_to_collection(USE_L2_REG, bconv)   
        

    x_res = my_resnet_group("res_block0", x_res, is_training, n, nstages[0], nstages[1], keep_prob, stride = 1)
    x_res = my_resnet_group("res_block1", x_res, is_training, n, nstages[1], nstages[2], keep_prob, stride = 2)
    x_res = my_resnet_group("res_block2", x_res, is_training, n, nstages[2], nstages[3], keep_prob, stride = 2)
        
    with tf.variable_scope("global_bn1"):
        x_res = tf.layers.batch_normalization(x_res, training=is_training)  
            
    x_res = tf.nn.relu(x_res)
    x_res = tf.nn.avg_pool(x_res, ksize=[1,8,8,1],strides=[1,1,1,1],padding="VALID")
        
    #добавляем полносвязный слой
    with tf.variable_scope("dense_layer_1"):
        
        
        size = 1*1*nstages[-1]
        W1 = tf.get_variable("W1", shape=[size, 10])
        b1 = tf.get_variable("b1", shape=[10])
        
        x_res = tf.reshape(x_res,[-1,size])
        x_res = tf.matmul(x_res, W1) + b1  
        
        tf.add_to_collection(USE_L2_REG, W1)
        tf.add_to_collection(USE_L2_REG, b1)     
        
    y_out = x_res 
        
    ## l2 regularization
    L2_loss = tf.add_n([tf.nn.l2_loss(v) for v in tf.get_collection(USE_L2_REG)]) * l2_reg
        
    # y_out -- это вектор оценок, которые генерирует модель. Теперь определим функцию потерь
    total_loss = tf.losses.hinge_loss(tf.one_hot(y,10),logits=y_out)
    mean_loss = tf.reduce_mean(total_loss) + L2_loss
    
    correct_prediction = tf.equal(tf.argmax(y_out,1), y)
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    
    tf.summary.scalar('mean_loss', mean_loss)
    tf.summary.scalar('accuracy', accuracy)
            
    #Возвращаем те узлы графа, которые нам понадобятся в дальнейшем.
    #(x,y) это входы графа, а (y_out, mean_loss) выходы, которые представляют для нас интерес
    return (x,y,is_training,l2_reg), (y_out, mean_loss, accuracy)

# %%
def training_loop(session, model_inputs, model_outputs, train_step, 
                  epochs=10, batch_size=64):
    
    train_writer = tf.summary.FileWriter('tensorboard/train',session.graph)
    val_writer = tf.summary.FileWriter('tensorboard/val')

    #создаём индекс по всем объектам
    index = np.arange(len(x_train))
    
    #перемешиваем его
    np.random.shuffle(index)
    
    #разбиваем на батчи
    num_batches = int(len(index) / batch_size)
    batch_indexes = np.array_split(index, num_batches)
    
    #аналогично для теста
    index_test = np.arange(len(x_test))
    np.random.shuffle(index_test)
    num_batches_test = int(len(index_test) / batch_size)
    batch_indexes_test = np.array_split(index_test, num_batches_test)
    
    #аналогично для validation
    index_val = np.arange(len(x_val))
    np.random.shuffle(index_val)
    num_batches_val = int(len(index_val) / batch_size)
    batch_indexes_val = np.array_split(index_val, num_batches_val)
    
    x,y,is_training,l2_reg,learning_rate = model_inputs
    y_out, mean_loss, accuracy = model_outputs
    
    datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=15,  # randomly rotate images in the range (degrees, 0 to 180)
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=True,  # randomly flip images
        vertical_flip=True)  # randomly flip images
    
    eraser = get_random_eraser(p=0.3, v_l=0, v_h=1, s_l=0.02, s_h=0.4, pixel_level=True)
    
    def cosine_decay(learning_rate,global_step,decay_steps,alpha=0.0):
        global_step = min(global_step, decay_steps)
        cosine_decay = 0.5 * (1 + np.cos(np.pi * global_step / decay_steps))
        decayed = (1 - alpha) * cosine_decay + alpha
        decayed_learning_rate = learning_rate * decayed
        return decayed_learning_rate
    
    def train(x_values, y_values, batch_indexes, epoch):
        train_loses = []
        for i, batch_index in enumerate(batch_indexes):
            
#             lr = 0.0001/10**(epoch)
#             lr = cosine_decay(0.01,global_step = epoch % 50,decay_steps = 50, alpha = 0.001)

            if epoch<50:
                lr = cosine_decay(0.001,global_step = epoch % 50,decay_steps = 25, alpha = 0.01)
            else:
                lr = cosine_decay(0.0001,global_step = epoch % 50,decay_steps = 25, alpha = 0.01)

            #Создаём словарь, осуществляющий сопоставление входов графа (plaseholders) и значений
#             x_batch = [datagen.random_transform(img) for img in x_values[batch_index]]
                
            x_batch = [eraser(img) for img in x_values[batch_index]]
        
            feed_dict = {x: x_batch,
                         y: y_values[batch_index],
                        is_training:True,
                        l2_reg: 0,
                        learning_rate:lr}

            #Здесь происходит непоследственный вызов модели
            #Обратите внимание, что мы передаём 
                      
            summary, scores, loss, acc, _ = session.run([merged,y_out, mean_loss, accuracy, train_step],feed_dict=feed_dict)

            train_loses.append(loss)
            print(f'iteration {i}, train loss: {loss:.3}, accuracy: {acc:.3}', end='\r')
            
            train_writer.add_summary(summary, epoch * num_batches+i)

        return train_loses
        
    def evaluate(x_values, y_values, batch_indexes, epoch):
        test_loses = []
        test_accuracy = []

        for batch_index in batch_indexes:

            #Создаём словарь, осуществляющий сопоставление входов графа (plaseholders) и значений
            feed_dict = {x: x_values[batch_index],
                         y: y_values[batch_index],
                        is_training:False,
                        l2_reg : 0}
            
            #Здесь происходит непоследственный вызов модели
            
            summary, loss, acc = session.run([merged,mean_loss, accuracy],feed_dict=feed_dict)
                             
                
            test_loses.append(loss)
            test_accuracy.append(acc)

            # Create a new Summary object with your measure
            
        summary = tf.Summary()
        summary.value.add(tag="val_Accuracy", simple_value=np.mean(test_accuracy))
        summary.value.add(tag="val_Loses", simple_value=np.mean(test_loses))
        
        val_writer.add_summary(summary, epoch)

        return test_loses, test_accuracy
    
        
    # цикл по эпохам
    for e in range(epochs):
        print(f'Epoch {e}:')
        train_loses = train(x_train, y_train, batch_indexes, e)
        val_loses, val_accuracy = evaluate(x_val, y_val, batch_indexes_val, e)
        lr = cosine_decay(0.0001,global_step = e % 50,decay_steps = 50, alpha = 0.001)
        print(f'train loss: {np.mean(train_loses):.3}, val loss: {np.mean(val_loses):.3}, accuracy: {np.mean(val_accuracy):.3}, lr: {lr:.10}')
        
        save_path = saver.save(session, "checkpoints/model_resnet164.ckpt")
        
        if e % 50 == 49:
            try:
                save_path = saver.save(session, "checkpoints/model_resnet164_ep"+str(e)+".ckpt")
            except:
                pass
            
    print('================================================')
    print('Test set results:')
    test_loses, test_accuracy = evaluate(x_test, y_test, batch_indexes_test,e)
    print(f'test loss: {np.mean(test_loses):.3}, accuracy: {np.mean(test_accuracy):.3}')

# %%
#Перед вызовом функции очистим память от графов других моделей (актуально если вы вызываете эту ячейку повторно)
tf.reset_default_graph()
(x,y,is_training,l2_reg), (y_out, mean_loss, accuracy) = my_resnet164(depth=164,keep_prob=0.7)

merged = tf.summary.merge_all()
saver = tf.train.Saver()


#Теперь зададим алгоритм оптимизации
learning_rate = tf.placeholder(tf.float32, shape=[])
optimizer = tf.train.AdamOptimizer(learning_rate) 
#train_step -- специальный служебный узел в графе, отвечающий за обратный проход


update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
with tf.control_dependencies(update_ops):
    
    gvs = optimizer.compute_gradients(mean_loss)
    capped_gvs = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gvs]
    train_step = optimizer.apply_gradients(capped_gvs)

#     train_step = optimizer.minimize(mean_loss)

# %%
import tensorflow.contrib.slim as slim
def model_summary():
    model_vars = tf.trainable_variables()
    slim.model_analyzer.analyze_vars(model_vars, print_info=True)

model_summary()
# Out:
# ---------
# Variables: name (type shape) [size]
# ---------
# res_start/Wconv:0 (float32_ref 3x3x3x16) [432, bytes: 1728]
# res_start/bconv:0 (float32_ref 16) [16, bytes: 64]
# res_block0_0/res_block0_0_bn1/batch_normalization/gamma:0 (float32_ref 16) [16, bytes: 64]
# res_block0_0/res_block0_0_bn1/batch_normalization/beta:0 (float32_ref 16) [16, bytes: 64]
# res_block0_0/Wconv1:0 (float32_ref 1x1x16x16) [256, bytes: 1024]
# res_block0_0/bconv1:0 (float32_ref 16) [16, bytes: 64]
# res_block0_0/res_block0_0_bn2/batch_normalization/gamma:0 (float32_ref 16) [16, bytes: 64]
# res_block0_0/res_block0_0_bn2/batch_normalization/beta:0 (float32_ref 16) [16, bytes: 64]
# res_block0_0/Wconv2:0 (float32_ref 3x3x16x16) [2304, bytes: 9216]
# res_block0_0/bconv2:0 (float32_ref 16) [16, bytes: 64]
# res_block0_0/res_block0_0_bn3/batch_normalization/gamma:0 (float32_ref 16) [16, bytes: 64]
# res_block0_0/res_block0_0_bn3/batch_normalization/beta:0 (float32_ref 16) [16, bytes: 64]
# res_block0_0/Wconv3:0 (float32_ref 1x1x16x64) [1024, bytes: 4096]
# res_block0_0/bconv3:0 (float32_ref 64) [64, bytes: 256]
# res_block0_0_sc/Wconv:0 (float32_ref 1x1x16x64) [1024, bytes: 4096]
# res_block0_0_sc/bconv:0 (float32_ref 64) [64, bytes: 256]
# res_block0_1/res_block0_1_bn1/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block0_1/res_block0_1_bn1/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block0_1/Wconv1:0 (float32_ref 1x1x64x16) [1024, bytes: 4096]
# res_block0_1/bconv1:0 (float32_ref 16) [16, bytes: 64]
# res_block0_1/res_block0_1_bn2/batch_normalization/gamma:0 (float32_ref 16) [16, bytes: 64]
# res_block0_1/res_block0_1_bn2/batch_normalization/beta:0 (float32_ref 16) [16, bytes: 64]
# res_block0_1/Wconv2:0 (float32_ref 3x3x16x16) [2304, bytes: 9216]
# res_block0_1/bconv2:0 (float32_ref 16) [16, bytes: 64]
# res_block0_1/res_block0_1_bn3/batch_normalization/gamma:0 (float32_ref 16) [16, bytes: 64]
# res_block0_1/res_block0_1_bn3/batch_normalization/beta:0 (float32_ref 16) [16, bytes: 64]
# res_block0_1/Wconv3:0 (float32_ref 1x1x16x64) [1024, bytes: 4096]
# res_block0_1/bconv3:0 (float32_ref 64) [64, bytes: 256]
# res_block0_2/res_block0_2_bn1/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block0_2/res_block0_2_bn1/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block0_2/Wconv1:0 (float32_ref 1x1x64x16) [1024, bytes: 4096]
# res_block0_2/bconv1:0 (float32_ref 16) [16, bytes: 64]
# res_block0_2/res_block0_2_bn2/batch_normalization/gamma:0 (float32_ref 16) [16, bytes: 64]
# res_block0_2/res_block0_2_bn2/batch_normalization/beta:0 (float32_ref 16) [16, bytes: 64]
# res_block0_2/Wconv2:0 (float32_ref 3x3x16x16) [2304, bytes: 9216]
# res_block0_2/bconv2:0 (float32_ref 16) [16, bytes: 64]
# res_block0_2/res_block0_2_bn3/batch_normalization/gamma:0 (float32_ref 16) [16, bytes: 64]
# res_block0_2/res_block0_2_bn3/batch_normalization/beta:0 (float32_ref 16) [16, bytes: 64]
# res_block0_2/Wconv3:0 (float32_ref 1x1x16x64) [1024, bytes: 4096]
# res_block0_2/bconv3:0 (float32_ref 64) [64, bytes: 256]
# res_block0_3/res_block0_3_bn1/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block0_3/res_block0_3_bn1/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block0_3/Wconv1:0 (float32_ref 1x1x64x16) [1024, bytes: 4096]
# res_block0_3/bconv1:0 (float32_ref 16) [16, bytes: 64]
# res_block0_3/res_block0_3_bn2/batch_normalization/gamma:0 (float32_ref 16) [16, bytes: 64]
# res_block0_3/res_block0_3_bn2/batch_normalization/beta:0 (float32_ref 16) [16, bytes: 64]
# res_block0_3/Wconv2:0 (float32_ref 3x3x16x16) [2304, bytes: 9216]
# res_block0_3/bconv2:0 (float32_ref 16) [16, bytes: 64]
# res_block0_3/res_block0_3_bn3/batch_normalization/gamma:0 (float32_ref 16) [16, bytes: 64]
# res_block0_3/res_block0_3_bn3/batch_normalization/beta:0 (float32_ref 16) [16, bytes: 64]
# res_block0_3/Wconv3:0 (float32_ref 1x1x16x64) [1024, bytes: 4096]
# res_block0_3/bconv3:0 (float32_ref 64) [64, bytes: 256]
# res_block0_4/res_block0_4_bn1/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block0_4/res_block0_4_bn1/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block0_4/Wconv1:0 (float32_ref 1x1x64x16) [1024, bytes: 4096]
# res_block0_4/bconv1:0 (float32_ref 16) [16, bytes: 64]
# res_block0_4/res_block0_4_bn2/batch_normalization/gamma:0 (float32_ref 16) [16, bytes: 64]
# res_block0_4/res_block0_4_bn2/batch_normalization/beta:0 (float32_ref 16) [16, bytes: 64]
# res_block0_4/Wconv2:0 (float32_ref 3x3x16x16) [2304, bytes: 9216]
# res_block0_4/bconv2:0 (float32_ref 16) [16, bytes: 64]
# res_block0_4/res_block0_4_bn3/batch_normalization/gamma:0 (float32_ref 16) [16, bytes: 64]
# res_block0_4/res_block0_4_bn3/batch_normalization/beta:0 (float32_ref 16) [16, bytes: 64]
# res_block0_4/Wconv3:0 (float32_ref 1x1x16x64) [1024, bytes: 4096]
# res_block0_4/bconv3:0 (float32_ref 64) [64, bytes: 256]
# res_block0_5/res_block0_5_bn1/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block0_5/res_block0_5_bn1/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block0_5/Wconv1:0 (float32_ref 1x1x64x16) [1024, bytes: 4096]
# res_block0_5/bconv1:0 (float32_ref 16) [16, bytes: 64]
# res_block0_5/res_block0_5_bn2/batch_normalization/gamma:0 (float32_ref 16) [16, bytes: 64]
# res_block0_5/res_block0_5_bn2/batch_normalization/beta:0 (float32_ref 16) [16, bytes: 64]
# res_block0_5/Wconv2:0 (float32_ref 3x3x16x16) [2304, bytes: 9216]
# res_block0_5/bconv2:0 (float32_ref 16) [16, bytes: 64]
# res_block0_5/res_block0_5_bn3/batch_normalization/gamma:0 (float32_ref 16) [16, bytes: 64]
# res_block0_5/res_block0_5_bn3/batch_normalization/beta:0 (float32_ref 16) [16, bytes: 64]
# res_block0_5/Wconv3:0 (float32_ref 1x1x16x64) [1024, bytes: 4096]
# res_block0_5/bconv3:0 (float32_ref 64) [64, bytes: 256]
# res_block0_6/res_block0_6_bn1/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block0_6/res_block0_6_bn1/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block0_6/Wconv1:0 (float32_ref 1x1x64x16) [1024, bytes: 4096]
# res_block0_6/bconv1:0 (float32_ref 16) [16, bytes: 64]
# res_block0_6/res_block0_6_bn2/batch_normalization/gamma:0 (float32_ref 16) [16, bytes: 64]
# res_block0_6/res_block0_6_bn2/batch_normalization/beta:0 (float32_ref 16) [16, bytes: 64]
# res_block0_6/Wconv2:0 (float32_ref 3x3x16x16) [2304, bytes: 9216]
# res_block0_6/bconv2:0 (float32_ref 16) [16, bytes: 64]
# res_block0_6/res_block0_6_bn3/batch_normalization/gamma:0 (float32_ref 16) [16, bytes: 64]
# res_block0_6/res_block0_6_bn3/batch_normalization/beta:0 (float32_ref 16) [16, bytes: 64]
# res_block0_6/Wconv3:0 (float32_ref 1x1x16x64) [1024, bytes: 4096]
# res_block0_6/bconv3:0 (float32_ref 64) [64, bytes: 256]
# res_block0_7/res_block0_7_bn1/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block0_7/res_block0_7_bn1/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block0_7/Wconv1:0 (float32_ref 1x1x64x16) [1024, bytes: 4096]
# res_block0_7/bconv1:0 (float32_ref 16) [16, bytes: 64]
# res_block0_7/res_block0_7_bn2/batch_normalization/gamma:0 (float32_ref 16) [16, bytes: 64]
# res_block0_7/res_block0_7_bn2/batch_normalization/beta:0 (float32_ref 16) [16, bytes: 64]
# res_block0_7/Wconv2:0 (float32_ref 3x3x16x16) [2304, bytes: 9216]
# res_block0_7/bconv2:0 (float32_ref 16) [16, bytes: 64]
# res_block0_7/res_block0_7_bn3/batch_normalization/gamma:0 (float32_ref 16) [16, bytes: 64]
# res_block0_7/res_block0_7_bn3/batch_normalization/beta:0 (float32_ref 16) [16, bytes: 64]
# res_block0_7/Wconv3:0 (float32_ref 1x1x16x64) [1024, bytes: 4096]
# res_block0_7/bconv3:0 (float32_ref 64) [64, bytes: 256]
# res_block0_8/res_block0_8_bn1/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block0_8/res_block0_8_bn1/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block0_8/Wconv1:0 (float32_ref 1x1x64x16) [1024, bytes: 4096]
# res_block0_8/bconv1:0 (float32_ref 16) [16, bytes: 64]
# res_block0_8/res_block0_8_bn2/batch_normalization/gamma:0 (float32_ref 16) [16, bytes: 64]
# res_block0_8/res_block0_8_bn2/batch_normalization/beta:0 (float32_ref 16) [16, bytes: 64]
# res_block0_8/Wconv2:0 (float32_ref 3x3x16x16) [2304, bytes: 9216]
# res_block0_8/bconv2:0 (float32_ref 16) [16, bytes: 64]
# res_block0_8/res_block0_8_bn3/batch_normalization/gamma:0 (float32_ref 16) [16, bytes: 64]
# res_block0_8/res_block0_8_bn3/batch_normalization/beta:0 (float32_ref 16) [16, bytes: 64]
# res_block0_8/Wconv3:0 (float32_ref 1x1x16x64) [1024, bytes: 4096]
# res_block0_8/bconv3:0 (float32_ref 64) [64, bytes: 256]
# res_block0_9/res_block0_9_bn1/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block0_9/res_block0_9_bn1/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block0_9/Wconv1:0 (float32_ref 1x1x64x16) [1024, bytes: 4096]
# res_block0_9/bconv1:0 (float32_ref 16) [16, bytes: 64]
# res_block0_9/res_block0_9_bn2/batch_normalization/gamma:0 (float32_ref 16) [16, bytes: 64]
# res_block0_9/res_block0_9_bn2/batch_normalization/beta:0 (float32_ref 16) [16, bytes: 64]
# res_block0_9/Wconv2:0 (float32_ref 3x3x16x16) [2304, bytes: 9216]
# res_block0_9/bconv2:0 (float32_ref 16) [16, bytes: 64]
# res_block0_9/res_block0_9_bn3/batch_normalization/gamma:0 (float32_ref 16) [16, bytes: 64]
# res_block0_9/res_block0_9_bn3/batch_normalization/beta:0 (float32_ref 16) [16, bytes: 64]
# res_block0_9/Wconv3:0 (float32_ref 1x1x16x64) [1024, bytes: 4096]
# res_block0_9/bconv3:0 (float32_ref 64) [64, bytes: 256]
# res_block0_10/res_block0_10_bn1/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block0_10/res_block0_10_bn1/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block0_10/Wconv1:0 (float32_ref 1x1x64x16) [1024, bytes: 4096]
# res_block0_10/bconv1:0 (float32_ref 16) [16, bytes: 64]
# res_block0_10/res_block0_10_bn2/batch_normalization/gamma:0 (float32_ref 16) [16, bytes: 64]
# res_block0_10/res_block0_10_bn2/batch_normalization/beta:0 (float32_ref 16) [16, bytes: 64]
# res_block0_10/Wconv2:0 (float32_ref 3x3x16x16) [2304, bytes: 9216]
# res_block0_10/bconv2:0 (float32_ref 16) [16, bytes: 64]
# res_block0_10/res_block0_10_bn3/batch_normalization/gamma:0 (float32_ref 16) [16, bytes: 64]
# res_block0_10/res_block0_10_bn3/batch_normalization/beta:0 (float32_ref 16) [16, bytes: 64]
# res_block0_10/Wconv3:0 (float32_ref 1x1x16x64) [1024, bytes: 4096]
# res_block0_10/bconv3:0 (float32_ref 64) [64, bytes: 256]
# res_block0_11/res_block0_11_bn1/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block0_11/res_block0_11_bn1/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block0_11/Wconv1:0 (float32_ref 1x1x64x16) [1024, bytes: 4096]
# res_block0_11/bconv1:0 (float32_ref 16) [16, bytes: 64]
# res_block0_11/res_block0_11_bn2/batch_normalization/gamma:0 (float32_ref 16) [16, bytes: 64]
# res_block0_11/res_block0_11_bn2/batch_normalization/beta:0 (float32_ref 16) [16, bytes: 64]
# res_block0_11/Wconv2:0 (float32_ref 3x3x16x16) [2304, bytes: 9216]
# res_block0_11/bconv2:0 (float32_ref 16) [16, bytes: 64]
# res_block0_11/res_block0_11_bn3/batch_normalization/gamma:0 (float32_ref 16) [16, bytes: 64]
# res_block0_11/res_block0_11_bn3/batch_normalization/beta:0 (float32_ref 16) [16, bytes: 64]
# res_block0_11/Wconv3:0 (float32_ref 1x1x16x64) [1024, bytes: 4096]
# res_block0_11/bconv3:0 (float32_ref 64) [64, bytes: 256]
# res_block0_12/res_block0_12_bn1/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block0_12/res_block0_12_bn1/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block0_12/Wconv1:0 (float32_ref 1x1x64x16) [1024, bytes: 4096]
# res_block0_12/bconv1:0 (float32_ref 16) [16, bytes: 64]
# res_block0_12/res_block0_12_bn2/batch_normalization/gamma:0 (float32_ref 16) [16, bytes: 64]
# res_block0_12/res_block0_12_bn2/batch_normalization/beta:0 (float32_ref 16) [16, bytes: 64]
# res_block0_12/Wconv2:0 (float32_ref 3x3x16x16) [2304, bytes: 9216]
# res_block0_12/bconv2:0 (float32_ref 16) [16, bytes: 64]
# res_block0_12/res_block0_12_bn3/batch_normalization/gamma:0 (float32_ref 16) [16, bytes: 64]
# res_block0_12/res_block0_12_bn3/batch_normalization/beta:0 (float32_ref 16) [16, bytes: 64]
# res_block0_12/Wconv3:0 (float32_ref 1x1x16x64) [1024, bytes: 4096]
# res_block0_12/bconv3:0 (float32_ref 64) [64, bytes: 256]
# res_block0_13/res_block0_13_bn1/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block0_13/res_block0_13_bn1/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block0_13/Wconv1:0 (float32_ref 1x1x64x16) [1024, bytes: 4096]
# res_block0_13/bconv1:0 (float32_ref 16) [16, bytes: 64]
# res_block0_13/res_block0_13_bn2/batch_normalization/gamma:0 (float32_ref 16) [16, bytes: 64]
# res_block0_13/res_block0_13_bn2/batch_normalization/beta:0 (float32_ref 16) [16, bytes: 64]
# res_block0_13/Wconv2:0 (float32_ref 3x3x16x16) [2304, bytes: 9216]
# res_block0_13/bconv2:0 (float32_ref 16) [16, bytes: 64]
# res_block0_13/res_block0_13_bn3/batch_normalization/gamma:0 (float32_ref 16) [16, bytes: 64]
# res_block0_13/res_block0_13_bn3/batch_normalization/beta:0 (float32_ref 16) [16, bytes: 64]
# res_block0_13/Wconv3:0 (float32_ref 1x1x16x64) [1024, bytes: 4096]
# res_block0_13/bconv3:0 (float32_ref 64) [64, bytes: 256]
# res_block0_14/res_block0_14_bn1/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block0_14/res_block0_14_bn1/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block0_14/Wconv1:0 (float32_ref 1x1x64x16) [1024, bytes: 4096]
# res_block0_14/bconv1:0 (float32_ref 16) [16, bytes: 64]
# res_block0_14/res_block0_14_bn2/batch_normalization/gamma:0 (float32_ref 16) [16, bytes: 64]
# res_block0_14/res_block0_14_bn2/batch_normalization/beta:0 (float32_ref 16) [16, bytes: 64]
# res_block0_14/Wconv2:0 (float32_ref 3x3x16x16) [2304, bytes: 9216]
# res_block0_14/bconv2:0 (float32_ref 16) [16, bytes: 64]
# res_block0_14/res_block0_14_bn3/batch_normalization/gamma:0 (float32_ref 16) [16, bytes: 64]
# res_block0_14/res_block0_14_bn3/batch_normalization/beta:0 (float32_ref 16) [16, bytes: 64]
# res_block0_14/Wconv3:0 (float32_ref 1x1x16x64) [1024, bytes: 4096]
# res_block0_14/bconv3:0 (float32_ref 64) [64, bytes: 256]
# res_block0_15/res_block0_15_bn1/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block0_15/res_block0_15_bn1/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block0_15/Wconv1:0 (float32_ref 1x1x64x16) [1024, bytes: 4096]
# res_block0_15/bconv1:0 (float32_ref 16) [16, bytes: 64]
# res_block0_15/res_block0_15_bn2/batch_normalization/gamma:0 (float32_ref 16) [16, bytes: 64]
# res_block0_15/res_block0_15_bn2/batch_normalization/beta:0 (float32_ref 16) [16, bytes: 64]
# res_block0_15/Wconv2:0 (float32_ref 3x3x16x16) [2304, bytes: 9216]
# res_block0_15/bconv2:0 (float32_ref 16) [16, bytes: 64]
# res_block0_15/res_block0_15_bn3/batch_normalization/gamma:0 (float32_ref 16) [16, bytes: 64]
# res_block0_15/res_block0_15_bn3/batch_normalization/beta:0 (float32_ref 16) [16, bytes: 64]
# res_block0_15/Wconv3:0 (float32_ref 1x1x16x64) [1024, bytes: 4096]
# res_block0_15/bconv3:0 (float32_ref 64) [64, bytes: 256]
# res_block0_16/res_block0_16_bn1/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block0_16/res_block0_16_bn1/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block0_16/Wconv1:0 (float32_ref 1x1x64x16) [1024, bytes: 4096]
# res_block0_16/bconv1:0 (float32_ref 16) [16, bytes: 64]
# res_block0_16/res_block0_16_bn2/batch_normalization/gamma:0 (float32_ref 16) [16, bytes: 64]
# res_block0_16/res_block0_16_bn2/batch_normalization/beta:0 (float32_ref 16) [16, bytes: 64]
# res_block0_16/Wconv2:0 (float32_ref 3x3x16x16) [2304, bytes: 9216]
# res_block0_16/bconv2:0 (float32_ref 16) [16, bytes: 64]
# res_block0_16/res_block0_16_bn3/batch_normalization/gamma:0 (float32_ref 16) [16, bytes: 64]
# res_block0_16/res_block0_16_bn3/batch_normalization/beta:0 (float32_ref 16) [16, bytes: 64]
# res_block0_16/Wconv3:0 (float32_ref 1x1x16x64) [1024, bytes: 4096]
# res_block0_16/bconv3:0 (float32_ref 64) [64, bytes: 256]
# res_block0_17/res_block0_17_bn1/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block0_17/res_block0_17_bn1/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block0_17/Wconv1:0 (float32_ref 1x1x64x16) [1024, bytes: 4096]
# res_block0_17/bconv1:0 (float32_ref 16) [16, bytes: 64]
# res_block0_17/res_block0_17_bn2/batch_normalization/gamma:0 (float32_ref 16) [16, bytes: 64]
# res_block0_17/res_block0_17_bn2/batch_normalization/beta:0 (float32_ref 16) [16, bytes: 64]
# res_block0_17/Wconv2:0 (float32_ref 3x3x16x16) [2304, bytes: 9216]
# res_block0_17/bconv2:0 (float32_ref 16) [16, bytes: 64]
# res_block0_17/res_block0_17_bn3/batch_normalization/gamma:0 (float32_ref 16) [16, bytes: 64]
# res_block0_17/res_block0_17_bn3/batch_normalization/beta:0 (float32_ref 16) [16, bytes: 64]
# res_block0_17/Wconv3:0 (float32_ref 1x1x16x64) [1024, bytes: 4096]
# res_block0_17/bconv3:0 (float32_ref 64) [64, bytes: 256]
# res_block1_0/res_block1_0_bn1/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block1_0/res_block1_0_bn1/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block1_0/Wconv1:0 (float32_ref 1x1x64x32) [2048, bytes: 8192]
# res_block1_0/bconv1:0 (float32_ref 32) [32, bytes: 128]
# res_block1_0/res_block1_0_bn2/batch_normalization/gamma:0 (float32_ref 32) [32, bytes: 128]
# res_block1_0/res_block1_0_bn2/batch_normalization/beta:0 (float32_ref 32) [32, bytes: 128]
# res_block1_0/Wconv2:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# res_block1_0/bconv2:0 (float32_ref 32) [32, bytes: 128]
# res_block1_0/res_block1_0_bn3/batch_normalization/gamma:0 (float32_ref 32) [32, bytes: 128]
# res_block1_0/res_block1_0_bn3/batch_normalization/beta:0 (float32_ref 32) [32, bytes: 128]
# res_block1_0/Wconv3:0 (float32_ref 1x1x32x128) [4096, bytes: 16384]
# res_block1_0/bconv3:0 (float32_ref 128) [128, bytes: 512]
# res_block1_0_sc/Wconv:0 (float32_ref 1x1x64x128) [8192, bytes: 32768]
# res_block1_0_sc/bconv:0 (float32_ref 128) [128, bytes: 512]
# res_block1_1/res_block1_1_bn1/batch_normalization/gamma:0 (float32_ref 128) [128, bytes: 512]
# res_block1_1/res_block1_1_bn1/batch_normalization/beta:0 (float32_ref 128) [128, bytes: 512]
# res_block1_1/Wconv1:0 (float32_ref 1x1x128x32) [4096, bytes: 16384]
# res_block1_1/bconv1:0 (float32_ref 32) [32, bytes: 128]
# res_block1_1/res_block1_1_bn2/batch_normalization/gamma:0 (float32_ref 32) [32, bytes: 128]
# res_block1_1/res_block1_1_bn2/batch_normalization/beta:0 (float32_ref 32) [32, bytes: 128]
# res_block1_1/Wconv2:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# res_block1_1/bconv2:0 (float32_ref 32) [32, bytes: 128]
# res_block1_1/res_block1_1_bn3/batch_normalization/gamma:0 (float32_ref 32) [32, bytes: 128]
# res_block1_1/res_block1_1_bn3/batch_normalization/beta:0 (float32_ref 32) [32, bytes: 128]
# res_block1_1/Wconv3:0 (float32_ref 1x1x32x128) [4096, bytes: 16384]
# res_block1_1/bconv3:0 (float32_ref 128) [128, bytes: 512]
# res_block1_2/res_block1_2_bn1/batch_normalization/gamma:0 (float32_ref 128) [128, bytes: 512]
# res_block1_2/res_block1_2_bn1/batch_normalization/beta:0 (float32_ref 128) [128, bytes: 512]
# res_block1_2/Wconv1:0 (float32_ref 1x1x128x32) [4096, bytes: 16384]
# res_block1_2/bconv1:0 (float32_ref 32) [32, bytes: 128]
# res_block1_2/res_block1_2_bn2/batch_normalization/gamma:0 (float32_ref 32) [32, bytes: 128]
# res_block1_2/res_block1_2_bn2/batch_normalization/beta:0 (float32_ref 32) [32, bytes: 128]
# res_block1_2/Wconv2:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# res_block1_2/bconv2:0 (float32_ref 32) [32, bytes: 128]
# res_block1_2/res_block1_2_bn3/batch_normalization/gamma:0 (float32_ref 32) [32, bytes: 128]
# res_block1_2/res_block1_2_bn3/batch_normalization/beta:0 (float32_ref 32) [32, bytes: 128]
# res_block1_2/Wconv3:0 (float32_ref 1x1x32x128) [4096, bytes: 16384]
# res_block1_2/bconv3:0 (float32_ref 128) [128, bytes: 512]
# res_block1_3/res_block1_3_bn1/batch_normalization/gamma:0 (float32_ref 128) [128, bytes: 512]
# res_block1_3/res_block1_3_bn1/batch_normalization/beta:0 (float32_ref 128) [128, bytes: 512]
# res_block1_3/Wconv1:0 (float32_ref 1x1x128x32) [4096, bytes: 16384]
# res_block1_3/bconv1:0 (float32_ref 32) [32, bytes: 128]
# res_block1_3/res_block1_3_bn2/batch_normalization/gamma:0 (float32_ref 32) [32, bytes: 128]
# res_block1_3/res_block1_3_bn2/batch_normalization/beta:0 (float32_ref 32) [32, bytes: 128]
# res_block1_3/Wconv2:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# res_block1_3/bconv2:0 (float32_ref 32) [32, bytes: 128]
# res_block1_3/res_block1_3_bn3/batch_normalization/gamma:0 (float32_ref 32) [32, bytes: 128]
# res_block1_3/res_block1_3_bn3/batch_normalization/beta:0 (float32_ref 32) [32, bytes: 128]
# res_block1_3/Wconv3:0 (float32_ref 1x1x32x128) [4096, bytes: 16384]
# res_block1_3/bconv3:0 (float32_ref 128) [128, bytes: 512]
# res_block1_4/res_block1_4_bn1/batch_normalization/gamma:0 (float32_ref 128) [128, bytes: 512]
# res_block1_4/res_block1_4_bn1/batch_normalization/beta:0 (float32_ref 128) [128, bytes: 512]
# res_block1_4/Wconv1:0 (float32_ref 1x1x128x32) [4096, bytes: 16384]
# res_block1_4/bconv1:0 (float32_ref 32) [32, bytes: 128]
# res_block1_4/res_block1_4_bn2/batch_normalization/gamma:0 (float32_ref 32) [32, bytes: 128]
# res_block1_4/res_block1_4_bn2/batch_normalization/beta:0 (float32_ref 32) [32, bytes: 128]
# res_block1_4/Wconv2:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# res_block1_4/bconv2:0 (float32_ref 32) [32, bytes: 128]
# res_block1_4/res_block1_4_bn3/batch_normalization/gamma:0 (float32_ref 32) [32, bytes: 128]
# res_block1_4/res_block1_4_bn3/batch_normalization/beta:0 (float32_ref 32) [32, bytes: 128]
# res_block1_4/Wconv3:0 (float32_ref 1x1x32x128) [4096, bytes: 16384]
# res_block1_4/bconv3:0 (float32_ref 128) [128, bytes: 512]
# res_block1_5/res_block1_5_bn1/batch_normalization/gamma:0 (float32_ref 128) [128, bytes: 512]
# res_block1_5/res_block1_5_bn1/batch_normalization/beta:0 (float32_ref 128) [128, bytes: 512]
# res_block1_5/Wconv1:0 (float32_ref 1x1x128x32) [4096, bytes: 16384]
# res_block1_5/bconv1:0 (float32_ref 32) [32, bytes: 128]
# res_block1_5/res_block1_5_bn2/batch_normalization/gamma:0 (float32_ref 32) [32, bytes: 128]
# res_block1_5/res_block1_5_bn2/batch_normalization/beta:0 (float32_ref 32) [32, bytes: 128]
# res_block1_5/Wconv2:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# res_block1_5/bconv2:0 (float32_ref 32) [32, bytes: 128]
# res_block1_5/res_block1_5_bn3/batch_normalization/gamma:0 (float32_ref 32) [32, bytes: 128]
# res_block1_5/res_block1_5_bn3/batch_normalization/beta:0 (float32_ref 32) [32, bytes: 128]
# res_block1_5/Wconv3:0 (float32_ref 1x1x32x128) [4096, bytes: 16384]
# res_block1_5/bconv3:0 (float32_ref 128) [128, bytes: 512]
# res_block1_6/res_block1_6_bn1/batch_normalization/gamma:0 (float32_ref 128) [128, bytes: 512]
# res_block1_6/res_block1_6_bn1/batch_normalization/beta:0 (float32_ref 128) [128, bytes: 512]
# res_block1_6/Wconv1:0 (float32_ref 1x1x128x32) [4096, bytes: 16384]
# res_block1_6/bconv1:0 (float32_ref 32) [32, bytes: 128]
# res_block1_6/res_block1_6_bn2/batch_normalization/gamma:0 (float32_ref 32) [32, bytes: 128]
# res_block1_6/res_block1_6_bn2/batch_normalization/beta:0 (float32_ref 32) [32, bytes: 128]
# res_block1_6/Wconv2:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# res_block1_6/bconv2:0 (float32_ref 32) [32, bytes: 128]
# res_block1_6/res_block1_6_bn3/batch_normalization/gamma:0 (float32_ref 32) [32, bytes: 128]
# res_block1_6/res_block1_6_bn3/batch_normalization/beta:0 (float32_ref 32) [32, bytes: 128]
# res_block1_6/Wconv3:0 (float32_ref 1x1x32x128) [4096, bytes: 16384]
# res_block1_6/bconv3:0 (float32_ref 128) [128, bytes: 512]
# res_block1_7/res_block1_7_bn1/batch_normalization/gamma:0 (float32_ref 128) [128, bytes: 512]
# res_block1_7/res_block1_7_bn1/batch_normalization/beta:0 (float32_ref 128) [128, bytes: 512]
# res_block1_7/Wconv1:0 (float32_ref 1x1x128x32) [4096, bytes: 16384]
# res_block1_7/bconv1:0 (float32_ref 32) [32, bytes: 128]
# res_block1_7/res_block1_7_bn2/batch_normalization/gamma:0 (float32_ref 32) [32, bytes: 128]
# res_block1_7/res_block1_7_bn2/batch_normalization/beta:0 (float32_ref 32) [32, bytes: 128]
# res_block1_7/Wconv2:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# res_block1_7/bconv2:0 (float32_ref 32) [32, bytes: 128]
# res_block1_7/res_block1_7_bn3/batch_normalization/gamma:0 (float32_ref 32) [32, bytes: 128]
# res_block1_7/res_block1_7_bn3/batch_normalization/beta:0 (float32_ref 32) [32, bytes: 128]
# res_block1_7/Wconv3:0 (float32_ref 1x1x32x128) [4096, bytes: 16384]
# res_block1_7/bconv3:0 (float32_ref 128) [128, bytes: 512]
# res_block1_8/res_block1_8_bn1/batch_normalization/gamma:0 (float32_ref 128) [128, bytes: 512]
# res_block1_8/res_block1_8_bn1/batch_normalization/beta:0 (float32_ref 128) [128, bytes: 512]
# res_block1_8/Wconv1:0 (float32_ref 1x1x128x32) [4096, bytes: 16384]
# res_block1_8/bconv1:0 (float32_ref 32) [32, bytes: 128]
# res_block1_8/res_block1_8_bn2/batch_normalization/gamma:0 (float32_ref 32) [32, bytes: 128]
# res_block1_8/res_block1_8_bn2/batch_normalization/beta:0 (float32_ref 32) [32, bytes: 128]
# res_block1_8/Wconv2:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# res_block1_8/bconv2:0 (float32_ref 32) [32, bytes: 128]
# res_block1_8/res_block1_8_bn3/batch_normalization/gamma:0 (float32_ref 32) [32, bytes: 128]
# res_block1_8/res_block1_8_bn3/batch_normalization/beta:0 (float32_ref 32) [32, bytes: 128]
# res_block1_8/Wconv3:0 (float32_ref 1x1x32x128) [4096, bytes: 16384]
# res_block1_8/bconv3:0 (float32_ref 128) [128, bytes: 512]
# res_block1_9/res_block1_9_bn1/batch_normalization/gamma:0 (float32_ref 128) [128, bytes: 512]
# res_block1_9/res_block1_9_bn1/batch_normalization/beta:0 (float32_ref 128) [128, bytes: 512]
# res_block1_9/Wconv1:0 (float32_ref 1x1x128x32) [4096, bytes: 16384]
# res_block1_9/bconv1:0 (float32_ref 32) [32, bytes: 128]
# res_block1_9/res_block1_9_bn2/batch_normalization/gamma:0 (float32_ref 32) [32, bytes: 128]
# res_block1_9/res_block1_9_bn2/batch_normalization/beta:0 (float32_ref 32) [32, bytes: 128]
# res_block1_9/Wconv2:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# res_block1_9/bconv2:0 (float32_ref 32) [32, bytes: 128]
# res_block1_9/res_block1_9_bn3/batch_normalization/gamma:0 (float32_ref 32) [32, bytes: 128]
# res_block1_9/res_block1_9_bn3/batch_normalization/beta:0 (float32_ref 32) [32, bytes: 128]
# res_block1_9/Wconv3:0 (float32_ref 1x1x32x128) [4096, bytes: 16384]
# res_block1_9/bconv3:0 (float32_ref 128) [128, bytes: 512]
# res_block1_10/res_block1_10_bn1/batch_normalization/gamma:0 (float32_ref 128) [128, bytes: 512]
# res_block1_10/res_block1_10_bn1/batch_normalization/beta:0 (float32_ref 128) [128, bytes: 512]
# res_block1_10/Wconv1:0 (float32_ref 1x1x128x32) [4096, bytes: 16384]
# res_block1_10/bconv1:0 (float32_ref 32) [32, bytes: 128]
# res_block1_10/res_block1_10_bn2/batch_normalization/gamma:0 (float32_ref 32) [32, bytes: 128]
# res_block1_10/res_block1_10_bn2/batch_normalization/beta:0 (float32_ref 32) [32, bytes: 128]
# res_block1_10/Wconv2:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# res_block1_10/bconv2:0 (float32_ref 32) [32, bytes: 128]
# res_block1_10/res_block1_10_bn3/batch_normalization/gamma:0 (float32_ref 32) [32, bytes: 128]
# res_block1_10/res_block1_10_bn3/batch_normalization/beta:0 (float32_ref 32) [32, bytes: 128]
# res_block1_10/Wconv3:0 (float32_ref 1x1x32x128) [4096, bytes: 16384]
# res_block1_10/bconv3:0 (float32_ref 128) [128, bytes: 512]
# res_block1_11/res_block1_11_bn1/batch_normalization/gamma:0 (float32_ref 128) [128, bytes: 512]
# res_block1_11/res_block1_11_bn1/batch_normalization/beta:0 (float32_ref 128) [128, bytes: 512]
# res_block1_11/Wconv1:0 (float32_ref 1x1x128x32) [4096, bytes: 16384]
# res_block1_11/bconv1:0 (float32_ref 32) [32, bytes: 128]
# res_block1_11/res_block1_11_bn2/batch_normalization/gamma:0 (float32_ref 32) [32, bytes: 128]
# res_block1_11/res_block1_11_bn2/batch_normalization/beta:0 (float32_ref 32) [32, bytes: 128]
# res_block1_11/Wconv2:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# res_block1_11/bconv2:0 (float32_ref 32) [32, bytes: 128]
# res_block1_11/res_block1_11_bn3/batch_normalization/gamma:0 (float32_ref 32) [32, bytes: 128]
# res_block1_11/res_block1_11_bn3/batch_normalization/beta:0 (float32_ref 32) [32, bytes: 128]
# res_block1_11/Wconv3:0 (float32_ref 1x1x32x128) [4096, bytes: 16384]
# res_block1_11/bconv3:0 (float32_ref 128) [128, bytes: 512]
# res_block1_12/res_block1_12_bn1/batch_normalization/gamma:0 (float32_ref 128) [128, bytes: 512]
# res_block1_12/res_block1_12_bn1/batch_normalization/beta:0 (float32_ref 128) [128, bytes: 512]
# res_block1_12/Wconv1:0 (float32_ref 1x1x128x32) [4096, bytes: 16384]
# res_block1_12/bconv1:0 (float32_ref 32) [32, bytes: 128]
# res_block1_12/res_block1_12_bn2/batch_normalization/gamma:0 (float32_ref 32) [32, bytes: 128]
# res_block1_12/res_block1_12_bn2/batch_normalization/beta:0 (float32_ref 32) [32, bytes: 128]
# res_block1_12/Wconv2:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# res_block1_12/bconv2:0 (float32_ref 32) [32, bytes: 128]
# res_block1_12/res_block1_12_bn3/batch_normalization/gamma:0 (float32_ref 32) [32, bytes: 128]
# res_block1_12/res_block1_12_bn3/batch_normalization/beta:0 (float32_ref 32) [32, bytes: 128]
# res_block1_12/Wconv3:0 (float32_ref 1x1x32x128) [4096, bytes: 16384]
# res_block1_12/bconv3:0 (float32_ref 128) [128, bytes: 512]
# res_block1_13/res_block1_13_bn1/batch_normalization/gamma:0 (float32_ref 128) [128, bytes: 512]
# res_block1_13/res_block1_13_bn1/batch_normalization/beta:0 (float32_ref 128) [128, bytes: 512]
# res_block1_13/Wconv1:0 (float32_ref 1x1x128x32) [4096, bytes: 16384]
# res_block1_13/bconv1:0 (float32_ref 32) [32, bytes: 128]
# res_block1_13/res_block1_13_bn2/batch_normalization/gamma:0 (float32_ref 32) [32, bytes: 128]
# res_block1_13/res_block1_13_bn2/batch_normalization/beta:0 (float32_ref 32) [32, bytes: 128]
# res_block1_13/Wconv2:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# res_block1_13/bconv2:0 (float32_ref 32) [32, bytes: 128]
# res_block1_13/res_block1_13_bn3/batch_normalization/gamma:0 (float32_ref 32) [32, bytes: 128]
# res_block1_13/res_block1_13_bn3/batch_normalization/beta:0 (float32_ref 32) [32, bytes: 128]
# res_block1_13/Wconv3:0 (float32_ref 1x1x32x128) [4096, bytes: 16384]
# res_block1_13/bconv3:0 (float32_ref 128) [128, bytes: 512]
# res_block1_14/res_block1_14_bn1/batch_normalization/gamma:0 (float32_ref 128) [128, bytes: 512]
# res_block1_14/res_block1_14_bn1/batch_normalization/beta:0 (float32_ref 128) [128, bytes: 512]
# res_block1_14/Wconv1:0 (float32_ref 1x1x128x32) [4096, bytes: 16384]
# res_block1_14/bconv1:0 (float32_ref 32) [32, bytes: 128]
# res_block1_14/res_block1_14_bn2/batch_normalization/gamma:0 (float32_ref 32) [32, bytes: 128]
# res_block1_14/res_block1_14_bn2/batch_normalization/beta:0 (float32_ref 32) [32, bytes: 128]
# res_block1_14/Wconv2:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# res_block1_14/bconv2:0 (float32_ref 32) [32, bytes: 128]
# res_block1_14/res_block1_14_bn3/batch_normalization/gamma:0 (float32_ref 32) [32, bytes: 128]
# res_block1_14/res_block1_14_bn3/batch_normalization/beta:0 (float32_ref 32) [32, bytes: 128]
# res_block1_14/Wconv3:0 (float32_ref 1x1x32x128) [4096, bytes: 16384]
# res_block1_14/bconv3:0 (float32_ref 128) [128, bytes: 512]
# res_block1_15/res_block1_15_bn1/batch_normalization/gamma:0 (float32_ref 128) [128, bytes: 512]
# res_block1_15/res_block1_15_bn1/batch_normalization/beta:0 (float32_ref 128) [128, bytes: 512]
# res_block1_15/Wconv1:0 (float32_ref 1x1x128x32) [4096, bytes: 16384]
# res_block1_15/bconv1:0 (float32_ref 32) [32, bytes: 128]
# res_block1_15/res_block1_15_bn2/batch_normalization/gamma:0 (float32_ref 32) [32, bytes: 128]
# res_block1_15/res_block1_15_bn2/batch_normalization/beta:0 (float32_ref 32) [32, bytes: 128]
# res_block1_15/Wconv2:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# res_block1_15/bconv2:0 (float32_ref 32) [32, bytes: 128]
# res_block1_15/res_block1_15_bn3/batch_normalization/gamma:0 (float32_ref 32) [32, bytes: 128]
# res_block1_15/res_block1_15_bn3/batch_normalization/beta:0 (float32_ref 32) [32, bytes: 128]
# res_block1_15/Wconv3:0 (float32_ref 1x1x32x128) [4096, bytes: 16384]
# res_block1_15/bconv3:0 (float32_ref 128) [128, bytes: 512]
# res_block1_16/res_block1_16_bn1/batch_normalization/gamma:0 (float32_ref 128) [128, bytes: 512]
# res_block1_16/res_block1_16_bn1/batch_normalization/beta:0 (float32_ref 128) [128, bytes: 512]
# res_block1_16/Wconv1:0 (float32_ref 1x1x128x32) [4096, bytes: 16384]
# res_block1_16/bconv1:0 (float32_ref 32) [32, bytes: 128]
# res_block1_16/res_block1_16_bn2/batch_normalization/gamma:0 (float32_ref 32) [32, bytes: 128]
# res_block1_16/res_block1_16_bn2/batch_normalization/beta:0 (float32_ref 32) [32, bytes: 128]
# res_block1_16/Wconv2:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# res_block1_16/bconv2:0 (float32_ref 32) [32, bytes: 128]
# res_block1_16/res_block1_16_bn3/batch_normalization/gamma:0 (float32_ref 32) [32, bytes: 128]
# res_block1_16/res_block1_16_bn3/batch_normalization/beta:0 (float32_ref 32) [32, bytes: 128]
# res_block1_16/Wconv3:0 (float32_ref 1x1x32x128) [4096, bytes: 16384]
# res_block1_16/bconv3:0 (float32_ref 128) [128, bytes: 512]
# res_block1_17/res_block1_17_bn1/batch_normalization/gamma:0 (float32_ref 128) [128, bytes: 512]
# res_block1_17/res_block1_17_bn1/batch_normalization/beta:0 (float32_ref 128) [128, bytes: 512]
# res_block1_17/Wconv1:0 (float32_ref 1x1x128x32) [4096, bytes: 16384]
# res_block1_17/bconv1:0 (float32_ref 32) [32, bytes: 128]
# res_block1_17/res_block1_17_bn2/batch_normalization/gamma:0 (float32_ref 32) [32, bytes: 128]
# res_block1_17/res_block1_17_bn2/batch_normalization/beta:0 (float32_ref 32) [32, bytes: 128]
# res_block1_17/Wconv2:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# res_block1_17/bconv2:0 (float32_ref 32) [32, bytes: 128]
# res_block1_17/res_block1_17_bn3/batch_normalization/gamma:0 (float32_ref 32) [32, bytes: 128]
# res_block1_17/res_block1_17_bn3/batch_normalization/beta:0 (float32_ref 32) [32, bytes: 128]
# res_block1_17/Wconv3:0 (float32_ref 1x1x32x128) [4096, bytes: 16384]
# res_block1_17/bconv3:0 (float32_ref 128) [128, bytes: 512]
# res_block2_0/res_block2_0_bn1/batch_normalization/gamma:0 (float32_ref 128) [128, bytes: 512]
# res_block2_0/res_block2_0_bn1/batch_normalization/beta:0 (float32_ref 128) [128, bytes: 512]
# res_block2_0/Wconv1:0 (float32_ref 1x1x128x64) [8192, bytes: 32768]
# res_block2_0/bconv1:0 (float32_ref 64) [64, bytes: 256]
# res_block2_0/res_block2_0_bn2/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block2_0/res_block2_0_bn2/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block2_0/Wconv2:0 (float32_ref 3x3x64x64) [36864, bytes: 147456]
# res_block2_0/bconv2:0 (float32_ref 64) [64, bytes: 256]
# res_block2_0/res_block2_0_bn3/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block2_0/res_block2_0_bn3/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block2_0/Wconv3:0 (float32_ref 1x1x64x256) [16384, bytes: 65536]
# res_block2_0/bconv3:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_0_sc/Wconv:0 (float32_ref 1x1x128x256) [32768, bytes: 131072]
# res_block2_0_sc/bconv:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_1/res_block2_1_bn1/batch_normalization/gamma:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_1/res_block2_1_bn1/batch_normalization/beta:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_1/Wconv1:0 (float32_ref 1x1x256x64) [16384, bytes: 65536]
# res_block2_1/bconv1:0 (float32_ref 64) [64, bytes: 256]
# res_block2_1/res_block2_1_bn2/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block2_1/res_block2_1_bn2/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block2_1/Wconv2:0 (float32_ref 3x3x64x64) [36864, bytes: 147456]
# res_block2_1/bconv2:0 (float32_ref 64) [64, bytes: 256]
# res_block2_1/res_block2_1_bn3/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block2_1/res_block2_1_bn3/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block2_1/Wconv3:0 (float32_ref 1x1x64x256) [16384, bytes: 65536]
# res_block2_1/bconv3:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_2/res_block2_2_bn1/batch_normalization/gamma:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_2/res_block2_2_bn1/batch_normalization/beta:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_2/Wconv1:0 (float32_ref 1x1x256x64) [16384, bytes: 65536]
# res_block2_2/bconv1:0 (float32_ref 64) [64, bytes: 256]
# res_block2_2/res_block2_2_bn2/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block2_2/res_block2_2_bn2/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block2_2/Wconv2:0 (float32_ref 3x3x64x64) [36864, bytes: 147456]
# res_block2_2/bconv2:0 (float32_ref 64) [64, bytes: 256]
# res_block2_2/res_block2_2_bn3/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block2_2/res_block2_2_bn3/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block2_2/Wconv3:0 (float32_ref 1x1x64x256) [16384, bytes: 65536]
# res_block2_2/bconv3:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_3/res_block2_3_bn1/batch_normalization/gamma:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_3/res_block2_3_bn1/batch_normalization/beta:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_3/Wconv1:0 (float32_ref 1x1x256x64) [16384, bytes: 65536]
# res_block2_3/bconv1:0 (float32_ref 64) [64, bytes: 256]
# res_block2_3/res_block2_3_bn2/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block2_3/res_block2_3_bn2/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block2_3/Wconv2:0 (float32_ref 3x3x64x64) [36864, bytes: 147456]
# res_block2_3/bconv2:0 (float32_ref 64) [64, bytes: 256]
# res_block2_3/res_block2_3_bn3/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block2_3/res_block2_3_bn3/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block2_3/Wconv3:0 (float32_ref 1x1x64x256) [16384, bytes: 65536]
# res_block2_3/bconv3:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_4/res_block2_4_bn1/batch_normalization/gamma:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_4/res_block2_4_bn1/batch_normalization/beta:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_4/Wconv1:0 (float32_ref 1x1x256x64) [16384, bytes: 65536]
# res_block2_4/bconv1:0 (float32_ref 64) [64, bytes: 256]
# res_block2_4/res_block2_4_bn2/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block2_4/res_block2_4_bn2/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block2_4/Wconv2:0 (float32_ref 3x3x64x64) [36864, bytes: 147456]
# res_block2_4/bconv2:0 (float32_ref 64) [64, bytes: 256]
# res_block2_4/res_block2_4_bn3/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block2_4/res_block2_4_bn3/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block2_4/Wconv3:0 (float32_ref 1x1x64x256) [16384, bytes: 65536]
# res_block2_4/bconv3:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_5/res_block2_5_bn1/batch_normalization/gamma:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_5/res_block2_5_bn1/batch_normalization/beta:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_5/Wconv1:0 (float32_ref 1x1x256x64) [16384, bytes: 65536]
# res_block2_5/bconv1:0 (float32_ref 64) [64, bytes: 256]
# res_block2_5/res_block2_5_bn2/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block2_5/res_block2_5_bn2/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block2_5/Wconv2:0 (float32_ref 3x3x64x64) [36864, bytes: 147456]
# res_block2_5/bconv2:0 (float32_ref 64) [64, bytes: 256]
# res_block2_5/res_block2_5_bn3/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block2_5/res_block2_5_bn3/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block2_5/Wconv3:0 (float32_ref 1x1x64x256) [16384, bytes: 65536]
# res_block2_5/bconv3:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_6/res_block2_6_bn1/batch_normalization/gamma:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_6/res_block2_6_bn1/batch_normalization/beta:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_6/Wconv1:0 (float32_ref 1x1x256x64) [16384, bytes: 65536]
# res_block2_6/bconv1:0 (float32_ref 64) [64, bytes: 256]
# res_block2_6/res_block2_6_bn2/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block2_6/res_block2_6_bn2/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block2_6/Wconv2:0 (float32_ref 3x3x64x64) [36864, bytes: 147456]
# res_block2_6/bconv2:0 (float32_ref 64) [64, bytes: 256]
# res_block2_6/res_block2_6_bn3/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block2_6/res_block2_6_bn3/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block2_6/Wconv3:0 (float32_ref 1x1x64x256) [16384, bytes: 65536]
# res_block2_6/bconv3:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_7/res_block2_7_bn1/batch_normalization/gamma:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_7/res_block2_7_bn1/batch_normalization/beta:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_7/Wconv1:0 (float32_ref 1x1x256x64) [16384, bytes: 65536]
# res_block2_7/bconv1:0 (float32_ref 64) [64, bytes: 256]
# res_block2_7/res_block2_7_bn2/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block2_7/res_block2_7_bn2/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block2_7/Wconv2:0 (float32_ref 3x3x64x64) [36864, bytes: 147456]
# res_block2_7/bconv2:0 (float32_ref 64) [64, bytes: 256]
# res_block2_7/res_block2_7_bn3/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block2_7/res_block2_7_bn3/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block2_7/Wconv3:0 (float32_ref 1x1x64x256) [16384, bytes: 65536]
# res_block2_7/bconv3:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_8/res_block2_8_bn1/batch_normalization/gamma:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_8/res_block2_8_bn1/batch_normalization/beta:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_8/Wconv1:0 (float32_ref 1x1x256x64) [16384, bytes: 65536]
# res_block2_8/bconv1:0 (float32_ref 64) [64, bytes: 256]
# res_block2_8/res_block2_8_bn2/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block2_8/res_block2_8_bn2/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block2_8/Wconv2:0 (float32_ref 3x3x64x64) [36864, bytes: 147456]
# res_block2_8/bconv2:0 (float32_ref 64) [64, bytes: 256]
# res_block2_8/res_block2_8_bn3/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block2_8/res_block2_8_bn3/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block2_8/Wconv3:0 (float32_ref 1x1x64x256) [16384, bytes: 65536]
# res_block2_8/bconv3:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_9/res_block2_9_bn1/batch_normalization/gamma:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_9/res_block2_9_bn1/batch_normalization/beta:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_9/Wconv1:0 (float32_ref 1x1x256x64) [16384, bytes: 65536]
# res_block2_9/bconv1:0 (float32_ref 64) [64, bytes: 256]
# res_block2_9/res_block2_9_bn2/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block2_9/res_block2_9_bn2/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block2_9/Wconv2:0 (float32_ref 3x3x64x64) [36864, bytes: 147456]
# res_block2_9/bconv2:0 (float32_ref 64) [64, bytes: 256]
# res_block2_9/res_block2_9_bn3/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block2_9/res_block2_9_bn3/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block2_9/Wconv3:0 (float32_ref 1x1x64x256) [16384, bytes: 65536]
# res_block2_9/bconv3:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_10/res_block2_10_bn1/batch_normalization/gamma:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_10/res_block2_10_bn1/batch_normalization/beta:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_10/Wconv1:0 (float32_ref 1x1x256x64) [16384, bytes: 65536]
# res_block2_10/bconv1:0 (float32_ref 64) [64, bytes: 256]
# res_block2_10/res_block2_10_bn2/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block2_10/res_block2_10_bn2/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block2_10/Wconv2:0 (float32_ref 3x3x64x64) [36864, bytes: 147456]
# res_block2_10/bconv2:0 (float32_ref 64) [64, bytes: 256]
# res_block2_10/res_block2_10_bn3/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block2_10/res_block2_10_bn3/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block2_10/Wconv3:0 (float32_ref 1x1x64x256) [16384, bytes: 65536]
# res_block2_10/bconv3:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_11/res_block2_11_bn1/batch_normalization/gamma:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_11/res_block2_11_bn1/batch_normalization/beta:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_11/Wconv1:0 (float32_ref 1x1x256x64) [16384, bytes: 65536]
# res_block2_11/bconv1:0 (float32_ref 64) [64, bytes: 256]
# res_block2_11/res_block2_11_bn2/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block2_11/res_block2_11_bn2/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block2_11/Wconv2:0 (float32_ref 3x3x64x64) [36864, bytes: 147456]
# res_block2_11/bconv2:0 (float32_ref 64) [64, bytes: 256]
# res_block2_11/res_block2_11_bn3/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block2_11/res_block2_11_bn3/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block2_11/Wconv3:0 (float32_ref 1x1x64x256) [16384, bytes: 65536]
# res_block2_11/bconv3:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_12/res_block2_12_bn1/batch_normalization/gamma:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_12/res_block2_12_bn1/batch_normalization/beta:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_12/Wconv1:0 (float32_ref 1x1x256x64) [16384, bytes: 65536]
# res_block2_12/bconv1:0 (float32_ref 64) [64, bytes: 256]
# res_block2_12/res_block2_12_bn2/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block2_12/res_block2_12_bn2/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block2_12/Wconv2:0 (float32_ref 3x3x64x64) [36864, bytes: 147456]
# res_block2_12/bconv2:0 (float32_ref 64) [64, bytes: 256]
# res_block2_12/res_block2_12_bn3/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block2_12/res_block2_12_bn3/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block2_12/Wconv3:0 (float32_ref 1x1x64x256) [16384, bytes: 65536]
# res_block2_12/bconv3:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_13/res_block2_13_bn1/batch_normalization/gamma:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_13/res_block2_13_bn1/batch_normalization/beta:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_13/Wconv1:0 (float32_ref 1x1x256x64) [16384, bytes: 65536]
# res_block2_13/bconv1:0 (float32_ref 64) [64, bytes: 256]
# res_block2_13/res_block2_13_bn2/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block2_13/res_block2_13_bn2/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block2_13/Wconv2:0 (float32_ref 3x3x64x64) [36864, bytes: 147456]
# res_block2_13/bconv2:0 (float32_ref 64) [64, bytes: 256]
# res_block2_13/res_block2_13_bn3/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block2_13/res_block2_13_bn3/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block2_13/Wconv3:0 (float32_ref 1x1x64x256) [16384, bytes: 65536]
# res_block2_13/bconv3:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_14/res_block2_14_bn1/batch_normalization/gamma:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_14/res_block2_14_bn1/batch_normalization/beta:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_14/Wconv1:0 (float32_ref 1x1x256x64) [16384, bytes: 65536]
# res_block2_14/bconv1:0 (float32_ref 64) [64, bytes: 256]
# res_block2_14/res_block2_14_bn2/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block2_14/res_block2_14_bn2/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block2_14/Wconv2:0 (float32_ref 3x3x64x64) [36864, bytes: 147456]
# res_block2_14/bconv2:0 (float32_ref 64) [64, bytes: 256]
# res_block2_14/res_block2_14_bn3/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block2_14/res_block2_14_bn3/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block2_14/Wconv3:0 (float32_ref 1x1x64x256) [16384, bytes: 65536]
# res_block2_14/bconv3:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_15/res_block2_15_bn1/batch_normalization/gamma:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_15/res_block2_15_bn1/batch_normalization/beta:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_15/Wconv1:0 (float32_ref 1x1x256x64) [16384, bytes: 65536]
# res_block2_15/bconv1:0 (float32_ref 64) [64, bytes: 256]
# res_block2_15/res_block2_15_bn2/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block2_15/res_block2_15_bn2/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block2_15/Wconv2:0 (float32_ref 3x3x64x64) [36864, bytes: 147456]
# res_block2_15/bconv2:0 (float32_ref 64) [64, bytes: 256]
# res_block2_15/res_block2_15_bn3/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block2_15/res_block2_15_bn3/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block2_15/Wconv3:0 (float32_ref 1x1x64x256) [16384, bytes: 65536]
# res_block2_15/bconv3:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_16/res_block2_16_bn1/batch_normalization/gamma:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_16/res_block2_16_bn1/batch_normalization/beta:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_16/Wconv1:0 (float32_ref 1x1x256x64) [16384, bytes: 65536]
# res_block2_16/bconv1:0 (float32_ref 64) [64, bytes: 256]
# res_block2_16/res_block2_16_bn2/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block2_16/res_block2_16_bn2/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block2_16/Wconv2:0 (float32_ref 3x3x64x64) [36864, bytes: 147456]
# res_block2_16/bconv2:0 (float32_ref 64) [64, bytes: 256]
# res_block2_16/res_block2_16_bn3/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block2_16/res_block2_16_bn3/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block2_16/Wconv3:0 (float32_ref 1x1x64x256) [16384, bytes: 65536]
# res_block2_16/bconv3:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_17/res_block2_17_bn1/batch_normalization/gamma:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_17/res_block2_17_bn1/batch_normalization/beta:0 (float32_ref 256) [256, bytes: 1024]
# res_block2_17/Wconv1:0 (float32_ref 1x1x256x64) [16384, bytes: 65536]
# res_block2_17/bconv1:0 (float32_ref 64) [64, bytes: 256]
# res_block2_17/res_block2_17_bn2/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block2_17/res_block2_17_bn2/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block2_17/Wconv2:0 (float32_ref 3x3x64x64) [36864, bytes: 147456]
# res_block2_17/bconv2:0 (float32_ref 64) [64, bytes: 256]
# res_block2_17/res_block2_17_bn3/batch_normalization/gamma:0 (float32_ref 64) [64, bytes: 256]
# res_block2_17/res_block2_17_bn3/batch_normalization/beta:0 (float32_ref 64) [64, bytes: 256]
# res_block2_17/Wconv3:0 (float32_ref 1x1x64x256) [16384, bytes: 65536]
# res_block2_17/bconv3:0 (float32_ref 256) [256, bytes: 1024]
# global_bn1/batch_normalization/gamma:0 (float32_ref 256) [256, bytes: 1024]
# global_bn1/batch_normalization/beta:0 (float32_ref 256) [256, bytes: 1024]
# dense_layer_1/W1:0 (float32_ref 256x10) [2560, bytes: 10240]
# dense_layer_1/b1:0 (float32_ref 10) [10, bytes: 40]
# Total size of variables: 1715818
# Total bytes of variables: 6863272

# %%
# создаём сессию. Сессия -- это среда, в которой выполняются вычисления
with tf.Session() as sess:
        
    #мы можем явно указать устройство
    with tf.device("/gpu:0"): #"/cpu:0" or "/gpu:0" 
        #инициализируем веса, в этот момент происходит выделение памяти
        sess.run(tf.global_variables_initializer())
        
        #запускаем тренировку
        training_loop(sess, model_inputs=(x,y,is_training, l2_reg, learning_rate), 
                      model_outputs=(y_out, mean_loss, accuracy), 
                      train_step=train_step, epochs=300)
# Out:
# Epoch 0:
# train loss: 0.212, val loss: 0.214, accuracy: 0.348, lr: 0.0001
# Epoch 1:
# train loss: 0.188, val loss: 0.181, accuracy: 0.516, lr: 9.990143508e-05
# Epoch 2:
# train loss: 0.16, val loss: 0.15, accuracy: 0.625, lr: 9.960612933e-05
# Epoch 3:
# train loss: 0.144, val loss: 0.156, accuracy: 0.625, lr: 9.911524817e-05
# Epoch 4:
# train loss: 0.128, val loss: 0.184, accuracy: 0.582, lr: 9.84307289e-05
# Epoch 5:
# train loss: 0.112, val loss: 0.121, accuracy: 0.742, lr: 9.755527299e-05
# Epoch 6:
# train loss: 0.0979, val loss: 0.13, accuracy: 0.719, lr: 9.649233547e-05
# Epoch 7:
# train loss: 0.0877, val loss: 0.122, accuracy: 0.745, lr: 9.524611127e-05
# Epoch 8:
# train loss: 0.0784, val loss: 0.12, accuracy: 0.749, lr: 9.382151867e-05
# Epoch 9:
# train loss: 0.0717, val loss: 0.116, accuracy: 0.753, lr: 9.222417988e-05
# Epoch 10:
# train loss: 0.0656, val loss: 0.111, accuracy: 0.758, lr: 9.046039887e-05
# Epoch 11:
# iteration 78, train loss: 0.0481, accuracy: 0.906

# %% [markdown]
# ### Make prediction on test set

# %%
def test_eval(session, model_input, model_output, x_test,y_test, batch_size = 64):
    
    x, y , is_training, l2_reg = model_input
    y_out = model_output

    #аналогично для теста
    index_test = np.arange(len(x_test))
    num_batches_test = int(len(index_test) / batch_size)
    batch_indexes_test = np.array_split(index_test, num_batches_test)
    
    y_pred = []

    for batch_index in batch_indexes_test:

        #Создаём словарь, осуществляющий сопоставление входов графа (plaseholders) и значений
        feed_dict = {x: x_test[batch_index],
                     y: y_test[batch_index],
                    is_training:False,
                    l2_reg : 0}

        #Здесь происходит непоследственный вызов модели

        y_pred_batch = session.run([y_out],feed_dict=feed_dict)

        y_pred.append(y_pred_batch[0])
        
    y_pred = np.concatenate(y_pred)
    y_pred = [np.argmax(x) for x in y_pred]
    return y_pred

with tf.Session() as sess:
    # Restore variables from disk.
    saver.restore(sess, "checkpoints/model_vgg16_v2.ckpt")
    y_pred = test_eval(sess,
                       model_input = (x, y , is_training, l2_reg),
                       model_output = y_out,
                       x_test = x_test, y_test = y_test)

# %%
to_file = np.stack([np.arange(len(y_pred)),y_pred]).T
np.savetxt("pred_vg16.txt",to_file,fmt='%.d',header='id,label',delimiter=",",comments="")
