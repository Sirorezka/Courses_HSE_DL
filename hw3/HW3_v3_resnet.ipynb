# %%
from sklearn.model_selection import train_test_split
import tensorflow as tf

import numpy as np
from keras.datasets import cifar10
from random import randrange
import time
import pickle

import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline
plt.rcParams['figure.figsize'] = (15, 12) # set default size of plots
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ### Load data

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

y_train = np.squeeze(y_train)
y_test = np.squeeze(y_test)

# %%
# print (x_train.shape)
# print (y_train.shape)

# all_aug_x = pickle.load(open('aug_image/x_images.p','rb'))
# all_aug_y = pickle.load(open('aug_image/y_images.p','rb'))


# x_train = np.concatenate([x_train,all_aug_x])
# y_train = np.concatenate([y_train,all_aug_y])

# print (x_train.shape)
# print (y_train.shape)

# %% [markdown]
# Визуализируем классы

# %%
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
num_classes = len(classes)
samples_per_class = 10
for y, cls in enumerate(classes):
    idxs = np.flatnonzero(y_train == y)
    idxs = np.random.choice(idxs, samples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt_idx = i * num_classes + y + 1
        plt.subplot(samples_per_class, num_classes, plt_idx)
        plt.imshow(x_train[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls)
plt.show()

# %%
# Preprocessing: вычитаем среднее
# 1: Находим среднее изображение
mean_image = np.mean(x_train, axis=0)
plt.figure(figsize=(4,4))
plt.imshow(mean_image.reshape((32,32,3)).astype('uint8')) # визуализируем полученное среднее
plt.show()

# %%
# 2: вычитаем среднее из изображений обучающей и тестовых выборок
x_train = x_train - mean_image
x_test = x_test - mean_image

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=1000,stratify=y_train)

# %% [markdown]
# Пожалуйста, ознакомьтесь с другими возможностями, которые предоставляет tf для описания модели.
#
# * Layers, Activations, Loss functions : https://www.tensorflow.org/api_guides/python/nn
# * Optimizers: https://www.tensorflow.org/api_guides/python/train#Optimizers
# * BatchNorm: https://www.tensorflow.org/api_docs/python/tf/layers/BatchNormalization

# %% [markdown]
# Теперь мы можем двигаться дальше и протестировать получившуюся модель. Для этого реализуем тренировочный цикл

# %% [markdown]
# Принимаются работы с точностью **не менее 84%**.
#
# Полезные ссылки:
#   - [ResNet](https://arxiv.org/abs/1512.03385).
#   - [DenseNet](https://arxiv.org/abs/1608.06993).
#   - [This blog has an in-depth overview](https://chatbotslife.com/resnets-highwaynets-and-densenets-oh-my-9bb15918ee32)

# %% [markdown]
# Напишите ваш код под текстом задания

# %% [markdown]
# ### My network

# %%
### For data augmentation
from keras.preprocessing.image import ImageDataGenerator

# %%
def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w
            r = np.random.uniform(r_1, r_2)
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img

    return eraser

# %%
import math

## https://gist.github.com/vertix/d2b1256003e9ffca8e7fc36ba1ba4eb3


def augment(images, labels,
            resize=None, # (width, height) tuple or None
            horizontal_flip=False,
            vertical_flip=False,
            rotate=0, # Maximum rotation angle in degrees
            crop_probability=0, # How often we do crops
            crop_min_percent=0.6, # Minimum linear dimension of a crop
            crop_max_percent=1.,  # Maximum linear dimension of a crop
            mixup=0):  # Mixup coeffecient, see https://arxiv.org/abs/1710.09412.pdf
  if resize is not None:
    images = tf.image.resize_bilinear(images, resize)
  
  # My experiments showed that casting on GPU improves training performance
  if images.dtype != tf.float32:
    images = tf.image.convert_image_dtype(images, dtype=tf.float32)
    images = tf.subtract(images, 0.5)
    images = tf.multiply(images, 2.0)
  labels = tf.to_float(labels)

  with tf.name_scope('augmentation'):
    shp = tf.shape(images)
    batch_size, height, width = shp[0], shp[1], shp[2]
    width = tf.cast(width, tf.float32)
    height = tf.cast(height, tf.float32)

    # The list of affine transformations that our image will go under.
    # Every element is Nx8 tensor, where N is a batch size.
    transforms = []
    identity = tf.constant([1, 0, 0, 0, 1, 0, 0, 0], dtype=tf.float32)
    if horizontal_flip:
      coin = tf.less(tf.random_uniform([batch_size], 0, 1.0), 0.5)
      flip_transform = tf.convert_to_tensor(
          [-1., 0., width, 0., 1., 0., 0., 0.], dtype=tf.float32)
      transforms.append(
          tf.where(coin,
                   tf.tile(tf.expand_dims(flip_transform, 0), [batch_size, 1]),
                   tf.tile(tf.expand_dims(identity, 0), [batch_size, 1])))

    if vertical_flip:
      coin = tf.less(tf.random_uniform([batch_size], 0, 1.0), 0.5)
      flip_transform = tf.convert_to_tensor(
          [1, 0, 0, 0, -1, height, 0, 0], dtype=tf.float32)
      transforms.append(
          tf.where(coin,
                   tf.tile(tf.expand_dims(flip_transform, 0), [batch_size, 1]),
                   tf.tile(tf.expand_dims(identity, 0), [batch_size, 1])))

    if rotate > 0:
      angle_rad = rotate / 180 * math.pi
      angles = tf.random_uniform([batch_size], -angle_rad, angle_rad)
      transforms.append(
          tf.contrib.image.angles_to_projective_transforms(
              angles, height, width))

    if crop_probability > 0:
      crop_pct = tf.random_uniform([batch_size], crop_min_percent,
                                   crop_max_percent)
      left = tf.random_uniform([batch_size], 0, width * (1 - crop_pct))
      top = tf.random_uniform([batch_size], 0, height * (1 - crop_pct))
      crop_transform = tf.stack([
          crop_pct,
          tf.zeros([batch_size]), top,
          tf.zeros([batch_size]), crop_pct, left,
          tf.zeros([batch_size]),
          tf.zeros([batch_size])
      ], 1)

      coin = tf.less(
          tf.random_uniform([batch_size], 0, 1.0), crop_probability)
      transforms.append(
          tf.where(coin, crop_transform,
                   tf.tile(tf.expand_dims(identity, 0), [batch_size, 1])))

    if transforms:
      images = tf.contrib.image.transform(
          images,
          tf.contrib.image.compose_transforms(*transforms),
          interpolation='BILINEAR') # or 'NEAREST'

    def cshift(values): # Circular shift in batch dimension
      return tf.concat([values[-1:, ...], values[:-1, ...]], 0)

    if mixup > 0:
      mixup = 1.0 * mixup # Convert to float, as tf.distributions.Beta requires floats.
      beta = tf.distributions.Beta(mixup, mixup)
      lam = beta.sample(batch_size)
      ll = tf.expand_dims(tf.expand_dims(tf.expand_dims(lam, -1), -1), -1)
      images = ll * images + (1 - ll) * cshift(images)
      labels = lam * labels + (1 - lam) * cshift(labels)

  return images, labels

# %%
## https://brandonlmorris.com/2018/06/30/wide-resnet-pytorch/
## https://github.com/meliketoy/wide-resnet.pytorch/blob/master/networks/wide_resnet.py
## https://github.com/tensorflow/models/blob/master/research/autoaugment/shake_drop.py#L4

def my_resnet_single(single_name, x, is_training, in_filters, out_filters, keep_prob, stride = 1  ):

    USE_L2_REG = 'L2_REG'
    
    with tf.variable_scope(single_name):
        
        ## BN - relu - conv2d - dropout - BN - relu - conv2d
        
        with tf.variable_scope(single_name+"_bn1"):
            x_res = tf.layers.batch_normalization(x, training=is_training)  
        x_res = tf.nn.relu(x_res)

        Wconv1 = tf.get_variable("Wconv1", shape=[3, 3, in_filters, out_filters])
        bconv1 = tf.get_variable("bconv1", shape=[out_filters])
        x_res = tf.nn.conv2d(x_res, Wconv1, strides=[1,stride,stride,1], padding='SAME') + bconv1

        
        x_res = tf.nn.dropout(x_res, keep_prob=keep_prob)
        
        with tf.variable_scope(single_name+"_bn2"):
            x_res = tf.layers.batch_normalization(x_res, training=is_training)  
            
        x_res = tf.nn.relu(x_res)
                
        Wconv2 = tf.get_variable("Wconv2", shape=[3, 3, out_filters, out_filters])
        bconv2 = tf.get_variable("bconv2", shape=[out_filters])
        x_res = tf.nn.conv2d(x_res, Wconv2, strides=[1,1,1,1], padding='SAME') + bconv2
        
        tf.add_to_collection(USE_L2_REG, Wconv1)
        tf.add_to_collection(USE_L2_REG, bconv1)
        
        tf.add_to_collection(USE_L2_REG, Wconv2)
        tf.add_to_collection(USE_L2_REG, bconv2)

    ## shortcut
    with tf.variable_scope(single_name+"_sc"): 
        
        ## shortcut
        if in_filters != out_filters or stride!=1:
            ## batch norm - relu - conv2d
            x_sc = tf.layers.batch_normalization(x, training=is_training)  
            x_sc = tf.nn.relu(x_sc)
            
            Wconv = tf.get_variable("Wconv", shape=[3, 3, in_filters, out_filters])
            bconv = tf.get_variable("bconv", shape=[out_filters])
            
            x_sc = tf.nn.conv2d(x_sc, Wconv, strides=[1,stride,stride,1], padding='SAME') + bconv
            
            tf.add_to_collection(USE_L2_REG, Wconv)
            tf.add_to_collection(USE_L2_REG, bconv)
            
        else:
            x_sc = x
            
    out = x_sc + x_res
    
    return out
    
def my_resnet_group(block_name, x, is_training, num_blocks, in_filters, out_filters, keep_prob, stride = 1):
    
    x_out = x
    
    strides = [stride] + [1]*(num_blocks-1)
    filters = [in_filters] + [out_filters]*(num_blocks-1)
        
    with tf.variable_scope(block_name):

        for i in range(num_blocks):
            x_out = my_resnet_single(block_name+"_"+str(i), x_out, is_training, filters[i], out_filters, keep_prob, stride = strides[i])
    
    return x_out
            


def my_WideResNet(n_grps = 3, N = 4, k = 10):
    
    x = tf.placeholder(tf.float32, [None, 32, 32, 3])
    y = tf.placeholder(tf.int64, [None])
    
    x, _ = augment(x, y,
            resize=None, # (width, height) tuple or None
            horizontal_flip=True,
            vertical_flip=True,
            rotate=15, # Maximum rotation angle in degrees
            crop_probability=0.1, # How often we do crops
            crop_min_percent=0.0, # Minimum linear dimension of a crop
            crop_max_percent=0.3,  # Maximum linear dimension of a crop
            mixup=0)
    
    is_training = tf.placeholder(tf.bool)
    l2_reg = tf.placeholder(tf.float32)

    USE_L2_REG = 'L2_REG' 
    
    ## ---  WideResNet 
    ##
    
    x_res = x
    
    with tf.variable_scope("res_start"):
        
        Wconv = tf.get_variable("Wconv", shape=[3, 3, 3, 16])
        bconv = tf.get_variable("bconv", shape=[16])
        x_res = tf.nn.conv2d(x_res, Wconv, strides=[1,1,1,1], padding='SAME') + bconv
        
        tf.add_to_collection(USE_L2_REG, Wconv)
        tf.add_to_collection(USE_L2_REG, bconv)   
        
    widths = [16]
    for i_grp in range(n_grps):
        widths.append(16*(2**i_grp)*k)
        ## [16, 16*k, 32*k, 64*k]
        
    for i in range(n_grps):
        x_res = my_resnet_group("res_block"+str(i), x_res, is_training, N, widths[i], widths[i+1], 
                                keep_prob = 0.7, stride = (1 if i == 0 else 2))
        
    print (x_res.shape)
        
    #добавляем полносвязный слой
    with tf.variable_scope("dense_layer_1"):
        
        x_res = tf.layers.batch_normalization(x_res, training=is_training)                    
        x_res = tf.nn.relu(x_res)
        
        size = 8*8*widths[n_grps]
        W1 = tf.get_variable("W1", shape=[size, 10])
        b1 = tf.get_variable("b1", shape=[10])
        
        x_res = tf.reshape(x_res,[-1,size])
        x_res = tf.matmul(x_res,W1) + b1  
        
        tf.add_to_collection(USE_L2_REG, W1)
        tf.add_to_collection(USE_L2_REG, b1)     
        
    y_out = x_res 
        
    ## l2 regularization
    L2_loss = tf.add_n([tf.nn.l2_loss(v) for v in tf.get_collection(USE_L2_REG)]) * l2_reg
        
    # y_out -- это вектор оценок, которые генерирует модель. Теперь определим функцию потерь
    total_loss = tf.losses.hinge_loss(tf.one_hot(y,10),logits=y_out)
    mean_loss = tf.reduce_mean(total_loss) + L2_loss
    
    correct_prediction = tf.equal(tf.argmax(y_out,1), y)
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    
    tf.summary.scalar('mean_loss', mean_loss)
    tf.summary.scalar('accuracy', accuracy)
            
    #Возвращаем те узлы графа, которые нам понадобятся в дальнейшем.
    #(x,y) это входы графа, а (y_out, mean_loss) выходы, которые представляют для нас интерес
    return (x,y,is_training,l2_reg), (y_out, mean_loss, accuracy)

# %%
def training_loop(session, model_inputs, model_outputs, train_step, 
                  epochs=10, batch_size=64):
    
    train_writer = tf.summary.FileWriter('tensorboard/train',session.graph)
    val_writer = tf.summary.FileWriter('tensorboard/val')

    #создаём индекс по всем объектам
    index = np.arange(len(x_train))
    
    #перемешиваем его
    np.random.shuffle(index)
    
    #разбиваем на батчи
    num_batches = int(len(index) / batch_size)
    batch_indexes = np.array_split(index, num_batches)
    
    #аналогично для теста
    index_test = np.arange(len(x_test))
    np.random.shuffle(index_test)
    num_batches_test = int(len(index_test) / batch_size)
    batch_indexes_test = np.array_split(index_test, num_batches_test)
    
    #аналогично для validation
    index_val = np.arange(len(x_val))
    np.random.shuffle(index_val)
    num_batches_val = int(len(index_val) / batch_size)
    batch_indexes_val = np.array_split(index_val, num_batches_val)
    
    x,y,is_training,l2_reg,learning_rate = model_inputs
    y_out, mean_loss, accuracy = model_outputs
    
    datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=15,  # randomly rotate images in the range (degrees, 0 to 180)
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=True,  # randomly flip images
        vertical_flip=True)  # randomly flip images
    
    eraser = get_random_eraser(p=0.3, v_l=0, v_h=1, s_l=0.02, s_h=0.4, pixel_level=True)
    
    def cosine_decay(learning_rate,global_step,decay_steps,alpha=0.0):
        global_step = min(global_step, decay_steps)
        cosine_decay = 0.5 * (1 + np.cos(np.pi * global_step / decay_steps))
        decayed = (1 - alpha) * cosine_decay + alpha
        decayed_learning_rate = learning_rate * decayed
        return decayed_learning_rate
    
    def train(x_values, y_values, batch_indexes, epoch):
        train_loses = []
        for i, batch_index in enumerate(batch_indexes):
            
#             lr = 0.0001/10**(epoch)
#             lr = cosine_decay(0.01,global_step = epoch % 50,decay_steps = 50, alpha = 0.001)
            lr = cosine_decay(0.0001,global_step = epoch % 50,decay_steps = 50, alpha = 0.01)

            #Создаём словарь, осуществляющий сопоставление входов графа (plaseholders) и значений
#             x_batch = [datagen.random_transform(img) for img in x_values[batch_index]]
                
            x_batch = [eraser(img) for img in x_values[batch_index]]
        
            feed_dict = {x: x_batch,
                         y: y_values[batch_index],
                        is_training:True,
                        l2_reg: 0.001,
                        learning_rate:lr}

            #Здесь происходит непоследственный вызов модели
            #Обратите внимание, что мы передаём 
                      
            summary, scores, loss, acc, _ = session.run([merged,y_out, mean_loss, accuracy, train_step],feed_dict=feed_dict)

            train_loses.append(loss)
            print(f'iteration {i}, train loss: {loss:.3}, accuracy: {acc:.3}', end='\r')
            
            train_writer.add_summary(summary, epoch * num_batches+i)

        return train_loses
        
    def evaluate(x_values, y_values, batch_indexes, epoch):
        test_loses = []
        test_accuracy = []

        for batch_index in batch_indexes:

            #Создаём словарь, осуществляющий сопоставление входов графа (plaseholders) и значений
            feed_dict = {x: x_values[batch_index],
                         y: y_values[batch_index],
                        is_training:False,
                        l2_reg : 0}
            
            #Здесь происходит непоследственный вызов модели
            
            summary, loss, acc = session.run([merged,mean_loss, accuracy],feed_dict=feed_dict)
                             
                
            test_loses.append(loss)
            test_accuracy.append(acc)

            # Create a new Summary object with your measure
            
        summary = tf.Summary()
        summary.value.add(tag="val_Accuracy", simple_value=np.mean(test_accuracy))
        summary.value.add(tag="val_Loses", simple_value=np.mean(test_loses))
        
        val_writer.add_summary(summary, epoch)

        return test_loses, test_accuracy
    
        
    # цикл по эпохам
    for e in range(epochs):
        print(f'Epoch {e}:')
        train_loses = train(x_train, y_train, batch_indexes, e)
        val_loses, val_accuracy = evaluate(x_val, y_val, batch_indexes_val, e)
        lr = cosine_decay(0.0001,global_step = e % 50,decay_steps = 50, alpha = 0.001)
        print(f'train loss: {np.mean(train_loses):.3}, val loss: {np.mean(val_loses):.3}, accuracy: {np.mean(val_accuracy):.3}, lr: {lr:.10}')
        
        save_path = saver.save(session, "checkpoints/model_resnet.ckpt")
        
        if e % 50 == 49:
            try:
                save_path = saver.save(session, "checkpoints/model_resnet_ep"+str(e)+".ckpt")
            except:
                pass
            
    print('================================================')
    print('Test set results:')
    test_loses, test_accuracy = evaluate(x_test, y_test, batch_indexes_test,e)
    print(f'test loss: {np.mean(test_loses):.3}, accuracy: {np.mean(test_accuracy):.3}')

# %%
#Перед вызовом функции очистим память от графов других моделей (актуально если вы вызываете эту ячейку повторно)
tf.reset_default_graph()
(x,y,is_training,l2_reg), (y_out, mean_loss, accuracy) = my_WideResNet(n_grps = 3, N = 4, k = 10)

merged = tf.summary.merge_all()
saver = tf.train.Saver()


#Теперь зададим алгоритм оптимизации
learning_rate = tf.placeholder(tf.float32, shape=[])
optimizer = tf.train.AdamOptimizer(learning_rate) 
#train_step -- специальный служебный узел в графе, отвечающий за обратный проход


update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
with tf.control_dependencies(update_ops):
    
    gvs = optimizer.compute_gradients(mean_loss)
    capped_gvs = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gvs]
    train_step = optimizer.apply_gradients(capped_gvs)

#     train_step = optimizer.minimize(mean_loss)
# Out:
# (?, 8, 8, 640)

# %%
# создаём сессию. Сессия -- это среда, в которой выполняются вычисления
with tf.Session() as sess:
        
    #мы можем явно указать устройство
    with tf.device("/gpu:0"): #"/cpu:0" or "/gpu:0" 
        #инициализируем веса, в этот момент происходит выделение памяти
        sess.run(tf.global_variables_initializer())
        
        #запускаем тренировку
        training_loop(sess, model_inputs=(x,y,is_training, l2_reg, learning_rate), 
                      model_outputs=(y_out, mean_loss, accuracy), 
                      train_step=train_step, epochs=300)
# Out:
# Epoch 0:
# train loss: 3.51, val loss: 0.22, accuracy: 0.399, lr: 0.0001
# Epoch 1:
# train loss: 1.41, val loss: 1.53, accuracy: 0.339, lr: 9.990143508e-05
# Epoch 2:
# train loss: 0.681, val loss: 0.224, accuracy: 0.438, lr: 9.960612933e-05
# Epoch 3:
# train loss: 0.437, val loss: 0.234, accuracy: 0.486, lr: 9.911524817e-05
# Epoch 4:
# train loss: 0.334, val loss: 0.217, accuracy: 0.496, lr: 9.84307289e-05
# Epoch 5:
# train loss: 0.28, val loss: 0.182, accuracy: 0.595, lr: 9.755527299e-05
# Epoch 6:
# train loss: 0.24, val loss: 0.156, accuracy: 0.686, lr: 9.649233547e-05
# Epoch 7:
# train loss: 0.223, val loss: 0.164, accuracy: 0.631, lr: 9.524611127e-05
# Epoch 8:
# train loss: 0.198, val loss: 0.174, accuracy: 0.633, lr: 9.382151867e-05
# Epoch 9:
# train loss: 0.184, val loss: 0.151, accuracy: 0.694, lr: 9.222417988e-05
# Epoch 10:
# train loss: 0.171, val loss: 0.139, accuracy: 0.708, lr: 9.046039887e-05
# Epoch 11:
# train loss: 0.162, val loss: 0.155, accuracy: 0.677, lr: 8.853713648e-05
# Epoch 12:
# train loss: 0.152, val loss: 0.132, accuracy: 0.737, lr: 8.646198294e-05
# Epoch 13:
# train loss: 0.146, val loss: 0.126, accuracy: 0.744, lr: 8.424312794e-05
# Epoch 14:
# train loss: 0.14, val loss: 0.138, accuracy: 0.746, lr: 8.188932829e-05
# Epoch 15:
# train loss: 0.133, val loss: 0.198, accuracy: 0.643, lr: 7.940987335e-05
# Epoch 16:
# train loss: 0.128, val loss: 0.142, accuracy: 0.7, lr: 7.681454841e-05
# Epoch 17:
# train loss: 0.123, val loss: 0.14, accuracy: 0.726, lr: 7.411359602e-05
# Epoch 18:
# train loss: 0.118, val loss: 0.158, accuracy: 0.701, lr: 7.131767561e-05
# Epoch 19:
# train loss: 0.113, val loss: 0.166, accuracy: 0.667, lr: 6.843782141e-05
# Epoch 20:
# train loss: 0.109, val loss: 0.124, accuracy: 0.741, lr: 6.548539887e-05
# Epoch 21:
# train loss: 0.104, val loss: 0.0961, accuracy: 0.801, lr: 6.247205986e-05
# Epoch 22:
# train loss: 0.1, val loss: 0.0981, accuracy: 0.811, lr: 5.940969666e-05
# Epoch 23:
# train loss: 0.0952, val loss: 0.0995, accuracy: 0.81, lr: 5.631039502e-05
# Epoch 24:
# train loss: 0.0911, val loss: 0.133, accuracy: 0.746, lr: 5.318638645e-05
# Epoch 25:
# train loss: 0.0868, val loss: 0.105, accuracy: 0.796, lr: 5.005e-05
# Epoch 26:
# train loss: 0.082, val loss: 0.158, accuracy: 0.705, lr: 4.691361355e-05
# Epoch 27:
# train loss: 0.0789, val loss: 0.0976, accuracy: 0.819, lr: 4.378960498e-05
# Epoch 28:
# train loss: 0.0752, val loss: 0.118, accuracy: 0.768, lr: 4.069030334e-05
# Epoch 29:
# train loss: 0.0718, val loss: 0.151, accuracy: 0.734, lr: 3.762794014e-05
# Epoch 30:
# train loss: 0.068, val loss: 0.0919, accuracy: 0.83, lr: 3.461460113e-05
# Epoch 31:
# train loss: 0.0643, val loss: 0.0775, accuracy: 0.857, lr: 3.166217859e-05
# Epoch 32:
# train loss: 0.0612, val loss: 0.0952, accuracy: 0.824, lr: 2.878232439e-05
# Epoch 33:
# train loss: 0.0579, val loss: 0.0909, accuracy: 0.83, lr: 2.598640398e-05
# Epoch 34:
# train loss: 0.0557, val loss: 0.0785, accuracy: 0.853, lr: 2.328545159e-05
# Epoch 35:
# train loss: 0.0535, val loss: 0.0782, accuracy: 0.858, lr: 2.069012665e-05
# Epoch 36:
# train loss: 0.0505, val loss: 0.0846, accuracy: 0.844, lr: 1.821067171e-05
# Epoch 37:
# train loss: 0.0487, val loss: 0.111, accuracy: 0.804, lr: 1.585687206e-05
# Epoch 38:
# train loss: 0.0471, val loss: 0.0681, accuracy: 0.876, lr: 1.363801706e-05
# Epoch 39:
# train loss: 0.0447, val loss: 0.0713, accuracy: 0.868, lr: 1.156286352e-05
# Epoch 40:
# train loss: 0.043, val loss: 0.0763, accuracy: 0.858, lr: 9.639601131e-06
# Epoch 41:
# train loss: 0.0417, val loss: 0.0652, accuracy: 0.884, lr: 7.875820121e-06
# Epoch 42:
# train loss: 0.0408, val loss: 0.0577, accuracy: 0.886, lr: 6.278481332e-06
# Epoch 43:
# train loss: 0.0396, val loss: 0.0596, accuracy: 0.883, lr: 4.853888729e-06
# Epoch 44:
# train loss: 0.0385, val loss: 0.0639, accuracy: 0.883, lr: 3.60766453e-06
# Epoch 45:
# train loss: 0.0377, val loss: 0.0588, accuracy: 0.884, lr: 2.544727011e-06
# Epoch 46:
# train loss: 0.0371, val loss: 0.0573, accuracy: 0.894, lr: 1.669271102e-06
# Epoch 47:
# train loss: 0.0366, val loss: 0.059, accuracy: 0.88, lr: 9.847518261e-07
# Epoch 48:
# train loss: 0.0366, val loss: 0.0573, accuracy: 0.886, lr: 4.938706693e-07
# Epoch 49:
# train loss: 0.0363, val loss: 0.0593, accuracy: 0.884, lr: 1.98564915e-07
# Epoch 50:
# train loss: 0.136, val loss: 0.163, accuracy: 0.697, lr: 0.0001
# Epoch 51:
# train loss: 0.117, val loss: 0.147, accuracy: 0.732, lr: 9.990143508e-05
# Epoch 52:
# train loss: 0.113, val loss: 0.196, accuracy: 0.683, lr: 9.960612933e-05
# Epoch 53:
# train loss: 0.111, val loss: 0.127, accuracy: 0.762, lr: 9.911524817e-05
# Epoch 54:
# train loss: 0.109, val loss: 0.183, accuracy: 0.676, lr: 9.84307289e-05
# Epoch 55:
# train loss: 0.109, val loss: 0.162, accuracy: 0.73, lr: 9.755527299e-05
# Epoch 56:
# train loss: 0.105, val loss: 0.152, accuracy: 0.73, lr: 9.649233547e-05
# Epoch 57:
# train loss: 0.104, val loss: 0.151, accuracy: 0.702, lr: 9.524611127e-05
# Epoch 58:
# train loss: 0.103, val loss: 0.165, accuracy: 0.735, lr: 9.382151867e-05
# Epoch 59:
# train loss: 0.101, val loss: 0.133, accuracy: 0.765, lr: 9.222417988e-05
# Epoch 60:
# train loss: 0.0983, val loss: 0.101, accuracy: 0.807, lr: 9.046039887e-05
# Epoch 61:
# train loss: 0.0971, val loss: 0.148, accuracy: 0.741, lr: 8.853713648e-05
# Epoch 62:
# train loss: 0.0943, val loss: 0.102, accuracy: 0.811, lr: 8.646198294e-05
# Epoch 63:
# train loss: 0.0913, val loss: 0.166, accuracy: 0.699, lr: 8.424312794e-05
# Epoch 64:
# train loss: 0.0886, val loss: 0.158, accuracy: 0.733, lr: 8.188932829e-05
# Epoch 65:
# train loss: 0.086, val loss: 0.1, accuracy: 0.811, lr: 7.940987335e-05
# Epoch 66:
# train loss: 0.084, val loss: 0.155, accuracy: 0.744, lr: 7.681454841e-05
# Epoch 67:
# train loss: 0.0818, val loss: 0.125, accuracy: 0.764, lr: 7.411359602e-05
# Epoch 68:
# train loss: 0.0785, val loss: 0.104, accuracy: 0.804, lr: 7.131767561e-05
# Epoch 69:
# train loss: 0.076, val loss: 0.112, accuracy: 0.801, lr: 6.843782141e-05
# Epoch 70:
# train loss: 0.0725, val loss: 0.121, accuracy: 0.771, lr: 6.548539887e-05
# Epoch 71:
# train loss: 0.0698, val loss: 0.153, accuracy: 0.745, lr: 6.247205986e-05
# Epoch 72:
# train loss: 0.0674, val loss: 0.118, accuracy: 0.791, lr: 5.940969666e-05
# Epoch 73:
# train loss: 0.0646, val loss: 0.162, accuracy: 0.738, lr: 5.631039502e-05
# Epoch 74:
# train loss: 0.0626, val loss: 0.0992, accuracy: 0.81, lr: 5.318638645e-05
# Epoch 75:
# train loss: 0.0597, val loss: 0.102, accuracy: 0.807, lr: 5.005e-05
# Epoch 76:
# train loss: 0.0572, val loss: 0.127, accuracy: 0.777, lr: 4.691361355e-05
# Epoch 77:
# train loss: 0.0552, val loss: 0.0947, accuracy: 0.838, lr: 4.378960498e-05
# Epoch 78:
# train loss: 0.0528, val loss: 0.094, accuracy: 0.827, lr: 4.069030334e-05
# Epoch 79:
# train loss: 0.0504, val loss: 0.0969, accuracy: 0.811, lr: 3.762794014e-05
# Epoch 80:
# train loss: 0.0486, val loss: 0.0963, accuracy: 0.814, lr: 3.461460113e-05
# Epoch 81:
# train loss: 0.0462, val loss: 0.0853, accuracy: 0.847, lr: 3.166217859e-05
# Epoch 82:
# train loss: 0.0441, val loss: 0.0972, accuracy: 0.819, lr: 2.878232439e-05
# Epoch 83:
# train loss: 0.0428, val loss: 0.0852, accuracy: 0.842, lr: 2.598640398e-05
# Epoch 84:
# train loss: 0.0407, val loss: 0.0938, accuracy: 0.835, lr: 2.328545159e-05
# Epoch 85:
# train loss: 0.039, val loss: 0.0785, accuracy: 0.856, lr: 2.069012665e-05
# Epoch 86:
# train loss: 0.0375, val loss: 0.0734, accuracy: 0.863, lr: 1.821067171e-05
# Epoch 87:
# train loss: 0.0362, val loss: 0.0733, accuracy: 0.871, lr: 1.585687206e-05
# Epoch 88:
# train loss: 0.0349, val loss: 0.0725, accuracy: 0.862, lr: 1.363801706e-05
# Epoch 89:
# train loss: 0.0341, val loss: 0.0632, accuracy: 0.879, lr: 1.156286352e-05
# Epoch 90:
# train loss: 0.0327, val loss: 0.0615, accuracy: 0.892, lr: 9.639601131e-06
# Epoch 91:
# train loss: 0.032, val loss: 0.0649, accuracy: 0.884, lr: 7.875820121e-06
# Epoch 92:
# train loss: 0.0313, val loss: 0.0579, accuracy: 0.891, lr: 6.278481332e-06
# Epoch 93:
# train loss: 0.0304, val loss: 0.0541, accuracy: 0.898, lr: 4.853888729e-06
# Epoch 94:
# train loss: 0.0297, val loss: 0.057, accuracy: 0.888, lr: 3.60766453e-06
# Epoch 95:
# train loss: 0.0295, val loss: 0.0551, accuracy: 0.891, lr: 2.544727011e-06
# Epoch 96:
# train loss: 0.0291, val loss: 0.0547, accuracy: 0.889, lr: 1.669271102e-06
# Epoch 97:
# train loss: 0.0286, val loss: 0.0527, accuracy: 0.897, lr: 9.847518261e-07
# Epoch 98:
# train loss: 0.0284, val loss: 0.0555, accuracy: 0.893, lr: 4.938706693e-07
# Epoch 99:
# train loss: 0.0286, val loss: 0.0544, accuracy: 0.893, lr: 1.98564915e-07
# Epoch 100:
# train loss: 0.107, val loss: 0.138, accuracy: 0.729, lr: 0.0001
# Epoch 101:
# train loss: 0.0842, val loss: 0.103, accuracy: 0.796, lr: 9.990143508e-05
# Epoch 102:
# train loss: 0.0797, val loss: 0.134, accuracy: 0.75, lr: 9.960612933e-05
# Epoch 103:
# train loss: 0.0791, val loss: 0.122, accuracy: 0.775, lr: 9.911524817e-05
# Epoch 104:
# train loss: 0.0797, val loss: 0.145, accuracy: 0.708, lr: 9.84307289e-05
# Epoch 105:
# train loss: 0.0788, val loss: 0.127, accuracy: 0.772, lr: 9.755527299e-05
# Epoch 106:
# train loss: 0.0774, val loss: 0.108, accuracy: 0.801, lr: 9.649233547e-05
# Epoch 107:
# train loss: 0.0769, val loss: 0.113, accuracy: 0.795, lr: 9.524611127e-05
# Epoch 108:
# train loss: 0.0762, val loss: 0.101, accuracy: 0.821, lr: 9.382151867e-05
# Epoch 109:
# train loss: 0.0747, val loss: 0.115, accuracy: 0.801, lr: 9.222417988e-05
# Epoch 110:
# train loss: 0.0736, val loss: 0.11, accuracy: 0.811, lr: 9.046039887e-05
# Epoch 111:
# train loss: 0.0722, val loss: 0.105, accuracy: 0.814, lr: 8.853713648e-05
# Epoch 112:
# train loss: 0.0703, val loss: 0.11, accuracy: 0.788, lr: 8.646198294e-05
# Epoch 113:
# train loss: 0.0695, val loss: 0.105, accuracy: 0.804, lr: 8.424312794e-05
# Epoch 114:
# train loss: 0.0671, val loss: 0.095, accuracy: 0.826, lr: 8.188932829e-05
# Epoch 115:
# train loss: 0.0655, val loss: 0.106, accuracy: 0.811, lr: 7.940987335e-05
# Epoch 116:
# train loss: 0.064, val loss: 0.128, accuracy: 0.79, lr: 7.681454841e-05
# Epoch 117:
# train loss: 0.0623, val loss: 0.117, accuracy: 0.784, lr: 7.411359602e-05
# Epoch 118:
# train loss: 0.0598, val loss: 0.0899, accuracy: 0.833, lr: 7.131767561e-05
# Epoch 119:
# train loss: 0.0589, val loss: 0.096, accuracy: 0.825, lr: 6.843782141e-05
# Epoch 120:
# train loss: 0.0568, val loss: 0.098, accuracy: 0.822, lr: 6.548539887e-05
# Epoch 121:
# train loss: 0.0552, val loss: 0.103, accuracy: 0.821, lr: 6.247205986e-05
# Epoch 122:
# train loss: 0.0534, val loss: 0.102, accuracy: 0.812, lr: 5.940969666e-05
# Epoch 123:
# train loss: 0.0518, val loss: 0.0988, accuracy: 0.814, lr: 5.631039502e-05
# Epoch 124:
# train loss: 0.0497, val loss: 0.0936, accuracy: 0.828, lr: 5.318638645e-05
# Epoch 125:
# train loss: 0.0481, val loss: 0.0824, accuracy: 0.843, lr: 5.005e-05
# Epoch 126:
# train loss: 0.0463, val loss: 0.0743, accuracy: 0.861, lr: 4.691361355e-05
# Epoch 127:
# train loss: 0.0443, val loss: 0.0906, accuracy: 0.827, lr: 4.378960498e-05
# Epoch 128:
# train loss: 0.0434, val loss: 0.0799, accuracy: 0.853, lr: 4.069030334e-05
# Epoch 129:
# train loss: 0.0414, val loss: 0.089, accuracy: 0.834, lr: 3.762794014e-05
# Epoch 130:
# train loss: 0.0399, val loss: 0.0737, accuracy: 0.862, lr: 3.461460113e-05
# Epoch 131:
# train loss: 0.0386, val loss: 0.0868, accuracy: 0.845, lr: 3.166217859e-05
# Epoch 132:
# train loss: 0.0371, val loss: 0.0856, accuracy: 0.834, lr: 2.878232439e-05
# Epoch 133:
# train loss: 0.0353, val loss: 0.0871, accuracy: 0.842, lr: 2.598640398e-05
# Epoch 134:
# train loss: 0.0342, val loss: 0.0728, accuracy: 0.865, lr: 2.328545159e-05
# Epoch 135:
# train loss: 0.0328, val loss: 0.0878, accuracy: 0.832, lr: 2.069012665e-05
# Epoch 136:
# train loss: 0.0318, val loss: 0.0744, accuracy: 0.872, lr: 1.821067171e-05
# Epoch 137:
# train loss: 0.0309, val loss: 0.0732, accuracy: 0.863, lr: 1.585687206e-05
# Epoch 138:
# train loss: 0.0299, val loss: 0.0705, accuracy: 0.872, lr: 1.363801706e-05
# Epoch 139:
# train loss: 0.0292, val loss: 0.0575, accuracy: 0.896, lr: 1.156286352e-05
# Epoch 140:
# train loss: 0.0282, val loss: 0.058, accuracy: 0.894, lr: 9.639601131e-06
# Epoch 141:
# train loss: 0.0277, val loss: 0.0615, accuracy: 0.89, lr: 7.875820121e-06
# Epoch 142:
# train loss: 0.0268, val loss: 0.0553, accuracy: 0.897, lr: 6.278481332e-06
# Epoch 143:
# train loss: 0.0264, val loss: 0.0558, accuracy: 0.891, lr: 4.853888729e-06
# Epoch 144:
# train loss: 0.0261, val loss: 0.0556, accuracy: 0.889, lr: 3.60766453e-06
# Epoch 145:
# train loss: 0.0257, val loss: 0.0559, accuracy: 0.895, lr: 2.544727011e-06
# Epoch 146:
# train loss: 0.0254, val loss: 0.0561, accuracy: 0.897, lr: 1.669271102e-06
# Epoch 147:
# train loss: 0.0252, val loss: 0.055, accuracy: 0.898, lr: 9.847518261e-07
# Epoch 148:
# train loss: 0.0251, val loss: 0.0537, accuracy: 0.898, lr: 4.938706693e-07
# Epoch 149:
# train loss: 0.0249, val loss: 0.0545, accuracy: 0.895, lr: 1.98564915e-07
# Epoch 150:
# train loss: 0.0885, val loss: 0.13, accuracy: 0.758, lr: 0.0001
# Epoch 151:
# train loss: 0.069, val loss: 0.119, accuracy: 0.793, lr: 9.990143508e-05
# Epoch 152:
# train loss: 0.066, val loss: 0.14, accuracy: 0.745, lr: 9.960612933e-05
# Epoch 153:
# train loss: 0.0661, val loss: 0.242, accuracy: 0.624, lr: 9.911524817e-05
# Epoch 154:
# train loss: 0.0649, val loss: 0.104, accuracy: 0.818, lr: 9.84307289e-05
# Epoch 155:
# train loss: 0.0652, val loss: 0.136, accuracy: 0.775, lr: 9.755527299e-05
# Epoch 156:
# train loss: 0.0657, val loss: 0.0948, accuracy: 0.817, lr: 9.649233547e-05
# Epoch 157:
# train loss: 0.0648, val loss: 0.101, accuracy: 0.811, lr: 9.524611127e-05
# Epoch 158:
# train loss: 0.0651, val loss: 0.139, accuracy: 0.752, lr: 9.382151867e-05
# Epoch 159:
# train loss: 0.0635, val loss: 0.11, accuracy: 0.801, lr: 9.222417988e-05
# Epoch 160:
# train loss: 0.0632, val loss: 0.0895, accuracy: 0.839, lr: 9.046039887e-05
# Epoch 161:
# train loss: 0.0614, val loss: 0.106, accuracy: 0.807, lr: 8.853713648e-05
# Epoch 162:
# train loss: 0.0616, val loss: 0.082, accuracy: 0.851, lr: 8.646198294e-05
# Epoch 163:
# train loss: 0.0595, val loss: 0.117, accuracy: 0.796, lr: 8.424312794e-05
# Epoch 164:
# train loss: 0.0589, val loss: 0.1, accuracy: 0.816, lr: 8.188932829e-05
# Epoch 165:
# train loss: 0.0583, val loss: 0.0911, accuracy: 0.832, lr: 7.940987335e-05
# Epoch 166:
# train loss: 0.057, val loss: 0.0973, accuracy: 0.82, lr: 7.681454841e-05
# Epoch 167:
# train loss: 0.0549, val loss: 0.0924, accuracy: 0.828, lr: 7.411359602e-05
# Epoch 168:
# train loss: 0.0535, val loss: 0.102, accuracy: 0.826, lr: 7.131767561e-05
# Epoch 169:
# train loss: 0.0524, val loss: 0.106, accuracy: 0.811, lr: 6.843782141e-05
# Epoch 170:
# train loss: 0.0506, val loss: 0.103, accuracy: 0.816, lr: 6.548539887e-05
# Epoch 171:
# train loss: 0.0493, val loss: 0.106, accuracy: 0.82, lr: 6.247205986e-05
# Epoch 172:
# train loss: 0.0474, val loss: 0.122, accuracy: 0.792, lr: 5.940969666e-05
# Epoch 173:
# train loss: 0.0469, val loss: 0.11, accuracy: 0.805, lr: 5.631039502e-05
# Epoch 174:
# train loss: 0.0447, val loss: 0.0928, accuracy: 0.847, lr: 5.318638645e-05
# Epoch 175:
# train loss: 0.0433, val loss: 0.077, accuracy: 0.857, lr: 5.005e-05
# Epoch 176:
# train loss: 0.0419, val loss: 0.0788, accuracy: 0.855, lr: 4.691361355e-05
# Epoch 177:
# train loss: 0.0404, val loss: 0.0801, accuracy: 0.856, lr: 4.378960498e-05
# Epoch 178:
# train loss: 0.0388, val loss: 0.0911, accuracy: 0.85, lr: 4.069030334e-05
# Epoch 179:
# train loss: 0.0373, val loss: 0.0655, accuracy: 0.876, lr: 3.762794014e-05
# Epoch 180:
# train loss: 0.0367, val loss: 0.0696, accuracy: 0.868, lr: 3.461460113e-05
# Epoch 181:
# train loss: 0.0349, val loss: 0.082, accuracy: 0.85, lr: 3.166217859e-05
# Epoch 182:
# train loss: 0.0335, val loss: 0.0764, accuracy: 0.852, lr: 2.878232439e-05
# Epoch 183:
# train loss: 0.0326, val loss: 0.0831, accuracy: 0.835, lr: 2.598640398e-05
# Epoch 184:
# train loss: 0.0313, val loss: 0.0819, accuracy: 0.851, lr: 2.328545159e-05
# Epoch 185:
# train loss: 0.0302, val loss: 0.0651, accuracy: 0.876, lr: 2.069012665e-05
# Epoch 186:
# train loss: 0.0295, val loss: 0.0693, accuracy: 0.869, lr: 1.821067171e-05
# Epoch 187:
# train loss: 0.0283, val loss: 0.061, accuracy: 0.887, lr: 1.585687206e-05
# Epoch 188:
# train loss: 0.0275, val loss: 0.06, accuracy: 0.89, lr: 1.363801706e-05
# Epoch 189:
# train loss: 0.0268, val loss: 0.059, accuracy: 0.885, lr: 1.156286352e-05
# Epoch 190:
# train loss: 0.026, val loss: 0.0586, accuracy: 0.892, lr: 9.639601131e-06
# Epoch 191:
# train loss: 0.0255, val loss: 0.0586, accuracy: 0.889, lr: 7.875820121e-06
# Epoch 192:
# train loss: 0.0251, val loss: 0.0565, accuracy: 0.882, lr: 6.278481332e-06
# Epoch 193:
# train loss: 0.0247, val loss: 0.0544, accuracy: 0.888, lr: 4.853888729e-06
# Epoch 194:
# train loss: 0.0242, val loss: 0.0525, accuracy: 0.898, lr: 3.60766453e-06
# Epoch 195:
# train loss: 0.0239, val loss: 0.0526, accuracy: 0.896, lr: 2.544727011e-06
# Epoch 196:
# train loss: 0.0236, val loss: 0.0505, accuracy: 0.903, lr: 1.669271102e-06
# Epoch 197:
# train loss: 0.0236, val loss: 0.0518, accuracy: 0.893, lr: 9.847518261e-07
# Epoch 198:
# train loss: 0.0234, val loss: 0.0485, accuracy: 0.909, lr: 4.938706693e-07
# Epoch 199:
# train loss: 0.0234, val loss: 0.0509, accuracy: 0.906, lr: 1.98564915e-07
# Epoch 200:
# train loss: 0.0819, val loss: 0.106, accuracy: 0.815, lr: 0.0001
# Epoch 201:
# train loss: 0.0617, val loss: 0.109, accuracy: 0.786, lr: 9.990143508e-05
# Epoch 202:
# train loss: 0.0596, val loss: 0.12, accuracy: 0.793, lr: 9.960612933e-05
# Epoch 203:
# train loss: 0.0585, val loss: 0.0894, accuracy: 0.842, lr: 9.911524817e-05
# Epoch 204:
# train loss: 0.0596, val loss: 0.104, accuracy: 0.8, lr: 9.84307289e-05
# Epoch 205:
# train loss: 0.0599, val loss: 0.0886, accuracy: 0.837, lr: 9.755527299e-05
# Epoch 206:
# train loss: 0.0598, val loss: 0.117, accuracy: 0.806, lr: 9.649233547e-05
# Epoch 207:
# train loss: 0.0589, val loss: 0.103, accuracy: 0.828, lr: 9.524611127e-05
# Epoch 208:
# train loss: 0.0596, val loss: 0.113, accuracy: 0.803, lr: 9.382151867e-05
# Epoch 209:
# train loss: 0.059, val loss: 0.0994, accuracy: 0.815, lr: 9.222417988e-05
# Epoch 210:
# train loss: 0.0577, val loss: 0.169, accuracy: 0.734, lr: 9.046039887e-05
# Epoch 211:
# train loss: 0.0572, val loss: 0.0891, accuracy: 0.835, lr: 8.853713648e-05
# Epoch 212:
# train loss: 0.0564, val loss: 0.106, accuracy: 0.82, lr: 8.646198294e-05
# Epoch 213:
# train loss: 0.0554, val loss: 0.132, accuracy: 0.805, lr: 8.424312794e-05
# Epoch 214:
# train loss: 0.0542, val loss: 0.0829, accuracy: 0.849, lr: 8.188932829e-05
# Epoch 215:
# train loss: 0.0528, val loss: 0.0894, accuracy: 0.839, lr: 7.940987335e-05
# Epoch 216:
# train loss: 0.0527, val loss: 0.133, accuracy: 0.793, lr: 7.681454841e-05
# Epoch 217:
# train loss: 0.0511, val loss: 0.103, accuracy: 0.812, lr: 7.411359602e-05
# Epoch 218:
# train loss: 0.0499, val loss: 0.0983, accuracy: 0.828, lr: 7.131767561e-05
# Epoch 219:
# train loss: 0.0485, val loss: 0.0842, accuracy: 0.839, lr: 6.843782141e-05
# Epoch 220:
# train loss: 0.0478, val loss: 0.102, accuracy: 0.806, lr: 6.548539887e-05
# Epoch 221:
# train loss: 0.0462, val loss: 0.0889, accuracy: 0.834, lr: 6.247205986e-05
# Epoch 222:
# train loss: 0.0449, val loss: 0.0841, accuracy: 0.848, lr: 5.940969666e-05
# Epoch 223:
# train loss: 0.0429, val loss: 0.0956, accuracy: 0.836, lr: 5.631039502e-05
# Epoch 224:
# train loss: 0.0417, val loss: 0.0832, accuracy: 0.843, lr: 5.318638645e-05
# Epoch 225:
# train loss: 0.0407, val loss: 0.0965, accuracy: 0.831, lr: 5.005e-05
# Epoch 226:
# train loss: 0.0394, val loss: 0.102, accuracy: 0.815, lr: 4.691361355e-05
# Epoch 227:
# train loss: 0.0379, val loss: 0.0819, accuracy: 0.85, lr: 4.378960498e-05
# Epoch 228:
# train loss: 0.0367, val loss: 0.089, accuracy: 0.843, lr: 4.069030334e-05
# Epoch 229:
# train loss: 0.0354, val loss: 0.0823, accuracy: 0.869, lr: 3.762794014e-05
# Epoch 230:
# train loss: 0.0341, val loss: 0.0735, accuracy: 0.859, lr: 3.461460113e-05
# Epoch 231:
# train loss: 0.0332, val loss: 0.0792, accuracy: 0.853, lr: 3.166217859e-05
# Epoch 232:
# train loss: 0.0317, val loss: 0.0711, accuracy: 0.873, lr: 2.878232439e-05
# Epoch 233:
# train loss: 0.0305, val loss: 0.0693, accuracy: 0.869, lr: 2.598640398e-05
# Epoch 234:
# train loss: 0.0295, val loss: 0.0647, accuracy: 0.879, lr: 2.328545159e-05
# Epoch 235:
# train loss: 0.0289, val loss: 0.0642, accuracy: 0.885, lr: 2.069012665e-05
# Epoch 236:
# train loss: 0.0278, val loss: 0.0689, accuracy: 0.869, lr: 1.821067171e-05
# Epoch 237:
# train loss: 0.0271, val loss: 0.0631, accuracy: 0.884, lr: 1.585687206e-05
# Epoch 238:
# train loss: 0.0261, val loss: 0.062, accuracy: 0.873, lr: 1.363801706e-05
# Epoch 239:
# train loss: 0.0255, val loss: 0.0644, accuracy: 0.886, lr: 1.156286352e-05
# Epoch 240:
# train loss: 0.0249, val loss: 0.0593, accuracy: 0.89, lr: 9.639601131e-06
# Epoch 241:
# train loss: 0.0245, val loss: 0.0576, accuracy: 0.892, lr: 7.875820121e-06
# Epoch 242:
# train loss: 0.0239, val loss: 0.0611, accuracy: 0.883, lr: 6.278481332e-06
# Epoch 243:
# train loss: 0.0237, val loss: 0.06, accuracy: 0.886, lr: 4.853888729e-06
# Epoch 244:
# train loss: 0.0231, val loss: 0.0558, accuracy: 0.891, lr: 3.60766453e-06
# Epoch 245:
# train loss: 0.023, val loss: 0.0571, accuracy: 0.894, lr: 2.544727011e-06
# Epoch 246:
# train loss: 0.0228, val loss: 0.0552, accuracy: 0.893, lr: 1.669271102e-06
# Epoch 247:
# train loss: 0.0227, val loss: 0.056, accuracy: 0.889, lr: 9.847518261e-07
# Epoch 248:
# train loss: 0.0225, val loss: 0.0542, accuracy: 0.896, lr: 4.938706693e-07
# Epoch 249:
# train loss: 0.0224, val loss: 0.0556, accuracy: 0.893, lr: 1.98564915e-07
# Epoch 250:
# train loss: 0.0775, val loss: 0.159, accuracy: 0.722, lr: 0.0001
# Epoch 251:
# iteration 691, train loss: 0.0446, accuracy: 0.984

# %% [markdown]
# ### Make prediction on test set

# %%
def test_eval(session, model_input, model_output, x_test,y_test, batch_size = 64):
    
    x, y , is_training, l2_reg = model_input
    y_out = model_output

    #аналогично для теста
    index_test = np.arange(len(x_test))
    num_batches_test = int(len(index_test) / batch_size)
    batch_indexes_test = np.array_split(index_test, num_batches_test)
    
    y_pred = []

    for batch_index in batch_indexes_test:

        #Создаём словарь, осуществляющий сопоставление входов графа (plaseholders) и значений
        feed_dict = {x: x_test[batch_index],
                     y: y_test[batch_index],
                    is_training:False,
                    l2_reg : 0}

        #Здесь происходит непоследственный вызов модели

        y_pred_batch = session.run([y_out],feed_dict=feed_dict)

        y_pred.append(y_pred_batch[0])
        
    y_pred = np.concatenate(y_pred)
    y_pred = [np.argmax(x) for x in y_pred]
    return y_pred

with tf.Session() as sess:
    # Restore variables from disk.
    saver.restore(sess, "checkpoints/model_vgg16_v2.ckpt")
    y_pred = test_eval(sess,
                       model_input = (x, y , is_training, l2_reg),
                       model_output = y_out,
                       x_test = x_test, y_test = y_test)

# %%
to_file = np.stack([np.arange(len(y_pred)),y_pred]).T
np.savetxt("pred_vg16.txt",to_file,fmt='%.d',header='id,label',delimiter=",",comments="")
