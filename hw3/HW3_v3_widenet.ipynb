# %%
from sklearn.model_selection import train_test_split
import tensorflow as tf

import numpy as np
from keras.datasets import cifar10
from random import randrange
import time
import pickle

import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline
plt.rcParams['figure.figsize'] = (15, 12) # set default size of plots
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ### Load data

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

y_train = np.squeeze(y_train)
y_test = np.squeeze(y_test)

# %%
# print (x_train.shape)
# print (y_train.shape)

# all_aug_x = pickle.load(open('aug_image/x_images.p','rb'))
# all_aug_y = pickle.load(open('aug_image/y_images.p','rb'))


# x_train = np.concatenate([x_train,all_aug_x])
# y_train = np.concatenate([y_train,all_aug_y])

# print (x_train.shape)
# print (y_train.shape)

# %% [markdown]
# Визуализируем классы

# %%
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
num_classes = len(classes)
samples_per_class = 10
for y, cls in enumerate(classes):
    idxs = np.flatnonzero(y_train == y)
    idxs = np.random.choice(idxs, samples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt_idx = i * num_classes + y + 1
        plt.subplot(samples_per_class, num_classes, plt_idx)
        plt.imshow(x_train[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls)
plt.show()

# %%
# Preprocessing: вычитаем среднее
# 1: Находим среднее изображение
mean_image = np.mean(x_train, axis=0)
plt.figure(figsize=(4,4))
plt.imshow(mean_image.reshape((32,32,3)).astype('uint8')) # визуализируем полученное среднее
plt.show()

# %%
# 2: вычитаем среднее из изображений обучающей и тестовых выборок
x_train = x_train - mean_image
x_test = x_test - mean_image

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=1000,stratify=y_train)

# %% [markdown]
# Пожалуйста, ознакомьтесь с другими возможностями, которые предоставляет tf для описания модели.
#
# * Layers, Activations, Loss functions : https://www.tensorflow.org/api_guides/python/nn
# * Optimizers: https://www.tensorflow.org/api_guides/python/train#Optimizers
# * BatchNorm: https://www.tensorflow.org/api_docs/python/tf/layers/BatchNormalization

# %% [markdown]
# Теперь мы можем двигаться дальше и протестировать получившуюся модель. Для этого реализуем тренировочный цикл

# %% [markdown]
# Принимаются работы с точностью **не менее 84%**.
#
# Полезные ссылки:
#   - [ResNet](https://arxiv.org/abs/1512.03385).
#   - [DenseNet](https://arxiv.org/abs/1608.06993).
#   - [This blog has an in-depth overview](https://chatbotslife.com/resnets-highwaynets-and-densenets-oh-my-9bb15918ee32)

# %% [markdown]
# Напишите ваш код под текстом задания

# %% [markdown]
# ### My network

# %%
### For data augmentation
from keras.preprocessing.image import ImageDataGenerator

# %%
def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w
            r = np.random.uniform(r_1, r_2)
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img

    return eraser

# %%
import math

## https://gist.github.com/vertix/d2b1256003e9ffca8e7fc36ba1ba4eb3


def augment(images, labels,
            resize=None, # (width, height) tuple or None
            horizontal_flip=False,
            vertical_flip=False,
            rotate=0, # Maximum rotation angle in degrees
            crop_probability=0, # How often we do crops
            crop_min_percent=0.6, # Minimum linear dimension of a crop
            crop_max_percent=1.,  # Maximum linear dimension of a crop
            mixup=0):  # Mixup coeffecient, see https://arxiv.org/abs/1710.09412.pdf
  if resize is not None:
    images = tf.image.resize_bilinear(images, resize)
  
  # My experiments showed that casting on GPU improves training performance
  if images.dtype != tf.float32:
    images = tf.image.convert_image_dtype(images, dtype=tf.float32)
    images = tf.subtract(images, 0.5)
    images = tf.multiply(images, 2.0)
  labels = tf.to_float(labels)

  with tf.name_scope('augmentation'):
    shp = tf.shape(images)
    batch_size, height, width = shp[0], shp[1], shp[2]
    width = tf.cast(width, tf.float32)
    height = tf.cast(height, tf.float32)

    # The list of affine transformations that our image will go under.
    # Every element is Nx8 tensor, where N is a batch size.
    transforms = []
    identity = tf.constant([1, 0, 0, 0, 1, 0, 0, 0], dtype=tf.float32)
    if horizontal_flip:
      coin = tf.less(tf.random_uniform([batch_size], 0, 1.0), 0.5)
      flip_transform = tf.convert_to_tensor(
          [-1., 0., width, 0., 1., 0., 0., 0.], dtype=tf.float32)
      transforms.append(
          tf.where(coin,
                   tf.tile(tf.expand_dims(flip_transform, 0), [batch_size, 1]),
                   tf.tile(tf.expand_dims(identity, 0), [batch_size, 1])))

    if vertical_flip:
      coin = tf.less(tf.random_uniform([batch_size], 0, 1.0), 0.5)
      flip_transform = tf.convert_to_tensor(
          [1, 0, 0, 0, -1, height, 0, 0], dtype=tf.float32)
      transforms.append(
          tf.where(coin,
                   tf.tile(tf.expand_dims(flip_transform, 0), [batch_size, 1]),
                   tf.tile(tf.expand_dims(identity, 0), [batch_size, 1])))

    if rotate > 0:
      angle_rad = rotate / 180 * math.pi
      angles = tf.random_uniform([batch_size], -angle_rad, angle_rad)
      transforms.append(
          tf.contrib.image.angles_to_projective_transforms(
              angles, height, width))

    if crop_probability > 0:
      crop_pct = tf.random_uniform([batch_size], crop_min_percent,
                                   crop_max_percent)
      left = tf.random_uniform([batch_size], 0, width * (1 - crop_pct))
      top = tf.random_uniform([batch_size], 0, height * (1 - crop_pct))
      crop_transform = tf.stack([
          crop_pct,
          tf.zeros([batch_size]), top,
          tf.zeros([batch_size]), crop_pct, left,
          tf.zeros([batch_size]),
          tf.zeros([batch_size])
      ], 1)

      coin = tf.less(
          tf.random_uniform([batch_size], 0, 1.0), crop_probability)
      transforms.append(
          tf.where(coin, crop_transform,
                   tf.tile(tf.expand_dims(identity, 0), [batch_size, 1])))

    if transforms:
      images = tf.contrib.image.transform(
          images,
          tf.contrib.image.compose_transforms(*transforms),
          interpolation='BILINEAR') # or 'NEAREST'

    def cshift(values): # Circular shift in batch dimension
      return tf.concat([values[-1:, ...], values[:-1, ...]], 0)

    if mixup > 0:
      mixup = 1.0 * mixup # Convert to float, as tf.distributions.Beta requires floats.
      beta = tf.distributions.Beta(mixup, mixup)
      lam = beta.sample(batch_size)
      ll = tf.expand_dims(tf.expand_dims(tf.expand_dims(lam, -1), -1), -1)
      images = ll * images + (1 - ll) * cshift(images)
      labels = lam * labels + (1 - lam) * cshift(labels)

  return images, labels

# %%
## https://github.com/meliketoy/wide-resnet.pytorch/blob/master/networks/wide_resnet.py
## https://brandonlmorris.com/2018/06/30/wide-resnet-pytorch/

def my_resnet_single(single_name, x, is_training, in_filters, out_filters, keep_prob, stride = 1  ):

    USE_L2_REG = 'L2_REG'
    
    with tf.variable_scope(single_name):
        
        ## BN - relu - conv2d - dropout - BN - relu - conv2d
        
        with tf.variable_scope(single_name+"_bn1"):
            x_res = tf.layers.batch_normalization(x, training=is_training)  
        x_res = tf.nn.relu(x_res)

        Wconv1 = tf.get_variable("Wconv1", shape=[3, 3, in_filters, out_filters])
        bconv1 = tf.get_variable("bconv1", shape=[out_filters])
        x_res = tf.nn.conv2d(x_res, Wconv1, strides=[1,stride,stride,1], padding='SAME') + bconv1

        
        x_res = tf.nn.dropout(x_res, keep_prob=keep_prob)
        
        with tf.variable_scope(single_name+"_bn2"):
            x_res = tf.layers.batch_normalization(x_res, training=is_training)  
            
        x_res = tf.nn.relu(x_res)
                
        Wconv2 = tf.get_variable("Wconv2", shape=[3, 3, out_filters, out_filters])
        bconv2 = tf.get_variable("bconv2", shape=[out_filters])
        x_res = tf.nn.conv2d(x_res, Wconv2, strides=[1,1,1,1], padding='SAME') + bconv2
        
        tf.add_to_collection(USE_L2_REG, Wconv1)
        tf.add_to_collection(USE_L2_REG, bconv1)
        
        tf.add_to_collection(USE_L2_REG, Wconv2)
        tf.add_to_collection(USE_L2_REG, bconv2)

    ## shortcut
    with tf.variable_scope(single_name+"_sc"): 
        
        ## shortcut
        if in_filters != out_filters or stride!=1:
            ## batch norm - relu - conv2d
            x_sc = tf.layers.batch_normalization(x, training=is_training)  
            x_sc = tf.nn.relu(x_sc)
            
            Wconv = tf.get_variable("Wconv", shape=[3, 3, in_filters, out_filters])
            bconv = tf.get_variable("bconv", shape=[out_filters])
            
            x_sc = tf.nn.conv2d(x_sc, Wconv, strides=[1,stride,stride,1], padding='SAME') + bconv
            
            tf.add_to_collection(USE_L2_REG, Wconv)
            tf.add_to_collection(USE_L2_REG, bconv)
            
        else:
            x_sc = x
            
    out = x_sc + x_res
    
    return out
    
def my_resnet_group(block_name, x, is_training, num_blocks, in_filters, out_filters, keep_prob, stride = 1):
    
    x_out = x
    
    strides = [stride] + [1]*(num_blocks-1)
    filters = [in_filters] + [out_filters]*(num_blocks-1)
        
    with tf.variable_scope(block_name):

        for i in range(num_blocks):
            x_out = my_resnet_single(block_name+"_"+str(i), x_out, is_training, filters[i], out_filters, keep_prob, stride = strides[i])
    
    return x_out
            


def my_WideResNet(n_grps = 3, N = 4, k = 10):
    
    x = tf.placeholder(tf.float32, [None, 32, 32, 3])
    y = tf.placeholder(tf.int64, [None])
    
    x, _ = augment(x, y,
            resize=None, # (width, height) tuple or None
            horizontal_flip=True,
            vertical_flip=True,
            rotate=15, # Maximum rotation angle in degrees
            crop_probability=0.1, # How often we do crops
            crop_min_percent=0.0, # Minimum linear dimension of a crop
            crop_max_percent=0.3,  # Maximum linear dimension of a crop
            mixup=0)
    
    is_training = tf.placeholder(tf.bool)
    l2_reg = tf.placeholder(tf.float32)

    USE_L2_REG = 'L2_REG' 
    
    ## ---  WideResNet 
    ##
    
    x_res = x
    
    with tf.variable_scope("res_start"):
        
        Wconv = tf.get_variable("Wconv", shape=[3, 3, 3, 16])
        bconv = tf.get_variable("bconv", shape=[16])
        x_res = tf.nn.conv2d(x_res, Wconv, strides=[1,1,1,1], padding='SAME') + bconv
        
        tf.add_to_collection(USE_L2_REG, Wconv)
        tf.add_to_collection(USE_L2_REG, bconv)   
        
    widths = [16]
    for i_grp in range(n_grps):
        widths.append(16*(2**i_grp)*k)
        ## [16, 16*k, 32*k, 64*k]
        
    for i in range(n_grps):
        x_res = my_resnet_group("res_block"+str(i), x_res, is_training, N, widths[i], widths[i+1], 
                                keep_prob = 0.7, stride = (1 if i == 0 else 2))
        
    print (x_res.shape)
        
    #добавляем полносвязный слой
    with tf.variable_scope("dense_layer_1"):
        
        x_res = tf.layers.batch_normalization(x_res, training=is_training)                    
        x_res = tf.nn.relu(x_res)
        
        size = 8*8*widths[n_grps]
        W1 = tf.get_variable("W1", shape=[size, 10])
        b1 = tf.get_variable("b1", shape=[10])
        
        x_res = tf.reshape(x_res,[-1,size])
        x_res = tf.matmul(x_res,W1) + b1  
        
        tf.add_to_collection(USE_L2_REG, W1)
        tf.add_to_collection(USE_L2_REG, b1)     
        
    y_out = x_res 
        
    ## l2 regularization
    L2_loss = tf.add_n([tf.nn.l2_loss(v) for v in tf.get_collection(USE_L2_REG)]) * l2_reg
        
    # y_out -- это вектор оценок, которые генерирует модель. Теперь определим функцию потерь
#     total_loss = tf.losses.hinge_loss(tf.one_hot(y,10),logits=y_out)

    total_loss = tf.nn.softmax_cross_entropy_with_logits_v2(labels=tf.one_hot(y,10),logits=y_out)
    mean_loss = tf.reduce_mean(total_loss) + L2_loss
    
    
    correct_prediction = tf.equal(tf.argmax(y_out,1), y)
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    
    tf.summary.scalar('mean_loss', mean_loss)
    tf.summary.scalar('accuracy', accuracy)
            
    #Возвращаем те узлы графа, которые нам понадобятся в дальнейшем.
    #(x,y) это входы графа, а (y_out, mean_loss) выходы, которые представляют для нас интерес
    return (x,y,is_training,l2_reg), (y_out, mean_loss, accuracy)

# %%
def training_loop(session, model_inputs, model_outputs, train_step, 
                  epochs=10, batch_size=64):
    
    train_writer = tf.summary.FileWriter('tensorboard/train',session.graph)
    val_writer = tf.summary.FileWriter('tensorboard/val')

    #создаём индекс по всем объектам
    index = np.arange(len(x_train))
    
    #перемешиваем его
    np.random.shuffle(index)
    
    #разбиваем на батчи
    num_batches = int(len(index) / batch_size)
    batch_indexes = np.array_split(index, num_batches)
    
    #аналогично для теста
    index_test = np.arange(len(x_test))
    np.random.shuffle(index_test)
    num_batches_test = int(len(index_test) / batch_size)
    batch_indexes_test = np.array_split(index_test, num_batches_test)
    
    #аналогично для validation
    index_val = np.arange(len(x_val))
    np.random.shuffle(index_val)
    num_batches_val = int(len(index_val) / batch_size)
    batch_indexes_val = np.array_split(index_val, num_batches_val)
    
    x,y,is_training,l2_reg,learning_rate = model_inputs
    y_out, mean_loss, accuracy = model_outputs
    
    
    eraser = get_random_eraser(p=0.3, v_l=0, v_h=1, s_l=0.02, s_h=0.4, pixel_level=True)
    
    def cosine_decay(learning_rate,global_step,decay_steps,alpha=0.0):
        global_step = min(global_step, decay_steps)
        cosine_decay = 0.5 * (1 + np.cos(np.pi * global_step / decay_steps))
        decayed = (1 - alpha) * cosine_decay + alpha
        decayed_learning_rate = learning_rate * decayed
        return decayed_learning_rate
    
    def train(x_values, y_values, batch_indexes, epoch):
        train_loses = []
        
        if epoch<50:
            lr = cosine_decay(0.0001,global_step = epoch % 50,decay_steps = 50, alpha = 0.01)
        if epoch>=50:
            lr = cosine_decay(0.0001,global_step = epoch % 50,decay_steps = 50, alpha = 0.01)
                
        for i, batch_index in enumerate(batch_indexes):
            

            #Создаём словарь, осуществляющий сопоставление входов графа (plaseholders) и значений
                
            x_batch = [eraser(img) for img in x_values[batch_index]]
        
            feed_dict = {x: x_batch,
                         y: y_values[batch_index],
                        is_training:True,
                        l2_reg: 0.001,
                        learning_rate:lr}

            #Здесь происходит непоследственный вызов модели
            #Обратите внимание, что мы передаём 
                      
            summary, scores, loss, acc, _ = session.run([merged,y_out, mean_loss, accuracy, train_step],feed_dict=feed_dict)

            train_loses.append(loss)
            print(f'iteration {i}, train loss: {loss:.3}, accuracy: {acc:.3}', end='\r')
            
            train_writer.add_summary(summary, epoch * num_batches+i)

        return train_loses, lr
        
    def evaluate(x_values, y_values, batch_indexes, epoch):
        test_loses = []
        test_accuracy = []

        for batch_index in batch_indexes:

            #Создаём словарь, осуществляющий сопоставление входов графа (plaseholders) и значений
            feed_dict = {x: x_values[batch_index],
                         y: y_values[batch_index],
                        is_training:False,
                        l2_reg : 0}
            
            #Здесь происходит непоследственный вызов модели
            
            summary, loss, acc = session.run([merged,mean_loss, accuracy],feed_dict=feed_dict)
                             
                
            test_loses.append(loss)
            test_accuracy.append(acc)

            # Create a new Summary object with your measure
            
        summary = tf.Summary()
        summary.value.add(tag="val_Accuracy", simple_value=np.mean(test_accuracy))
        summary.value.add(tag="val_Loses", simple_value=np.mean(test_loses))
        
        val_writer.add_summary(summary, epoch)

        return test_loses, test_accuracy
    
        
    # цикл по эпохам
    for e in range(epochs):
        print(f'Epoch {e}:')
        train_loses, lr = train(x_train, y_train, batch_indexes, e)
        val_loses, val_accuracy = evaluate(x_val, y_val, batch_indexes_val, e)
        print(f'train loss: {np.mean(train_loses):.3}, val loss: {np.mean(val_loses):.3}, accuracy: {np.mean(val_accuracy):.3}, lr: {lr:.10}')
        
        save_path = saver.save(session, "checkpoints/model_resnet.ckpt")
        
        if e % 50 == 49:
            try:
                save_path = saver.save(session, "checkpoints/model_resnet_ep"+str(e)+".ckpt")
            except:
                pass
            
    print('================================================')
    print('Test set results:')
    test_loses, test_accuracy = evaluate(x_test, y_test, batch_indexes_test,e)
    print(f'test loss: {np.mean(test_loses):.3}, accuracy: {np.mean(test_accuracy):.3}')

# %%
#Перед вызовом функции очистим память от графов других моделей (актуально если вы вызываете эту ячейку повторно)
tf.reset_default_graph()
(x,y,is_training,l2_reg), (y_out, mean_loss, accuracy) = my_WideResNet(n_grps = 3, N = 4, k = 10)

merged = tf.summary.merge_all()
saver = tf.train.Saver()


#Теперь зададим алгоритм оптимизации
learning_rate = tf.placeholder(tf.float32, shape=[])
optimizer = tf.train.AdamOptimizer(learning_rate) 
#train_step -- специальный служебный узел в графе, отвечающий за обратный проход


update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
with tf.control_dependencies(update_ops):
    
    gvs = optimizer.compute_gradients(mean_loss)
    capped_gvs = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gvs]
    train_step = optimizer.apply_gradients(capped_gvs)

#     train_step = optimizer.minimize(mean_loss)
# Out:
# (?, 8, 8, 640)

# %%
import tensorflow.contrib.slim as slim
def model_summary():
    model_vars = tf.trainable_variables()
    slim.model_analyzer.analyze_vars(model_vars, print_info=True)

model_summary()
# Out:
# ---------
# Variables: name (type shape) [size]
# ---------
# res_start/Wconv:0 (float32_ref 3x3x3x16) [432, bytes: 1728]
# res_start/bconv:0 (float32_ref 16) [16, bytes: 64]
# res_block0/res_block0_0/res_block0_0_bn1/batch_normalization/gamma:0 (float32_ref 16) [16, bytes: 64]
# res_block0/res_block0_0/res_block0_0_bn1/batch_normalization/beta:0 (float32_ref 16) [16, bytes: 64]
# res_block0/res_block0_0/Wconv1:0 (float32_ref 3x3x16x160) [23040, bytes: 92160]
# res_block0/res_block0_0/bconv1:0 (float32_ref 160) [160, bytes: 640]
# res_block0/res_block0_0/res_block0_0_bn2/batch_normalization/gamma:0 (float32_ref 160) [160, bytes: 640]
# res_block0/res_block0_0/res_block0_0_bn2/batch_normalization/beta:0 (float32_ref 160) [160, bytes: 640]
# res_block0/res_block0_0/Wconv2:0 (float32_ref 3x3x160x160) [230400, bytes: 921600]
# res_block0/res_block0_0/bconv2:0 (float32_ref 160) [160, bytes: 640]
# res_block0/res_block0_0_sc/batch_normalization/gamma:0 (float32_ref 16) [16, bytes: 64]
# res_block0/res_block0_0_sc/batch_normalization/beta:0 (float32_ref 16) [16, bytes: 64]
# res_block0/res_block0_0_sc/Wconv:0 (float32_ref 3x3x16x160) [23040, bytes: 92160]
# res_block0/res_block0_0_sc/bconv:0 (float32_ref 160) [160, bytes: 640]
# res_block0/res_block0_1/res_block0_1_bn1/batch_normalization/gamma:0 (float32_ref 160) [160, bytes: 640]
# res_block0/res_block0_1/res_block0_1_bn1/batch_normalization/beta:0 (float32_ref 160) [160, bytes: 640]
# res_block0/res_block0_1/Wconv1:0 (float32_ref 3x3x160x160) [230400, bytes: 921600]
# res_block0/res_block0_1/bconv1:0 (float32_ref 160) [160, bytes: 640]
# res_block0/res_block0_1/res_block0_1_bn2/batch_normalization/gamma:0 (float32_ref 160) [160, bytes: 640]
# res_block0/res_block0_1/res_block0_1_bn2/batch_normalization/beta:0 (float32_ref 160) [160, bytes: 640]
# res_block0/res_block0_1/Wconv2:0 (float32_ref 3x3x160x160) [230400, bytes: 921600]
# res_block0/res_block0_1/bconv2:0 (float32_ref 160) [160, bytes: 640]
# res_block0/res_block0_2/res_block0_2_bn1/batch_normalization/gamma:0 (float32_ref 160) [160, bytes: 640]
# res_block0/res_block0_2/res_block0_2_bn1/batch_normalization/beta:0 (float32_ref 160) [160, bytes: 640]
# res_block0/res_block0_2/Wconv1:0 (float32_ref 3x3x160x160) [230400, bytes: 921600]
# res_block0/res_block0_2/bconv1:0 (float32_ref 160) [160, bytes: 640]
# res_block0/res_block0_2/res_block0_2_bn2/batch_normalization/gamma:0 (float32_ref 160) [160, bytes: 640]
# res_block0/res_block0_2/res_block0_2_bn2/batch_normalization/beta:0 (float32_ref 160) [160, bytes: 640]
# res_block0/res_block0_2/Wconv2:0 (float32_ref 3x3x160x160) [230400, bytes: 921600]
# res_block0/res_block0_2/bconv2:0 (float32_ref 160) [160, bytes: 640]
# res_block0/res_block0_3/res_block0_3_bn1/batch_normalization/gamma:0 (float32_ref 160) [160, bytes: 640]
# res_block0/res_block0_3/res_block0_3_bn1/batch_normalization/beta:0 (float32_ref 160) [160, bytes: 640]
# res_block0/res_block0_3/Wconv1:0 (float32_ref 3x3x160x160) [230400, bytes: 921600]
# res_block0/res_block0_3/bconv1:0 (float32_ref 160) [160, bytes: 640]
# res_block0/res_block0_3/res_block0_3_bn2/batch_normalization/gamma:0 (float32_ref 160) [160, bytes: 640]
# res_block0/res_block0_3/res_block0_3_bn2/batch_normalization/beta:0 (float32_ref 160) [160, bytes: 640]
# res_block0/res_block0_3/Wconv2:0 (float32_ref 3x3x160x160) [230400, bytes: 921600]
# res_block0/res_block0_3/bconv2:0 (float32_ref 160) [160, bytes: 640]
# res_block1/res_block1_0/res_block1_0_bn1/batch_normalization/gamma:0 (float32_ref 160) [160, bytes: 640]
# res_block1/res_block1_0/res_block1_0_bn1/batch_normalization/beta:0 (float32_ref 160) [160, bytes: 640]
# res_block1/res_block1_0/Wconv1:0 (float32_ref 3x3x160x320) [460800, bytes: 1843200]
# res_block1/res_block1_0/bconv1:0 (float32_ref 320) [320, bytes: 1280]
# res_block1/res_block1_0/res_block1_0_bn2/batch_normalization/gamma:0 (float32_ref 320) [320, bytes: 1280]
# res_block1/res_block1_0/res_block1_0_bn2/batch_normalization/beta:0 (float32_ref 320) [320, bytes: 1280]
# res_block1/res_block1_0/Wconv2:0 (float32_ref 3x3x320x320) [921600, bytes: 3686400]
# res_block1/res_block1_0/bconv2:0 (float32_ref 320) [320, bytes: 1280]
# res_block1/res_block1_0_sc/batch_normalization/gamma:0 (float32_ref 160) [160, bytes: 640]
# res_block1/res_block1_0_sc/batch_normalization/beta:0 (float32_ref 160) [160, bytes: 640]
# res_block1/res_block1_0_sc/Wconv:0 (float32_ref 3x3x160x320) [460800, bytes: 1843200]
# res_block1/res_block1_0_sc/bconv:0 (float32_ref 320) [320, bytes: 1280]
# res_block1/res_block1_1/res_block1_1_bn1/batch_normalization/gamma:0 (float32_ref 320) [320, bytes: 1280]
# res_block1/res_block1_1/res_block1_1_bn1/batch_normalization/beta:0 (float32_ref 320) [320, bytes: 1280]
# res_block1/res_block1_1/Wconv1:0 (float32_ref 3x3x320x320) [921600, bytes: 3686400]
# res_block1/res_block1_1/bconv1:0 (float32_ref 320) [320, bytes: 1280]
# res_block1/res_block1_1/res_block1_1_bn2/batch_normalization/gamma:0 (float32_ref 320) [320, bytes: 1280]
# res_block1/res_block1_1/res_block1_1_bn2/batch_normalization/beta:0 (float32_ref 320) [320, bytes: 1280]
# res_block1/res_block1_1/Wconv2:0 (float32_ref 3x3x320x320) [921600, bytes: 3686400]
# res_block1/res_block1_1/bconv2:0 (float32_ref 320) [320, bytes: 1280]
# res_block1/res_block1_2/res_block1_2_bn1/batch_normalization/gamma:0 (float32_ref 320) [320, bytes: 1280]
# res_block1/res_block1_2/res_block1_2_bn1/batch_normalization/beta:0 (float32_ref 320) [320, bytes: 1280]
# res_block1/res_block1_2/Wconv1:0 (float32_ref 3x3x320x320) [921600, bytes: 3686400]
# res_block1/res_block1_2/bconv1:0 (float32_ref 320) [320, bytes: 1280]
# res_block1/res_block1_2/res_block1_2_bn2/batch_normalization/gamma:0 (float32_ref 320) [320, bytes: 1280]
# res_block1/res_block1_2/res_block1_2_bn2/batch_normalization/beta:0 (float32_ref 320) [320, bytes: 1280]
# res_block1/res_block1_2/Wconv2:0 (float32_ref 3x3x320x320) [921600, bytes: 3686400]
# res_block1/res_block1_2/bconv2:0 (float32_ref 320) [320, bytes: 1280]
# res_block1/res_block1_3/res_block1_3_bn1/batch_normalization/gamma:0 (float32_ref 320) [320, bytes: 1280]
# res_block1/res_block1_3/res_block1_3_bn1/batch_normalization/beta:0 (float32_ref 320) [320, bytes: 1280]
# res_block1/res_block1_3/Wconv1:0 (float32_ref 3x3x320x320) [921600, bytes: 3686400]
# res_block1/res_block1_3/bconv1:0 (float32_ref 320) [320, bytes: 1280]
# res_block1/res_block1_3/res_block1_3_bn2/batch_normalization/gamma:0 (float32_ref 320) [320, bytes: 1280]
# res_block1/res_block1_3/res_block1_3_bn2/batch_normalization/beta:0 (float32_ref 320) [320, bytes: 1280]
# res_block1/res_block1_3/Wconv2:0 (float32_ref 3x3x320x320) [921600, bytes: 3686400]
# res_block1/res_block1_3/bconv2:0 (float32_ref 320) [320, bytes: 1280]
# res_block2/res_block2_0/res_block2_0_bn1/batch_normalization/gamma:0 (float32_ref 320) [320, bytes: 1280]
# res_block2/res_block2_0/res_block2_0_bn1/batch_normalization/beta:0 (float32_ref 320) [320, bytes: 1280]
# res_block2/res_block2_0/Wconv1:0 (float32_ref 3x3x320x640) [1843200, bytes: 7372800]
# res_block2/res_block2_0/bconv1:0 (float32_ref 640) [640, bytes: 2560]
# res_block2/res_block2_0/res_block2_0_bn2/batch_normalization/gamma:0 (float32_ref 640) [640, bytes: 2560]
# res_block2/res_block2_0/res_block2_0_bn2/batch_normalization/beta:0 (float32_ref 640) [640, bytes: 2560]
# res_block2/res_block2_0/Wconv2:0 (float32_ref 3x3x640x640) [3686400, bytes: 14745600]
# res_block2/res_block2_0/bconv2:0 (float32_ref 640) [640, bytes: 2560]
# res_block2/res_block2_0_sc/batch_normalization/gamma:0 (float32_ref 320) [320, bytes: 1280]
# res_block2/res_block2_0_sc/batch_normalization/beta:0 (float32_ref 320) [320, bytes: 1280]
# res_block2/res_block2_0_sc/Wconv:0 (float32_ref 3x3x320x640) [1843200, bytes: 7372800]
# res_block2/res_block2_0_sc/bconv:0 (float32_ref 640) [640, bytes: 2560]
# res_block2/res_block2_1/res_block2_1_bn1/batch_normalization/gamma:0 (float32_ref 640) [640, bytes: 2560]
# res_block2/res_block2_1/res_block2_1_bn1/batch_normalization/beta:0 (float32_ref 640) [640, bytes: 2560]
# res_block2/res_block2_1/Wconv1:0 (float32_ref 3x3x640x640) [3686400, bytes: 14745600]
# res_block2/res_block2_1/bconv1:0 (float32_ref 640) [640, bytes: 2560]
# res_block2/res_block2_1/res_block2_1_bn2/batch_normalization/gamma:0 (float32_ref 640) [640, bytes: 2560]
# res_block2/res_block2_1/res_block2_1_bn2/batch_normalization/beta:0 (float32_ref 640) [640, bytes: 2560]
# res_block2/res_block2_1/Wconv2:0 (float32_ref 3x3x640x640) [3686400, bytes: 14745600]
# res_block2/res_block2_1/bconv2:0 (float32_ref 640) [640, bytes: 2560]
# res_block2/res_block2_2/res_block2_2_bn1/batch_normalization/gamma:0 (float32_ref 640) [640, bytes: 2560]
# res_block2/res_block2_2/res_block2_2_bn1/batch_normalization/beta:0 (float32_ref 640) [640, bytes: 2560]
# res_block2/res_block2_2/Wconv1:0 (float32_ref 3x3x640x640) [3686400, bytes: 14745600]
# res_block2/res_block2_2/bconv1:0 (float32_ref 640) [640, bytes: 2560]
# res_block2/res_block2_2/res_block2_2_bn2/batch_normalization/gamma:0 (float32_ref 640) [640, bytes: 2560]
# res_block2/res_block2_2/res_block2_2_bn2/batch_normalization/beta:0 (float32_ref 640) [640, bytes: 2560]
# res_block2/res_block2_2/Wconv2:0 (float32_ref 3x3x640x640) [3686400, bytes: 14745600]
# res_block2/res_block2_2/bconv2:0 (float32_ref 640) [640, bytes: 2560]
# res_block2/res_block2_3/res_block2_3_bn1/batch_normalization/gamma:0 (float32_ref 640) [640, bytes: 2560]
# res_block2/res_block2_3/res_block2_3_bn1/batch_normalization/beta:0 (float32_ref 640) [640, bytes: 2560]
# res_block2/res_block2_3/Wconv1:0 (float32_ref 3x3x640x640) [3686400, bytes: 14745600]
# res_block2/res_block2_3/bconv1:0 (float32_ref 640) [640, bytes: 2560]
# res_block2/res_block2_3/res_block2_3_bn2/batch_normalization/gamma:0 (float32_ref 640) [640, bytes: 2560]
# res_block2/res_block2_3/res_block2_3_bn2/batch_normalization/beta:0 (float32_ref 640) [640, bytes: 2560]
# res_block2/res_block2_3/Wconv2:0 (float32_ref 3x3x640x640) [3686400, bytes: 14745600]
# res_block2/res_block2_3/bconv2:0 (float32_ref 640) [640, bytes: 2560]
# dense_layer_1/batch_normalization/gamma:0 (float32_ref 640) [640, bytes: 2560]
# dense_layer_1/batch_normalization/beta:0 (float32_ref 640) [640, bytes: 2560]
# dense_layer_1/W1:0 (float32_ref 40960x10) [409600, bytes: 1638400]
# dense_layer_1/b1:0 (float32_ref 10) [10, bytes: 40]
# Total size of variables: 38961962
# Total bytes of variables: 155847848

# %%
# создаём сессию. Сессия -- это среда, в которой выполняются вычисления
with tf.Session() as sess:
        
    #мы можем явно указать устройство
    with tf.device("/gpu:0"): #"/cpu:0" or "/gpu:0" 
        #инициализируем веса, в этот момент происходит выделение памяти
        sess.run(tf.global_variables_initializer())
        
        #запускаем тренировку
        training_loop(sess, model_inputs=(x,y,is_training, l2_reg, learning_rate), 
                      model_outputs=(y_out, mean_loss, accuracy), 
                      train_step=train_step, epochs=300)
# Out:
# Epoch 0:
# train loss: 6.19, val loss: 1.64, accuracy: 0.489, lr: 0.0001
# Epoch 1:
# train loss: 5.26, val loss: 1.12, accuracy: 0.613, lr: 9.990143508e-05
# Epoch 2:
# train loss: 4.43, val loss: 1.03, accuracy: 0.652, lr: 9.960612933e-05
# Epoch 3:
# train loss: 3.67, val loss: 0.979, accuracy: 0.676, lr: 9.911524817e-05
# Epoch 4:
# train loss: 3.03, val loss: 0.858, accuracy: 0.724, lr: 9.84307289e-05
# Epoch 5:
# train loss: 2.52, val loss: 1.44, accuracy: 0.604, lr: 9.755527299e-05
# Epoch 6:
# train loss: 2.11, val loss: 1.45, accuracy: 0.669, lr: 9.649233547e-05
# Epoch 7:
# train loss: 1.8, val loss: 0.918, accuracy: 0.755, lr: 9.524611127e-05
# Epoch 8:
# train loss: 1.6, val loss: 0.787, accuracy: 0.765, lr: 9.382151867e-05
# Epoch 9:
# train loss: 1.41, val loss: 1.1, accuracy: 0.738, lr: 9.222417988e-05
# Epoch 10:
# train loss: 1.27, val loss: 0.786, accuracy: 0.792, lr: 9.046039887e-05
# Epoch 11:
# train loss: 1.15, val loss: 1.18, accuracy: 0.743, lr: 8.853713648e-05
# Epoch 12:
# train loss: 1.07, val loss: 0.917, accuracy: 0.784, lr: 8.646198294e-05
# Epoch 13:
# train loss: 0.995, val loss: 0.91, accuracy: 0.775, lr: 8.424312794e-05
# Epoch 14:
# train loss: 0.933, val loss: 0.747, accuracy: 0.798, lr: 8.188932829e-05
# Epoch 15:
# train loss: 0.856, val loss: 1.14, accuracy: 0.768, lr: 7.940987335e-05
# Epoch 16:
# iteration 527, train loss: 0.948, accuracy: 0.875

# %% [markdown]
# ### Make prediction on test set

# %%
def test_eval(session, model_input, model_output, x_test,y_test, batch_size = 64):
    
    x, y , is_training, l2_reg = model_input
    y_out = model_output

    #аналогично для теста
    index_test = np.arange(len(x_test))
    num_batches_test = int(len(index_test) / batch_size)
    batch_indexes_test = np.array_split(index_test, num_batches_test)
    
    y_pred = []

    for batch_index in batch_indexes_test:

        #Создаём словарь, осуществляющий сопоставление входов графа (plaseholders) и значений
        feed_dict = {x: x_test[batch_index],
                     y: y_test[batch_index],
                    is_training:False,
                    l2_reg : 0}

        #Здесь происходит непоследственный вызов модели

        y_pred_batch = session.run([y_out],feed_dict=feed_dict)

        y_pred.append(y_pred_batch[0])
        
    y_pred = np.concatenate(y_pred)
    y_pred = [np.argmax(x) for x in y_pred]
    return y_pred

with tf.Session() as sess:
    # Restore variables from disk.
    saver.restore(sess, "checkpoints/model_vgg16_v2.ckpt")
    y_pred = test_eval(sess,
                       model_input = (x, y , is_training, l2_reg),
                       model_output = y_out,
                       x_test = x_test, y_test = y_test)

# %%
to_file = np.stack([np.arange(len(y_pred)),y_pred]).T
np.savetxt("pred_vg16.txt",to_file,fmt='%.d',header='id,label',delimiter=",",comments="")
