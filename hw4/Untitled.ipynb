# %%
import numpy as np
import tensorflow
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
from tensorflow import keras

# %%
class Vocab(object):
    def __init__(self):
        self.rev_vocabulary_mapping = []  ## (V,E)
        self.vocabulary_mapping = {}  ## каждому слову индекс строки из матрицы E
        self.embeddings = None
    
    def unvectorize(self, ids):
        return ' '.join([self.rev_vocabulary_mapping[i] for i in ids])
    
    def vectorize(self, tokens):
        return [self.vocabulary_mapping.get(w, self.vocabulary_mapping['<UNK>']) for w in tokens]
    
    def load_embeddings(self, filename, embedding_size=50, cut_at=400000):
        # список векторов
        embeddings_list = []
        # словарь слово-индекс
        self.vocabulary_mapping = {'<PAD>': 0} # занесём ключ соотетствующий отступу
        self.rev_vocabulary_mapping.append('<PAD>')
        pad = np.zeros(embedding_size) # создадим вектор для PAD
        embeddings_list.append(pad)

        with open(filename,encoding='utf8') as glove_file: 
            i = 1
            for line in glove_file:
                fields = line.split()
                token = fields[0]
                vector = np.array(list(map(float, fields[1:])))
                
                embeddings_list.append(vector)
                self.vocabulary_mapping[token] = i
                self.rev_vocabulary_mapping.append(token)
                i += 1
                if i >= cut_at:
                    break
                    
        self.vocabulary_mapping['<UNK>'] = len(embeddings_list)
        self.rev_vocabulary_mapping.append('<UNK>')
        unk = np.mean(embeddings_list[1:], axis=0) # считаем средний вектор
        embeddings_list.append(unk)

        self.embeddings = np.array(embeddings_list)
                
        print(f'Loaded {self.embeddings.shape} embeddings')

# %%
vocab = Vocab()
vocab.load_embeddings('glove.6B.50d.txt')
# Out:
# Loaded (400001, 50) embeddings

# %%
v = vocab.vectorize(['mother','of','god'])
v
# Out:
# [809, 4, 1534]

# %%
vocab.unvectorize(v)
# Out:
# 'mother of god'

# %% [markdown]
# ### Загрузим ATIS

# %%
def load_csv(filename):
    results = []
    with open(filename) as f:
        for l in f:
            results.append(l.strip())
            
    return results

# %%
slots = load_csv('data/atis.dict.slots.csv')
intents = load_csv('data/atis.dict.intent.csv')
atis_vocab = load_csv('data/atis.dict.vocab.csv')

# %%
atis_train_queries = load_csv('data/atis.train.query.csv')
atis_train_intents = load_csv('data/atis.train.intent.csv')
atis_train_slots = load_csv('data/atis.train.slots.csv')

# %%
def atis_ids_to_words(ids, atis_vocab):
    return [atis_vocab[i] for i in ids]

# %%
atis_train_queries = [[int(index) for index in line.split()] for line in atis_train_queries]
atis_train_intents = [int(index) for index in atis_train_intents]
atis_train_slots = [[int(index) for index in line.split()] for line in atis_train_slots]

# %%
atis_train_queries_w = [[atis_vocab[i] for i in line] for line in atis_train_queries]
[' '.join([i for i in line]) for line in atis_train_queries_w]
# Out:
# ['BOS i want to fly from boston at 838 am and arrive in denver at 1110 in the morning EOS',
#  'BOS what flights are available from pittsburgh to baltimore on thursday morning EOS',
#  'BOS what is the arrival time in san francisco for the 755 am flight leaving washington EOS',
#  'BOS cheapest airfare from tacoma to orlando EOS',
#  'BOS round trip fares from pittsburgh to philadelphia under 1000 dollars EOS',
#  'BOS i need a flight tomorrow from columbus to minneapolis EOS',
#  'BOS what kind of aircraft is used on a flight from cleveland to dallas EOS',
#  'BOS show me the flights from pittsburgh to los angeles on thursday EOS',
#  'BOS all flights from boston to washington EOS',
#  'BOS what kind of ground transportation is available in denver EOS',
#  'BOS show me the flights from dallas to san francisco EOS',
#  'BOS show me the flights from san diego to newark by way of houston EOS',
#  "BOS what 's the airport at orlando EOS",
#  'BOS what is the cheapest flight from boston to bwi EOS',
#  'BOS all flights to baltimore after 6 pm EOS',
#  'BOS show me the first class fares from boston to denver EOS',
#  'BOS show me the ground transportation in denver EOS',
#  'BOS all flights from denver to pittsburgh leaving after 6 pm and before 7 pm EOS',
#  'BOS i need information on flights for tuesday leaving baltimore for dallas dallas to boston and boston to baltimore EOS',
#  'BOS please give me the flights from boston to pittsburgh on thursday of next week EOS',
#  'BOS i would like to fly from denver to pittsburgh on united airlines EOS',
#  'BOS show me the flights from san diego to newark EOS',
#  'BOS please list all first class flights on united from denver to baltimore EOS',
#  'BOS what kinds of planes are used by american airlines EOS',
#  "BOS i 'd like to have some information on a ticket from denver to pittsburgh and atlanta EOS",
#  "BOS i 'd like to book a flight from atlanta to denver EOS",
#  'BOS which airline serves denver pittsburgh and atlanta EOS',
#  "BOS show me all flights from boston to pittsburgh on wednesday of next week which leave boston after 2 o'clock pm EOS",
#  'BOS atlanta ground transportation EOS',
#  'BOS i also need service from dallas to boston arriving by noon EOS',
#  'BOS show me the cheapest round trip fare from baltimore to dallas EOS',
#  'BOS show me all flights from new york to milwaukee on northwest airlines departing at 720 am EOS',
#  'BOS flights from new york to miami EOS',
#  'BOS please find a flight on delta from philadelphia to san francisco and give me the flight numbers EOS',
#  'BOS i need a flight from dallas to san francisco EOS',
#  'BOS fares and flights from pittsburgh to philadelphia EOS',
#  'BOS show me the airlines with first class flights EOS',
#  'BOS what are the flights from st. louis to burbank sunday evening EOS',
#  "BOS i 'd like to arrange a flight from pittsburgh to atlanta EOS",
#  'BOS show flights from baltimore to san francisco between 6 pm and 8 pm on friday EOS',
#  'BOS how far is it from orlando airport to orlando EOS',
#  'BOS i would like a list of round trip flights between indianapolis and orlando florida for the twenty seventh and the twenty eighth of december EOS',
#  'BOS which airline has the most arrivals in atlanta EOS',
#  'BOS what airlines fly from new york to milwaukee to los angeles EOS',
#  'BOS pittsburgh to denver EOS',
#  'BOS which airlines serve atlanta EOS',
#  'BOS show me information on ground transportation for dallas EOS',
#  'BOS what is fare code h EOS',
#  'BOS show me all flights from boston to dallas fort worth both direct and connecting that arrive before noon EOS',
#  'BOS i need a flight from charlotte to newark leaving today evening EOS',
#  'BOS what are the times that you have planes leaving from san francisco going to pittsburgh on july seventh EOS',
#  'BOS flights from newark to cleveland EOS',
#  "BOS what flights go from boston to pittsburgh after 6 o'clock next tuesday EOS",
#  'BOS how much does the limousine service cost within pittsburgh EOS',
#  'BOS does us air have any flights out of atlanta to denver EOS',
#  'BOS what is booking class c EOS',
#  "BOS i 'd like to know the shortest trip between boston and san francisco EOS",
#  'BOS i would like to see information for flights from san francisco leaving after 12 pm to pittsburgh on monday EOS',
#  'BOS what is the least expensive flight from denver to atlanta EOS',
#  'BOS i need to know information for flights leaving dallas on tuesday evening and returning to atlanta EOS',
#  'BOS what flight goes from denver to baltimore first class on united airlines arriving on may seventh EOS',
#  'BOS could you please tell me the airlines that fly from toronto to san diego EOS',
#  'BOS what flights do you have from burbank to tacoma washington EOS',
#  'BOS what is the ground transportation from philadelphia airport to the city proper EOS',
#  'BOS which airlines have first class flights today EOS',
#  'BOS find the latest flight from san francisco to atlanta that serves a meal EOS',
#  'BOS i would like to make a reservation for a flight to denver from philadelphia on this coming sunday EOS',
#  'BOS give me a list of airports in baltimore EOS',
#  'BOS show me flights from boston to denver on wednesday EOS',
#  'BOS show me the flights from boston to baltimore EOS',
#  'BOS what does fare code q mean EOS',
#  'BOS please give me the flights from san francisco to washington dc EOS',
#  'BOS i need information from denver to pittsburgh EOS',
#  'BOS from seattle to salt lake city EOS',
#  'BOS what is the earliest flight from boston to bwi that serves a snack EOS',
#  'BOS what types of aircraft does delta fly EOS',
#  'BOS what is the cost of a round trip flight from pittsburgh to atlanta beginning on april twenty fifth and returning on may sixth EOS',
#  'BOS give me the flights leaving denver august ninth coming back to boston EOS',
#  'BOS list all the flights that fly into general mitchell international EOS',
#  'BOS what flights fly from denver to san francisco on monday tuesday wednesday thursday and friday EOS',
#  'BOS list all flights from indianapolis to seattle EOS',
#  'BOS in flight meal oakland to philadelphia saturday EOS',
#  'BOS show me the flights on twa from atlanta in the morning EOS',
#  'BOS i want to find the first flight from baltimore to boston that serves a meal EOS',
#  'BOS of all airlines which airline has the most arrivals in atlanta EOS',
#  'BOS display all flights from baltimore to boston on july twenty ninth EOS',
#  'BOS i want to travel from atlanta to baltimore early in the morning first flight EOS',
#  'BOS i now need a flight from san jose to houston leaving on sunday the fourth EOS',
#  'BOS what are the flights available after 6 pm between san francisco and boston EOS',
#  'BOS what flights depart baltimore on friday and arrive in san francisco by 8 pm EOS',
#  'BOS show me flights from boston to san francisco EOS',
#  'BOS list the delta airlines flights from boston to philadelphia EOS',
#  'BOS show me the fares from dallas to san francisco EOS',
#  "BOS what nonstop flights between boston and washington arrive after 4 o'clock pm EOS",
#  'BOS what is the distance from los angeles international airport to los angeles EOS',
#  'BOS ground transportation in san jose EOS',
#  'BOS please tell me how many nonstop flights there are from boston to atlanta EOS',
#  'BOS on the earliest flight from san francisco to atlanta on delta is a meal being served EOS',
#  'BOS where does canadian airlines international fly EOS',
#  'BOS what flights from denver to pittsburgh arrive before 8 in the morning EOS',
#  'BOS find me the earliest flight from boston to atlanta EOS',
#  'BOS list nonstop flights from houston to dallas which arrive before midnight EOS',
#  'BOS show me the flights from boston to san francisco that stop in atlanta EOS',
#  'BOS show me flights to san francisco from philadelphia stopping in dallas EOS',
#  'BOS what city is the airport mco in EOS',
#  'BOS how much does it cost to rent a car in tacoma EOS',
#  'BOS show me flights from baltimore to dallas EOS',
#  'BOS show me a list of ground transportation at denver EOS',
#  "BOS i 'd like a flight from columbus to phoenix stopping in cincinnati and serving dinner what 's available EOS",
#  'BOS also show me flights from san francisco to pittsburgh on tuesday EOS',
#  'BOS show flights from dallas to oakland EOS',
#  'BOS give me the cheapest flight from charlotte to long beach EOS',
#  'BOS show me all flights from san francisco to pittsburgh EOS',
#  'BOS find me a flight on united from boston to san francisco with a stopover in denver EOS',
#  'BOS show me the last flight from love field EOS',
#  'BOS what flights go from newark to boston after 5 pm EOS',
#  'BOS what are all the flights from boston to dallas EOS',
#  'BOS what is the earliest flight departing san francisco and arriving in boston on november ninth EOS',
#  'BOS what is the earliest flight flying from pittsburgh to atlanta on july fifth EOS',
#  'BOS please list available flights for next saturday from philadelphia to dallas EOS',
#  'BOS what flights leave pittsburgh and arrive in los angeles after 5 pm on thursday EOS',
#  'BOS what is the transportation time from the airport to boston EOS',
#  'BOS which airline has the smallest plane leaving pittsburgh and arriving in baltimore on july fourth EOS',
#  'BOS what are the nonstop flights on america west or southwest air from kansas city to burbank on saturday may twenty two EOS',
#  'BOS what are the classes of service for american airlines EOS',
#  'BOS i would like to find out what flights there are on friday june eleventh from st. petersburg to milwaukee and then from milwaukee to tacoma thank you EOS',
#  'BOS all flights from boston to washington dc on november tenth EOS',
#  'BOS what are the flights from denver to san francisco EOS',
#  'BOS on the 8 am flight from san francisco to atlanta what type of aircraft is used EOS',
#  'BOS which flight is a one way fare at 329 dollars from denver to pittsburgh EOS',
#  "BOS what flights leave baltimore for boston after 6 o'clock on friday EOS",
#  'BOS okay i need to get a flight from houston to seattle EOS',
#  'BOS please list flights between denver and boston EOS',
#  'BOS find me the flights that are nonstop between boston and dallas that leave between 12 and 2 in the afternoon EOS',
#  'BOS i would like some information on flights leaving boston to atlanta EOS',
#  'BOS show me the latest nonstop flight from denver to washington dc EOS',
#  'BOS what are the flights from dallas to baltimore EOS',
#  'BOS i would like a nonstop flight from new york to las vegas on march second EOS',
#  'BOS no i want to go from denver to oakland EOS',
#  'BOS show me all the night fares between philadelphia and san francisco EOS',
#  'BOS what kinds of ground transportation is available in dallas fort worth EOS',
#  'BOS can you show me economy class one way fares for flights from oakland to dallas on december sixteenth EOS',
#  'BOS what is fare code qw EOS',
#  "BOS i 'd like a flight on july ninth from orlando to kansas city in the afternoon EOS",
#  'BOS what are the coach fares from charlotte to la wednesday night EOS',
#  'BOS is there ground transportation available in denver EOS',
#  'BOS show me flights from philadelphia to oakland on friday EOS',
#  "BOS i would like to know the flights available from boston to denver arriving in denver by 8 o'clock wednesday morning EOS",
#  'BOS i would like to fly the cheapest rate available from pittsburgh to atlanta on wednesday morning EOS',
#  'BOS list the flight from philadelphia to san francisco on american airlines EOS',
#  'BOS flights from memphis to las vegas on sunday EOS',
#  'BOS what is the first flight from atlanta to boston on thursday september fifth that leaves after 8 am EOS',
#  'BOS what is the first class fare on united flight 352 from denver to boston EOS',
#  'BOS flight from philadelphia to dallas arriving before 4 pm on saturday EOS',
#  'BOS list flights tomorrow from san diego to phoenix EOS',
#  'BOS show me all flights from san francisco to washington dc area EOS',
#  'BOS sure i want to go from philadelphia to dallas EOS',
#  'BOS show me all the united airlines flights leaving dallas EOS',
#  'BOS can you list all the flights between phoenix and las vegas EOS',
#  'BOS list all flights from baltimore to philadelphia EOS',
#  'BOS round trip flights from minneapolis to san diego coach economy fare EOS',
#  "BOS i want to fly from boston to denver and i don 't want any stopovers and i 'd like to fly only during the afternoon EOS",
#  'BOS flights from denver to baltimore between 10 am and 2 pm EOS',
#  'BOS show me the flights from denver to atlanta EOS',
#  'BOS what flights are there on delta from boston to dallas EOS',
#  'BOS what kind of ground transportation can you offer me in seattle EOS',
#  'BOS leaving washington going to san francisco the latest flight EOS',
#  'BOS show me the flights available from atlanta to baltimore leaving atlanta in the morning EOS',
#  'BOS round trip fares new york to san jose EOS',
#  'BOS which flights are serviced by american airlines EOS',
#  'BOS how do i get from pittsburgh airport to downtown pittsburgh EOS',
#  'BOS does midwest express serve charlotte EOS',
#  'BOS what flights from houston to milwaukee on friday in the evening on american airlines EOS',
#  'BOS what is the earliest flight going from san francisco to dallas on monday august nineteenth EOS',
#  'BOS what flights from atlanta to st. louis on tuesday arriving around 230 pm EOS',
#  'BOS i need a flight from kansas city to chicago that leaves wednesday and arrives in chicago around 7 pm EOS',
#  'BOS i would like information on any flights from pittsburgh to san francisco leaving thursday evening EOS',
#  'BOS i need a cheap flight from baltimore to san francisco EOS',
#  'BOS what is the cost of a first class ticket from baltimore to dallas EOS',
#  'BOS what is the economy thrift fare from boston to washington EOS',
#  'BOS list the nonstop flights early tuesday morning from dallas to atlanta EOS',
#  'BOS what is the earliest flight you have that leaves philadelphia to dallas EOS',
#  'BOS are there any flights from dallas fort worth to boston leaving before 10 am EOS',
#  "BOS show me all the flights to baltimore after 6 o'clock pm EOS",
#  'BOS i need a return flight from philadelphia to boston EOS',
#  'BOS united airlines flights stopping in denver before noon EOS',
#  'BOS show me the car rentals in baltimore EOS',
#  'BOS what flights go from newark to boston after 1024 in the morning EOS',
#  'BOS shortest evening flight from tampa to cincinnati EOS',
#  'BOS how much time does it take to go between the airport and downtown by ground transportation in dallas EOS',
#  'BOS flights from boston to pittsburgh EOS',
#  "BOS i 'd like to fly continental airlines between boston and philadelphia EOS",
#  'BOS i would like to book a flight on continental airlines from chicago to seattle on june first EOS',
#  'BOS all flights from pittsburgh to dallas round trip after 12 pm less than 100 EOS',
#  'BOS show me flights on sunday going from san francisco to boston nonstop first class leaving after 12 noon EOS',
#  'BOS from las vegas to phoenix EOS',
#  'BOS show me flights from pittsburgh to atlanta on monday afternoon EOS',
#  'BOS show me the flight with the smallest seating capacity which leaves pittsburgh and arrives in baltimore on june fourteenth EOS',
#  'BOS show all flights from boston to denver on july thirty first EOS',
#  'BOS are there any flights before 12 noon on june fifteenth from long beach to columbus EOS',
#  'BOS list daily flights from boston to atlanta EOS',
#  'BOS on a flight from san francisco to atlanta that leaves before 8 am is there such a flight EOS',
#  'BOS on united airlines give me the flight times from boston to dallas EOS',
#  'BOS ground transportation minneapolis EOS',
#  'BOS show me airline abbreviations EOS',
#  'BOS how many flights does delta have with a class of service code f EOS',
#  'BOS please list all the arriving and departing flights from general mitchell international EOS',
#  'BOS i would like to see the flights from denver to philadelphia please EOS',
#  'BOS does eastern airlines fly early in the morning between logan and bwi EOS',
#  'BOS what flights leave phoenix on american airlines EOS',
#  'BOS can you list all the airlines that have flights from boston to san francisco EOS',
#  'BOS flights from nashville to orlando daily EOS',
#  'BOS show me first class flights from pittsburgh to san francisco on friday EOS',
#  'BOS i need the earliest flight from denver to boston that serves dinner EOS',
#  'BOS from toronto to atlanta in the afternoon EOS',
#  'BOS please list the friday afternoon flights from san jose to dallas on american airlines EOS',
#  'BOS is there ground transportation in boston from the airport EOS',
#  'BOS show first flight from pittsburgh to atlanta on wednesday EOS',
#  "BOS i 'm sorry i wanted to fly twa is there a flight between oakland and boston with a stopover in dallas fort worth on twa EOS",
#  'BOS show me all flights from san francisco to la guardia nonstop EOS',
#  'BOS what flights are there from pittsburgh to los angeles EOS',
#  'BOS what kind of ground transportation is there in washington dc EOS',
#  'BOS what is the least expensive flight available from dallas fort worth to san francisco EOS',
#  'BOS what does the fare code f mean EOS',
#  "BOS what 's the most expensive way i can fly to washington EOS",
#  'BOS what flights from houston to milwaukee on friday on american airlines EOS',
#  'BOS what is the schedule of ground transportation from the airport in philadelphia into downtown EOS',
#  'BOS show me a list of flights from san francisco to boston for august thirtieth EOS',
#  'BOS show me the least expensive flight from miami to cleveland on sunday after noon EOS',
#  'BOS how much does it cost to go from downtown to logan airport EOS',
#  'BOS what flights are there from newark to tampa EOS',
#  'BOS i want a flight from philadelphia to dallas that at least has one stop EOS',
#  "BOS show flights from denver to oakland arriving between 12 and 1 o'clock EOS",
#  'BOS what is the fare from san francisco to dallas fort worth on delta flight 852 EOS',
#  'BOS flights from newark new jersey to cleveland ohio EOS',
#  'BOS give me flights from denver to baltimore EOS',
#  'BOS show the flights from denver to san francisco EOS',
#  'BOS show me flights denver to washington dc on thursday EOS',
#  'BOS please list the thursday morning flights from st. louis to st. paul EOS',
#  'BOS what flight do you have from pittsburgh to san francisco on the morning of august twenty seventh EOS',
#  'BOS what are the flights from boston to atlanta EOS',
#  'BOS what flights from baltimore to san francisco arrive before 8 pm in san francisco EOS',
#  'BOS show me the flights from pittsburgh to san francisco for thursday night or friday EOS',
#  'BOS get me a first class flight on american to san francisco on tuesday next week EOS',
#  'BOS ground transportation in westchester county EOS',
#  'BOS what flights are there from atlanta to baltimore EOS',
#  "BOS i 'd like to fly from dallas to san francisco at approximately 615 pm EOS",
#  'BOS list the fares of us air flights from boston to philadelphia EOS',
#  'BOS list flights from phoenix to detroit on thursday june twenty fourth EOS',
#  'BOS what flights from miami to indianapolis on sunday EOS',
#  'BOS now show me the flights from memphis to cleveland EOS',
#  'BOS can you give me information on all the flights from san francisco no from pittsburgh to san francisco on monday EOS',
#  'BOS could you find me a flight from boston to san francisco that stops in denver EOS',
#  'BOS flights from cleveland to miami EOS',
#  'BOS give me the flights from pittsburgh to los angeles thursday evening EOS',
#  'BOS please list all of the flights leaving atlanta heading to baltimore after 8 pm wednesday and before 9 am thursday EOS',
#  'BOS show me flights from seattle to san francisco that leave after 5 pm EOS',
#  'BOS show me the flights that go from tacoma to miami EOS',
#  'BOS which airline can fly me from atlanta to denver to san francisco EOS',
#  'BOS are there any flights from denver to pittsburgh with stops in atlanta EOS',
#  'BOS list all the flights that arrive at general mitchell international EOS',
#  'BOS what is fare code h EOS',
#  'BOS what flights from salt lake city to new york city arrive next saturday before 6 pm EOS',
#  'BOS flights from nashville to seattle EOS',
#  'BOS show me fares from seattle to minneapolis EOS',
#  'BOS i need a flight from boston to san francisco via dallas fort worth EOS',
#  "BOS i 'd like an afternoon flight from atlanta to san francisco with a stopover in denver arriving i 'd say about mealtime EOS",
#  'BOS show me the most expensive one way flight from detroit to westchester county EOS',
#  'BOS show me the flights from baltimore to philadelphia EOS',
#  'BOS from denver to washington dc on monday november eleventh 1991 EOS',
#  'BOS please list all the flights from boston to denver which serve meals EOS',
#  'BOS list aircraft types that fly between boston and san francisco EOS',
#  'BOS what does fare code qw mean EOS',
#  "BOS i 'm interested in a flight on american airlines from dallas to washington EOS",
#  'BOS give me flights from pittsburgh to baltimore EOS',
#  'BOS how much is a round trip fare from indianapolis to seattle EOS',
#  'BOS what is the cheapest flight from long beach to memphis EOS',
#  'BOS which airline provides business class flights EOS',
#  'BOS pittsburgh to denver EOS',
#  'BOS which airlines fly between boston and pittsburgh EOS',
#  'BOS list the flights arriving in atlanta from baltimore before noon on august fourth EOS',
#  'BOS give me the flights for american airline from philadelphia to dallas EOS',
#  'BOS i need a flight this sunday from miami to las vegas and i would prefer a morning flight EOS',
#  'BOS flights from boston to pittsburgh EOS',
#  'BOS which flights go from pittsburgh to atlanta in the evening EOS',
#  'BOS show me the fares from dallas to san francisco EOS',
#  'BOS give me american airlines flights from milwaukee to phoenix on saturday and on sunday EOS',
#  'BOS list all flights that leave from baltimore or denver or pittsburgh and arrive in philadelphia EOS',
#  'BOS show me the flights from baltimore to oakland EOS',
#  'BOS show me the earliest flight from denver to las vegas EOS',
#  'BOS show me flights from milwaukee to orlando on wednesday night EOS',
#  'BOS may i have a listing of flights from milwaukee to tacoma washington departing in the evening EOS',
#  'BOS what morning flights do you have between oakland and denver EOS',
#  "BOS i 'd like a flight from washington that stops in denver and goes on to san francisco EOS",
#  'BOS show me all flights from pittsburgh to baltimore tomorrow EOS',
#  'BOS all one way flights between boston and philadelphia EOS',
#  'BOS what flights go to san francisco from boston EOS',
#  'BOS what flights are there from san francisco to philadelphia daily with economy class EOS',
#  'BOS first flights from pittsburgh to atlanta on a thursday EOS',
#  'BOS show me the flights from baltimore to atlanta EOS',
#  'BOS tell me about flights from toronto to salt lake city leaving after 530 pm EOS',
#  'BOS show me the flights from indianapolis to orlando with round trip fares less than 1288 EOS',
#  'BOS i need a flight from boston to pittsburgh that leaves early in the morning EOS',
#  'BOS what is the first flight from atlanta to baltimore that serves lunch EOS',
#  'BOS show me the flights from pittsburgh to baltimore EOS',
#  'BOS all flights from denver to philadelphia EOS',
#  'BOS oakland to philadelphia saturday EOS',
#  'BOS give me the earliest flight tomorrow on united airlines from st. petersburg to milwaukee EOS',
#  'BOS show me flights on monday from philadelphia to boston after 7 am EOS',
#  'BOS show me all the flights leaving baltimore EOS',
#  'BOS show me the flights from philadelphia to boston EOS',
#  'BOS is there a plane from boston to washington EOS',
#  'BOS i need to go from boston to atlanta and back in the same day find me the earliest flight from boston EOS',
#  'BOS what are flights between boston and pittsburgh on august tenth EOS',
#  'BOS what are the schedule of flights from boston to san francisco for august first EOS',
#  'BOS show me one way flights from milwaukee to orlando wednesday EOS',
#  'BOS show me all flights from pittsburgh to baltimore tomorrow which serve a meal EOS',
#  'BOS give me flights on american airlines from milwaukee to phoenix EOS',
#  'BOS show all flights from pittsburgh to san francisco EOS',
#  'BOS i wish to fly from boston to washington please find an airline for me EOS',
#  'BOS please list the flights from dallas fort worth to dc baltimore on july twenty third EOS',
#  'BOS which flights from memphis to tacoma also stop in los angeles EOS',
#  'BOS show me the flights on tuesday morning from charlotte to baltimore EOS',
#  'BOS i need 2 first class tickets from dallas fort worth to san francisco EOS',
#  'BOS are there any flights from philadelphia to dallas which stop in atlanta EOS',
#  'BOS flights to baltimore EOS',
#  'BOS what does mco stand for EOS',
#  'BOS what is the least expensive way to fly from philadelphia to san francisco EOS',
#  'BOS list all nonstop flights from los angeles to pittsburgh before 5 pm on tuesday EOS',
#  'BOS how many booking classes are there EOS',
#  'BOS flight numbers from columbus to minneapolis tomorrow EOS',
#  'BOS give me the continental flights from chicago to seattle on friday EOS',
#  'BOS what are the united airlines flights between baltimore and denver on august twelfth EOS',
#  'BOS show me the flights next tuesday between philadelphia and san francisco EOS',
#  'BOS find a flight on american airlines from boston to san francisco that makes a stopover in denver EOS',
#  'BOS show me the fares on all flights round trip from pittsburgh to oakland EOS',
#  "BOS what 's the difference between fare code q and fare code f EOS",
#  'BOS flights from cincinnati to salt lake city EOS',
#  'BOS ground transportation denver EOS',
#  'BOS show me flights from denver to washington dc on wednesdays EOS',
#  'BOS find a flight between denver and oakland the flight should be in the afternoon and arrive close to 5 pm the flight should be nonstop EOS',
#  'BOS show me all flights from atlanta to washington with prices EOS',
#  'BOS flights between new york and miami EOS',
#  'BOS please list the monday morning flights from kansas city to atlanta EOS',
#  'BOS list all american airlines flights from phoenix to milwaukee which arrive on wednesday after 4 pm EOS',
#  'BOS what round trip tickets are there from cleveland to miami on us air that arrive before 4 pm EOS',
#  "BOS i 'd like to go from boston to denver at 9 o'clock saturday night EOS",
#  'BOS show me the northwest flights from detroit to st. petersburg EOS',
#  'BOS what is the available ground transportation between the airport in denver and downtown EOS',
#  'BOS on may four atlanta to denver delta flight 257 EOS',
#  'BOS show me all flights from indianapolis EOS',
#  'BOS which airlines have flights between philadelphia and pittsburgh EOS',
#  'BOS which are the flights from denver to baltimore or washington dc EOS',
#  'BOS list the number of flights leaving boston for dallas fort worth before 9 am in the morning EOS',
#  'BOS are there delta flights leaving atlanta EOS',
#  'BOS can you list all round trip flights from orlando to kansas city and then to minneapolis EOS',
#  "BOS i would like to find a flight from kansas city to salt lake city on delta and arriving at about 8 o'clock in the evening could you please tell me the aircraft and the flight number thank you EOS",
#  'BOS i would like a flight from washington to boston leaving at 230 on august twentieth EOS',
#  'BOS how much is a flight from washington to boston EOS',
#  'BOS show me all flights from orlando to san diego on a boeing 737 EOS',
#  'BOS what flights are there on sunday from seattle to minneapolis EOS',
#  'BOS where is mco EOS',
#  'BOS show me all flights from pittsburgh to atlanta EOS',
#  'BOS which united airlines flight flies across this continent and leaves from boston goes to dallas and makes a stopover in philadelphia EOS',
#  'BOS list daily flights of united airline from denver to baltimore with first class service EOS',
#  'BOS show me flights from pittsburgh to atlanta on monday morning EOS',
#  'BOS all flights phoenix to sfo EOS',
#  'BOS i want to travel from washington dc to philadelphia on tuesday morning EOS',
#  'BOS what is the fare going from atlanta to boston one way on november seventh EOS',
#  'BOS is there a flight on american airlines from boston to denver EOS',
#  'BOS what flights are available from san francisco to pittsburgh on thursday evening EOS',
#  'BOS do you have an afternoon flight leaving in the afternoon going from boston to san francisco with a stopover in dallas EOS',
#  'BOS show the flights from pittsburgh to san francisco again on monday EOS',
#  'BOS show me a list of flights on american airlines from boston to dc on july twenty second EOS',
#  "BOS now i 'd like flights from philadelphia to pittsburgh leaving between 430 and 530 pm EOS",
#  'BOS what economy flights are available from dallas to baltimore on december seventeenth EOS',
#  'BOS please show me flights from san francisco to dallas EOS',
#  'BOS please show me all the flights from indianapolis to san diego tomorrow EOS',
#  'BOS what does flight code us mean EOS',
#  'BOS i would like a flight from denver to pittsburgh EOS',
#  'BOS what is the flight schedule of the f28 from pittsburgh to baltimore EOS',
#  'BOS looking for a flight from dc to minnesota EOS',
#  'BOS how many us air flights leave from washington EOS',
#  'BOS show me times for flights from san francisco to atlanta EOS',
#  'BOS what flights are there on wednesday evening or thursday morning from denver to sfo EOS',
#  'BOS how many flights go from dallas to baltimore on july nineteenth EOS',
#  'BOS could you show me all the flights from oakland to salt lake city EOS',
#  'BOS find me a flight from boston to san francisco with layover in denver on united EOS',
#  'BOS what flights are available between boston and washington arriving in washington at 630 EOS',
#  'BOS show me the airlines between toronto and denver EOS',
#  'BOS what flights do you have between pittsburgh and atlanta EOS',
#  'BOS show me the flights from denver to westchester county EOS',
#  'BOS i need information for a flight from denver to atlanta EOS',
#  'BOS what is the cheapest flight from boston to atlanta EOS',
#  'BOS what is the cheapest flight from atlanta to pittsburgh one way EOS',
#  'BOS show me all overnight flights from washington dc to san francisco and list their fares EOS',
#  'BOS round trip flights between new york and miami EOS',
#  'BOS show me the one way flight from detroit to westchester county with the highest fare EOS',
#  'BOS what flights are there from newark to chicago on continental EOS',
#  "BOS i 'm trying to make a connection between denver and san francisco does delta airline fly between those two EOS",
#  'BOS what is the latest us air flight leaving philadelphia and returning to boston EOS',
#  'BOS what flights does us air have from san francisco to pittsburgh on tuesday EOS',
#  'BOS can i fly from boston to baltimore washington EOS',
#  'BOS what is mco EOS',
#  'BOS flights from las vegas to phoenix EOS',
#  "BOS i would like to leave around 7 o'clock in the morning EOS",
#  'BOS show me fares from baltimore to philadelphia EOS',
#  'BOS flights from memphis to seattle EOS',
#  'BOS please show me flights from pittsburgh to atlanta on wednesday morning serving breakfast EOS',
#  'BOS flights from atlanta august second EOS',
#  'BOS does american airlines fly from atlanta to philadelphia EOS',
#  "BOS yes i 'd like a flight from long beach to st. louis by way of dallas EOS",
#  "BOS i 'd like to know if you have any flights from denver to philadelphia EOS",
#  'BOS what are the cheapest one way flights from atlanta to denver EOS',
#  'BOS what is the first flight after 12 noon from washington for denver EOS',
#  'BOS how many delta flights leave from washington EOS',
#  'BOS now list for me only the united flights that flight from oakland to boston EOS',
#  'BOS from philadelphia to toronto EOS',
#  'BOS i am interested in a flight on american airlines from dallas to washington EOS',
#  'BOS what airplane types fly from pittsburgh to baltimore EOS',
#  'BOS what is the yn code EOS',
#  'BOS i would like the earliest morning flight from atlanta to philadelphia on wednesday morning EOS',
#  'BOS how many seats in a 100 EOS',
#  'BOS may i have a listing of flights from long beach to columbus ohio on tuesday EOS',
#  'BOS what flights leave from phoenix to nashville on american airlines EOS',
#  'BOS show me all round trips from new york to miami leaving on tuesday EOS',
#  'BOS list all nonstop flights on sunday from tampa to charlotte EOS',
#  'BOS list all flights from burbank to denver EOS',
#  'BOS what are the round trip fares for flights from denver to philadelphia arriving after 1700 on continental EOS',
#  "BOS i 'd like to see flights from baltimore to atlanta EOS",
#  'BOS please show me the flights from las vegas to detroit on the twenty eighth EOS',
#  'BOS what is ord EOS',
#  'BOS what type of ground transportation is available between the airport and downtown san francisco EOS',
#  'BOS is the american flight 813 from boston to oakland a nonstop flight EOS',
#  'BOS give me the flights from washington dc to philadelphia for december second EOS',
#  'BOS show all connecting flights from pittsburgh to oakland EOS',
#  'BOS list daily flights from boston to oakland using twa EOS',
#  'BOS i would like the least expensive airfare flight on sunday to pittsburgh from san francisco EOS',
#  'BOS i need a flight from san diego to indianapolis leaving in the afternoon on tuesday EOS',
#  'BOS can you give me the evening flight on wednesday from washington to atlanta again EOS',
#  'BOS i would like to book a flight from los angeles to pittsburgh on june first EOS',
#  'BOS what flights from atlanta to washington EOS',
#  'BOS show me all flights direct only from boston to san francisco or oakland that arrive before 10 am local time EOS',
#  'BOS first class round trip airfare from indianapolis to memphis EOS',
#  'BOS flights from cincinnati to denver on american airlines EOS',
#  'BOS list all flights on continental leaving denver on sunday after 2134 EOS',
#  'BOS show me all flights from charlotte EOS',
#  'BOS show me all nationair flights from toronto EOS',
#  'BOS what are the fares from newark to la monday and wednesday EOS',
#  'BOS show me flights from denver to atlanta on june sixteenth EOS',
#  'BOS please show me round trip tickets from denver to oakland EOS',
#  'BOS list all flights on united from san francisco to boston with fare code qx EOS',
#  'BOS how many flights does twa have in business class EOS',
#  "BOS list all flights going from boston to atlanta after 6 o'clock on wednesday and before 7 o'clock am on thursday EOS",
#  'BOS show me the flights to love field EOS',
#  'BOS show me flights from pittsburgh to philadelphia EOS',
#  'BOS show me the flights from philadelphia to atlanta EOS',
#  'BOS philadelphia to dallas arriving before 1 in the afternoon EOS',
#  'BOS i need a flight from tampa to montreal EOS',
#  'BOS please give me flights leaving san francisco and going to pittsburgh EOS',
#  'BOS what do you have from philadelphia to dallas on saturday morning EOS',
#  'BOS flight leaving from oakland to salt lake city EOS',
#  'BOS tell me about flights on american airlines from dallas fort worth to philadelphia on june twenty ninth EOS',
#  'BOS list all flights from boston to san francisco with the maximum number of stops EOS',
#  'BOS are there any flights from atlanta to denver EOS',
#  'BOS what are the flights dallas to boston on monday morning EOS',
#  'BOS show me flights leaving from denver colorado to pittsburgh pennsylvania on wednesdays after 5 pm EOS',
#  'BOS i need flight information between atlanta and boston EOS',
#  'BOS what are my choices of flights from las vegas to new york EOS',
#  'BOS what is the cheapest flight from boston to san francisco EOS',
#  'BOS on continental airlines any class service from san francisco to pittsburgh EOS',
#  'BOS find the cheapest flight from denver to atlanta with a stopover in pittsburgh EOS',
#  'BOS what are the lowest one way fares from atlanta to denver EOS',
#  'BOS are there any flights from boston to san francisco stopping in denver EOS',
#  'BOS flights from kansas city to cleveland on wednesday EOS',
#  'BOS how much is a round trip fare from memphis to seattle EOS',
#  'BOS show me the flights into love field EOS',
#  "BOS i 'd like to fly from philadelphia to dallas through atlanta EOS",
#  'BOS information on flights from pittsburgh to philadelphia EOS',
#  'BOS what flights does american airlines fly from philadelphia to dallas EOS',
#  "BOS i want to travel from kansas city to chicago round trip leaving wednesday june sixteenth arriving in chicago at around 7 o'clock in the evening and returning the next day arriving in kansas city at around 7 o'clock in the evening which airlines fly that route EOS",
#  'BOS i would like the time of all flights from san francisco to pittsburgh on sunday EOS',
#  'BOS show me ground transportation in dallas please EOS',
#  'BOS are there any nonstop flights leaving from denver arriving in baltimore on july seventh EOS',
#  'BOS how much does dl 746 cost EOS',
#  'BOS what is the earliest flight from boston to san francisco on american airlines EOS',
#  'BOS please list ground transport in san francisco EOS',
#  'BOS i need a flight from ontario to los angeles on a thursday EOS',
#  'BOS show me flights from all airports to love field EOS',
#  'BOS list the flights from pittsburgh to san francisco on thursday EOS',
#  'BOS what flights are available from denver to baltimore first class on united airlines arriving may seventh before noon EOS',
#  'BOS which airlines are represented in the database EOS',
#  'BOS which flight between pittsburgh and baltimore on july nineteenth has the smallest seating capacity EOS',
#  'BOS list all trans world airline flights from indianapolis to houston that arrive in houston between 1030 am and 1130 am EOS',
#  'BOS what flights are there from new york city to las vegas EOS',
#  'BOS is there ground transportation from san diego airport to the downtown area EOS',
#  'BOS shortest morning flights from cincinnati to tampa EOS',
#  "BOS what 's the last flight from houston to dallas EOS",
#  'BOS is there a flight from charlotte to newark on tuesday evening EOS',
#  'BOS what is airline us EOS',
#  "BOS what 's the lowest round trip fare from dallas to atlanta EOS",
#  'BOS find me the earliest flight from boston to atlanta on any day of the week EOS',
#  'BOS display all flights from boston to baltimore on july thirty first EOS',
#  'BOS economy fares new york to miami round trip EOS',
#  'BOS i need to fly from boston to denver on to san francisco and back EOS',
#  'BOS i wish to book a flight from pittsburgh to atlanta coach discount fare EOS',
#  'BOS show me flights to dallas from san francisco and atlanta and pittsburgh EOS',
#  'BOS tell me distance from orlando airport to the city EOS',
#  'BOS hi i need to get a flight from memphis to salt lake city departing before 10 am EOS',
#  'BOS what is the cheapest fare i can get from dallas to denver EOS',
#  'BOS i would like a flight from philadelphia to dallas arrive dallas about 12 noon EOS',
#  'BOS us air next wednesday from cleveland to miami EOS',
#  'BOS could you please find me the cheapest one way fare from boston to philadelphia EOS',
#  "BOS i 'd like a flight from detroit to st. petersburg for tuesday EOS",
#  'BOS return from miami to new york on tower air on saturdays EOS',
#  'BOS show me ground transportation in san francisco EOS',
#  'BOS please give me the earliest flight tomorrow from st. petersburg to milwaukee EOS',
#  "BOS i need ground transportation in dallas please show me what 's available EOS",
#  "BOS what 's fare code yn EOS",
#  'BOS the cheapest flights from atlanta to philadelphia that arrive after 12 pm on a tuesday EOS',
#  'BOS is there an early morning delta airlines flight between boston and washington EOS',
#  'BOS what flights from orlando to tacoma on saturday EOS',
#  'BOS show me all flights both direct and connecting from dallas fort worth to either san francisco or oakland that depart after 7 pm EOS',
#  'BOS give me flights from chicago to seattle on saturday morning EOS',
#  'BOS okay tell me what the earliest flight is that leaves between atlanta and denver EOS',
#  'BOS i want a flight from toronto to montreal that leaves early friday morning EOS',
#  'BOS what first class flights are available from denver to baltimore on july twenty fifth 1991 EOS',
#  'BOS show me the airlines from love field EOS',
#  "BOS what 's the cheapest one way ticket from baltimore to atlanta EOS",
#  'BOS a first class flight on american to san francisco on tuesday in the next week EOS',
#  'BOS what airlines fly between boston and san francisco and stop in denver EOS',
#  "BOS what 're the flights from new york city to las vegas that arrive on a sunday EOS",
#  'BOS flights on friday from newark to tampa EOS',
#  'BOS flights from san francisco august one EOS',
#  'BOS how many stops on continental 1765 from boston to san francisco EOS',
#  'BOS on flight us air 2153 from san francisco to baltimore what time and what city does the plane stop in between EOS',
#  'BOS i need a flight from st. petersburg to charlotte which will get me into charlotte by 5 pm or as soon thereafter as possible EOS',
#  'BOS i want a one way ticket from dallas to baltimore EOS',
#  'BOS find me the latest flight leaving atlanta august seventh and arriving in denver EOS',
#  "BOS what 's the lowest one way fare from pittsburgh to denver EOS",
#  'BOS show me flights from los angeles to pittsburgh on monday evening EOS',
#  'BOS show me the flights from san francisco to washington dc EOS',
#  'BOS show me flights from pittsburgh to philadelphia EOS',
#  'BOS show me the shortest flight from boston to denver which arrives in denver wednesday before noon EOS',
#  'BOS what are the flights from orlando to kansas city EOS',
#  'BOS show me flights from san francisco to boston on thursday EOS',
#  'BOS sunday flights from new york city to las vegas EOS',
#  'BOS i need a flight from pittsburgh to new york leaving at 5 pm EOS',
#  "BOS what 's the smallest plane that flies from pittsburgh to baltimore on eight sixteen EOS",
#  'BOS give me the flights on december twenty seventh with the fares from indianapolis to orlando EOS',
#  'BOS show me all the us air flights leaving pittsburgh between 12 and 4 in the afternoon EOS',
#  'BOS i want a cheap from denver to atlanta EOS',
#  'BOS show all flights from miami to jfk EOS',
#  'BOS show me all flights from san francisco to pittsburgh on a monday EOS',
#  'BOS show me the earliest flight from boston to denver EOS',
#  'BOS i need a united airlines flight from denver to baltimore on saturday EOS',
#  'BOS what are the cheapest one way flights from denver to atlanta EOS',
#  'BOS all flights from boston to washington dc after 5 pm on november eleventh economy class EOS',
#  'BOS is there ground transportation in oakland EOS',
#  'BOS list united flights from denver to san francisco on wednesdays EOS',
#  'BOS what is the cheapest way to fly from denver to oakland EOS',
#  'BOS philadelphia to san francisco with one stop in dallas please EOS',
#  'BOS i would like to fly us air from orlando to cleveland in the late evening what do you have available EOS',
#  'BOS what does restriction ap 57 mean EOS',
#  'BOS what are the latest flights that i can take from baltimore to boston EOS',
#  'BOS list flights from philadelphia to san francisco via dallas EOS',
#  'BOS how much does the american airlines flight 71 from dallas to san francisco cost EOS',
#  'BOS all flights from boston to philadelphia which show up on tuesday afternoon EOS',
#  'BOS show me flights from new york to miami on a tuesday with a round trip fare less than 466 dollars EOS',
#  'BOS nonstop flights from seattle to denver EOS',
#  'BOS give me the flights and fares on december twenty seventh from indianapolis to orlando EOS',
#  'BOS what flights are available wednesday afternoon from denver to san francisco EOS',
#  'BOS what are the flights from tacoma to san jose also on tuesday the eighteenth of may EOS',
#  "BOS what 's the ground transportation like at pittsburgh EOS",
#  'BOS list daily flights from boston to oakland using united airlines EOS',
#  'BOS in the next two days i want to fly from nashville to san jose or to tacoma EOS',
#  'BOS how many flights does each airline have with business class service EOS',
#  'BOS what flights from st. paul to kansas city on friday with supper served EOS',
#  'BOS show flights from san francisco to denver on either wednesday the twenty third or thursday the twenty fourth EOS',
#  'BOS what are the flights available between 10 am and 3 pm between pittsburgh and fort worth EOS',
#  'BOS list all flights from memphis to seattle EOS',
#  'BOS airline code as EOS',
#  'BOS show me the flights from san francisco to boston EOS',
#  'BOS show me all flights from san diego to phoenix on a boeing 737 EOS',
#  'BOS may i have a list of flights going from boston to denver on the twenty ninth of july EOS',
#  'BOS could you tell me the cheapest fare from atlanta to boston on thirty first of august EOS',
#  'BOS which united airlines flight flies from boston to san francisco and makes a stopover in philadelphia EOS',
#  'BOS what are the latest flights from boston to dallas on the evening of july seventh EOS',
#  'BOS can you tell me how to get from the airport in philadelphia to downtown EOS',
#  'BOS what is bna EOS',
#  'BOS now show me the flights from denver to atlanta EOS',
#  'BOS what is the cost of flight dl 106 from philadelphia to boston EOS',
#  'BOS what stops does dl 838 make from san francisco to atlanta EOS',
#  'BOS what are the cheapest round trip flights from denver to atlanta EOS',
#  'BOS what are the flights from atlanta to dallas EOS',
#  'BOS delta flights to san francisco please EOS',
#  'BOS i would like to know the latest flight on wednesday you have leaving from oakland to salt lake city which offers a meal EOS',
#  'BOS what are the costs of car rental in dallas EOS',
#  'BOS what airlines fly from boston to pittsburgh EOS',
#  'BOS can you tell me which flights go from memphis to tacoma and make a stop in los angeles EOS',
#  'BOS what is the cheapest round trip fare between boston and san francisco EOS',
#  'BOS show me ground transportation information for pittsburgh EOS',
#  'BOS all flights and fares from atlanta to dallas round trip after 12 pm less than 1100 dollars EOS',
#  'BOS what is the fare from boston to oakland on united airlines EOS',
#  'BOS show me the latest flight from salt lake city to phoenix EOS',
#  'BOS show me all the eastern airlines flights leaving pittsburgh between 12 and 4 in the afternoon EOS',
#  'BOS show me flights from denver to philadelphia EOS',
#  'BOS flights from newark to boston EOS',
#  'BOS what is the first flight from atlanta to boston leaving on thursday september fifth EOS',
#  'BOS all united airlines flights with stopovers in denver EOS',
#  'BOS show flights from boston to denver on wednesday morning EOS',
#  'BOS show me all the twa flights from indianapolis to houston that arrive around 11 am EOS',
#  'BOS show me the direct flights from san francisco to boston EOS',
#  "BOS i 'd like to find the cheapest flight from boston to san francisco EOS",
#  'BOS show me round trip fares from denver to philadelphia EOS',
#  'BOS i want to go from denver to atlanta round trip and make a stop at pittsburgh is this possible EOS',
#  'BOS please tell me which airline has the most departures from atlanta EOS',
#  'BOS what are the flights from atlanta to baltimore EOS',
#  'BOS show me round trip fares from san jose to salt lake city EOS',
#  'BOS explain the restriction ap 80 EOS',
#  'BOS show me the flights from salt lake city to milwaukee EOS',
#  'BOS show me us air fares for next sunday from miami to cleveland EOS',
#  'BOS list a round trip fare from kansas city to minneapolis flights EOS',
#  'BOS show me flights from pittsburgh to san francisco EOS',
#  'BOS show me all flights from baltimore to dallas EOS',
#  'BOS can you show me the cheapest round trip flights between denver and pittsburgh EOS',
#  'BOS how many passengers fit on a d9s EOS',
# ...
#  'BOS what are the first class and coach fares for flights from chicago to kansas city arriving around 7 pm next thursday EOS',
#  "BOS show me all flights from dallas to pittsburgh on monday which leave after 8 o'clock pm EOS",
#  'BOS find me the cheapest one way fare i can get from boston to denver EOS',
#  'BOS show me the flights from atlanta to denver on friday EOS',
#  "BOS what 's the cheapest flight from san francisco to boston EOS",
#  'BOS please list the flight times from boston to pittsburgh EOS',
#  'BOS is there a flight between washington dc and san francisco on us air at 8 am EOS',
#  'BOS show me all flights from pittsburgh which leave tomorrow and arrive in boston EOS',
#  'BOS how many seats in a 72s EOS',
#  'BOS what does fn under fare code mean EOS',
#  'BOS all am flights departing pittsburgh arriving denver EOS',
#  'BOS what flights leave after 7 pm from pittsburgh to philadelphia EOS',
#  'BOS show flights from philadelphia to san francisco EOS',
#  'BOS what flights leave chicago and arrive in detroit around 6 pm next tuesday EOS',
#  'BOS what does it cost to fly from boston to oakland on united airlines EOS',
#  'BOS how much is a flight from washington to montreal EOS',
#  'BOS is there limousine service available at baltimore airport EOS',
#  'BOS what are the morning flights in the next two days from nashville to tacoma EOS',
#  'BOS what is the last flight leaving san francisco going to washington on friday EOS',
#  'BOS what are the flights from dallas to san francisco on tuesday october first EOS',
#  'BOS does united airlines fly from boston to dallas fort worth EOS',
#  'BOS please list the flight schedule from baltimore to san francisco on friday nights EOS',
#  'BOS flights from cleveland to kansas city on monday EOS',
#  'BOS i would like to find a flight that goes from boston to orlando i would like it to have a stop in new york and i would like a flight that serves breakfast EOS',
#  'BOS what are the lowest one way fares from atlanta to pittsburgh EOS',
#  "BOS okay and then from pittsburgh i 'd like to travel to atlanta on september fourth EOS",
#  "BOS what flights go from pittsburgh to baltimore after 8 o'clock next wednesday EOS",
#  'BOS how much does it cost to get downtown from the atlanta airport by limousine EOS',
#  'BOS i would like to fly from boston to san francisco EOS',
#  'BOS show me the airfare from pittsburgh to san francisco EOS',
#  'BOS are there any flights on june eleventh from st. petersburg to milwaukee EOS',
#  'BOS what is hp EOS',
#  'BOS show me the type of aircraft that cp uses EOS',
#  'BOS show me flights from pittsburgh to san francisco on sunday EOS',
#  'BOS what type of aircraft does eastern fly from atlanta to denver before 6 pm EOS',
#  'BOS can you list all flights from chicago to milwaukee EOS',
#  'BOS display all flights from denver to san francisco on august seven EOS',
#  'BOS what are the most expensive first class tickets between boston and san francisco EOS',
#  'BOS which of the flights from pittsburgh to baltimore on july twenty fifth 1991 carries the smallest number of passengers EOS',
#  "BOS show me all the flights to baltimore after 6 o'clock pm EOS",
#  'BOS what airlines go from atlanta to baltimore EOS',
#  'BOS what does fare code qo mean EOS',
#  'BOS show me flights from baltimore to dallas EOS',
#  'BOS what does the abbreviation co mean EOS',
#  'BOS can you list all flights between milwaukee and chicago EOS',
#  'BOS what are the air restrictions on flights from pittsburgh to atlanta for the airfare of 416 dollars EOS',
#  'BOS last nonstop flight from los angeles to pittsburgh on monday night EOS',
#  'BOS what is the earliest flight from boston to san francisco EOS',
#  'BOS i would like an early morning flight from chicago into seattle on june first on continental airline EOS',
#  'BOS what would be cost of a round trip from pittsburgh to san francisco EOS',
#  'BOS show me the flights from dallas to baltimore EOS',
#  'BOS give me the flights from baltimore to pittsburgh EOS',
#  'BOS please list the flights from charlotte to long beach arriving after lunch time EOS',
#  'BOS what flights are available between philadelphia and denver on september sixteenth EOS',
#  'BOS what type of aircraft leaving after 2 pm from boston to oakland EOS',
#  'BOS i would like the cheapest flight from boston to san francisco EOS',
#  'BOS are there any flights from boston to oakland that stop EOS',
#  "BOS i would like to find a flight from pittsburgh to boston on wednesday and i have to be in boston by one so i 'd like a flight out of here no later than 11 am EOS",
#  'BOS i need information on a flight from washington to fort worth EOS',
#  'BOS can you tell me what flights you have from baltimore to dallas EOS',
#  'BOS what are the ground transportation services in philadelphia EOS',
#  'BOS give me flights from baltimore to denver on united that offer first class EOS',
#  'BOS does american airlines have a flight from pittsburgh to atlanta EOS',
#  'BOS all flights and fares from atlanta to dallas round trip after 12 pm less than 1100 dollars EOS',
#  'BOS list flights from denver to baltimore EOS',
#  'BOS i would like a list of the round trip flights between indianapolis and orlando on the twenty seventh or the twenty eighth of december EOS',
#  'BOS i need a return flight from denver to atlanta EOS',
#  "BOS i 'd like a flight from burbank to tacoma washington EOS",
#  'BOS what flights from atlanta to washington EOS',
#  'BOS please list all flights from atlanta to baltimore on wednesday and thursday EOS',
#  'BOS what is the latest flight between washington and boston EOS',
#  'BOS explain the restriction ap 57 EOS',
#  "BOS the latest flight from baltimore to oakland please and i 'd like a meal with that EOS",
#  'BOS what are the flights on january first 1992 from boston to san francisco EOS',
#  'BOS on november twenty third what flights are available between boston and denver EOS',
#  'BOS list nonstop flights on sunday from new york to las vegas and list nonstop flights on sunday from memphis to las vegas EOS',
#  'BOS show me the list of flights from dallas to baltimore on american and delta airlines EOS',
#  'BOS what does us stand for EOS',
#  'BOS could you show me all weekday flights from phoenix to denver EOS',
#  'BOS show me all united airlines first class flights EOS',
#  'BOS what is hp EOS',
#  'BOS what is the price of a first class ticket from milwaukee to san francisco round trip EOS',
#  'BOS find a flight on delta from philadelphia to san francisco EOS',
#  "BOS i 'm trying to find the flight number from a flight from orlando to cleveland on us air and it arrives around 10 pm EOS",
#  'BOS what are the costs of flights from dallas to boston tomorrow EOS',
#  'BOS what flights go from philadelphia to dallas via atlanta EOS',
#  "BOS what 's the cheapest round trip fare between boston and washington EOS",
#  'BOS what are the flights between dallas and pittsburgh on july eight EOS',
#  'BOS show me flights from milwaukee to orlando on thursday morning EOS',
#  'BOS what flights are available from boston to dallas EOS',
#  'BOS i want to leave boston at 838 EOS',
#  'BOS kindly give me the type of aircraft used to fly from atlanta to denver EOS',
#  'BOS can you show me flights from dallas to atlanta on tuesday night EOS',
#  'BOS is there ground transportation from atlanta airport to downtown atlanta EOS',
#  'BOS are there any limousines or taxi services available at the boston airport EOS',
#  'BOS on eastern flight 825 flying from atlanta to denver can you tell me what type of aircraft is used on a flight when it leaves at 555 EOS',
#  'BOS how do i get from the airport to downtown in tacoma EOS',
#  'BOS tuesday morning flights between charlotte and baltimore EOS',
#  'BOS show me flights from atlanta to washington EOS',
#  "BOS show me all flights from atlanta to san francisco which leave atlanta after 5 o'clock pm tomorrow EOS",
#  'BOS round trip fares from denver to philadelphia less than 1000 dollars EOS',
#  'BOS i want to fly from milwaukee to orlando on wednesday evening EOS',
#  'BOS how many daily us air flights are there between philadelphia and pittsburgh EOS',
#  'BOS show me all the northwest flights from new york to milwaukee that leave at 720 am EOS',
#  'BOS how long does it take to get from atlanta airport into the city of atlanta EOS',
#  "BOS what 's the cheapest way to fly between atlanta and denver EOS",
#  'BOS what are the fares for flights from la to newark leaving monday morning EOS',
#  'BOS give me the list of flights for continental airlines between boston and denver EOS',
#  'BOS can i see ground transportation from long beach airport to downtown EOS',
#  'BOS i want a flight from atlanta to pittsburgh EOS',
#  'BOS us 201 EOS',
#  'BOS what flights are available from pittsburgh to oakland airport EOS',
#  'BOS afternoon flight from denver to san francisco EOS',
#  'BOS show me all the flights from charlotte to cleveland EOS',
#  'BOS show me the flights on twa to atlanta in the morning EOS',
#  'BOS do all the flights to oakland land at the same place EOS',
#  'BOS show me the flights from st. petersburg to toronto that arrive before noon EOS',
#  'BOS how much is a first class ticket from baltimore to san francisco EOS',
#  'BOS please give me all flights from long beach to memphis EOS',
#  'BOS i want to fly nonstop from denver to dallas EOS',
#  'BOS what is the earliest flight leaving boston on july first to dallas on july first EOS',
#  "BOS i 'd like a flight tomorrow evening from nashville to houston that includes dinner for tomorrow EOS",
#  'BOS show me the flights from denver to san diego leaving after 5 pm EOS',
#  'BOS what flights go from san francisco to washington via indianapolis EOS',
#  'BOS can you help me with ground transportation information i need to get from the airport in philadelphia to downtown philadelphia EOS',
#  'BOS show me the earliest flight on wednesday from baltimore to newark EOS',
#  'BOS could you please give me the round trip fare from denver to atlanta EOS',
#  'BOS show sunday flights from seattle to chicago EOS',
#  'BOS what flights depart from pittsburgh and arrive in oakland california EOS',
#  'BOS flights from houston to los angeles departing after 1026 EOS',
#  'BOS i would like a flight from pittsburgh to san francisco on august twentieth EOS',
#  'BOS show me flights from dallas to atlanta EOS',
#  'BOS please give all flights from dallas to oakland california monday EOS',
#  'BOS what flights are available wednesday morning from boston to denver EOS',
#  'BOS show me the flights from pittsburgh to baltimore arriving in baltimore on june fourteenth EOS',
#  'BOS list the morning flights at a 124 dollars from atlanta to boston EOS',
#  'BOS show me the flights from denver to philadelphia on a saturday EOS',
#  'BOS i need to fly from boston to denver and then to san francisco and back to boston EOS',
#  'BOS what is the cheapest flight on american airlines from cleveland to miami EOS',
#  'BOS show me flights available from atlanta to baltimore leaving on monday morning EOS',
#  "BOS what 's the earliest flight from pittsburgh to baltimore on thursday morning EOS",
#  'BOS what ground transportation is available in boston EOS',
#  'BOS what is the latest flight leaving pittsburgh returning to denver EOS',
#  'BOS does lufthansa fly between boston and oakland EOS',
#  'BOS show me flights from boston to washington leaving july fifteen EOS',
#  'BOS list all the landings at general mitchell international EOS',
#  'BOS how many first class flights does delta have today EOS',
#  'BOS are there any nonstop flights from indianapolis to san diego on wednesday may twelfth EOS',
#  'BOS what are the flights which depart from san francisco fly to washington via indianapolis and arrive by 9 pm EOS',
#  'BOS please list the flights from dallas fort worth to boston on july twenty third EOS',
#  'BOS hello i would like to plan a flight on american airlines from boston to denver EOS',
#  'BOS what are the two american airlines flights that leave from dallas to san francisco in the evening EOS',
#  'BOS what flights do you have from baltimore to san francisco EOS',
#  "BOS i 'd like a nonstop flight from indianapolis to san diego that serves dinner what 's available EOS",
#  'BOS what times on wednesday could i take a plane from denver to oakland EOS',
#  'BOS show me ground transportation for boston EOS',
#  'BOS are there any flights from boston to san francisco which stop in denver EOS',
#  'BOS what airlines have business class EOS',
#  'BOS please give me all flights from long beach to memphis EOS',
#  'BOS flight from denver to dallas fort worth EOS',
#  'BOS list flights from san francisco to pittsburgh EOS',
#  "BOS i 'd like to know what type of plane flies from boston to dallas fort worth after 530 EOS",
#  'BOS please tell me the times of the flights between boston and baltimore EOS',
#  'BOS find a flight from philadelphia to san francisco please on delta EOS',
#  'BOS what is the cost of a ticket going from denver to boston july twenty fifth 1991 EOS',
#  'BOS flight numbers from minneapolis to long beach on june twenty six EOS',
#  "BOS i 'm looking for a flight from oakland to denver with a stopover in dallas fort worth EOS",
#  'BOS show me first class airlines from san francisco to pittsburgh on next tuesday first class only EOS',
#  'BOS what flights are there on saturdays from philadelphia to denver EOS',
#  'BOS i need a flight from denver to washington dc on wednesday EOS',
#  'BOS show me the flights from columbus to charlotte EOS',
#  "BOS oh let 's see does eastern airline have a flight from atlanta to washington EOS",
#  'BOS what is the price of business class from boston to san francisco on twa EOS',
#  'BOS flights from atlanta to dallas in the afternoon EOS',
#  'BOS eastern flight 825 from atlanta to denver leaving at 555 what type of aircraft is used on that flight EOS',
#  'BOS what are all the flights between san francisco and boston EOS',
#  'BOS define airline us EOS',
#  'BOS i want to fly philadelphia to san francisco on july eighth EOS',
#  'BOS find a flight from boston to washington on monday EOS',
#  'BOS give me information on flights from atlanta to washington dc on wednesday after 4 pm and thursday before 9 am EOS',
#  'BOS find the flights from boston to san francisco leaving after 6 pm EOS',
#  'BOS show me the cheapest fare from dallas to baltimore EOS',
#  "BOS i live in denver and i 'd like to make a trip to pittsburgh EOS",
#  'BOS give me flights that arrive in baltimore from atlanta denver and pittsburgh EOS',
#  "BOS hello i 'm trying to find a flight that goes from pittsburgh to denver after 2 pm EOS",
#  'BOS what airlines fly between boston and san francisco EOS',
#  'BOS code ff EOS',
#  'BOS what is the earliest flight from boston to san francisco on november seventh EOS',
#  'BOS list all flights from boston to san francisco on us air EOS',
#  'BOS i would like a list of flights from pittsburgh to dallas EOS',
#  "BOS on november twenty third of this year 1991 i 'd like to fly from atlanta to denver and i 'd like to fly on delta EOS",
#  'BOS do you have any airlines that would stop at denver on the way from baltimore to san francisco EOS',
#  'BOS list all flights from tampa florida to miami that are the cheapest one way EOS',
#  'BOS list the nonstop flights on wednesday june second from miami to baltimore arriving in baltimore between 1115 am and 1245 pm EOS',
#  'BOS give me flights from san francisco to boston on thursday afternoon EOS',
#  'BOS denver to atlanta EOS',
#  "BOS what 's the last flight leaving from pittsburgh to oakland EOS",
#  'BOS does any airline have an afternoon flight from boston to oakland EOS',
#  'BOS do you have a flight from philadelphia to san francisco with a stopover in dallas EOS',
#  'BOS i want to make a trip from washington to san francisco EOS',
#  'BOS i would like information on flights leaving atlanta in the afternoon arriving in dallas EOS',
#  'BOS show me all flights from san diego to new york nonstop EOS',
#  'BOS show me all flights with fares from pittsburgh to san francisco EOS',
#  'BOS what are the flights from milwaukee to tampa EOS',
#  ...]

# %%
train_sent = [vocab.vectorize(tokens[1:-1]) for tokens in atis_train_queries_w]

# %%
atis_train_queries_w
# Out:
# [['BOS',
#   'i',
#   'want',
#   'to',
#   'fly',
#   'from',
#   'boston',
#   'at',
#   '838',
#   'am',
#   'and',
#   'arrive',
#   'in',
#   'denver',
#   'at',
#   '1110',
#   'in',
#   'the',
#   'morning',
#   'EOS'],
#  ['BOS',
#   'what',
#   'flights',
#   'are',
#   'available',
#   'from',
#   'pittsburgh',
#   'to',
#   'baltimore',
#   'on',
#   'thursday',
#   'morning',
#   'EOS'],
#  ['BOS',
#   'what',
#   'is',
#   'the',
#   'arrival',
#   'time',
#   'in',
#   'san',
#   'francisco',
#   'for',
#   'the',
#   '755',
#   'am',
#   'flight',
#   'leaving',
#   'washington',
#   'EOS'],
#  ['BOS', 'cheapest', 'airfare', 'from', 'tacoma', 'to', 'orlando', 'EOS'],
#  ['BOS',
#   'round',
#   'trip',
#   'fares',
#   'from',
#   'pittsburgh',
#   'to',
#   'philadelphia',
#   'under',
#   '1000',
#   'dollars',
#   'EOS'],
#  ['BOS',
#   'i',
#   'need',
#   'a',
#   'flight',
#   'tomorrow',
#   'from',
#   'columbus',
#   'to',
#   'minneapolis',
#   'EOS'],
#  ['BOS',
#   'what',
#   'kind',
#   'of',
#   'aircraft',
#   'is',
#   'used',
#   'on',
#   'a',
#   'flight',
#   'from',
#   'cleveland',
#   'to',
#   'dallas',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'the',
#   'flights',
#   'from',
#   'pittsburgh',
#   'to',
#   'los',
#   'angeles',
#   'on',
#   'thursday',
#   'EOS'],
#  ['BOS', 'all', 'flights', 'from', 'boston', 'to', 'washington', 'EOS'],
#  ['BOS',
#   'what',
#   'kind',
#   'of',
#   'ground',
#   'transportation',
#   'is',
#   'available',
#   'in',
#   'denver',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'the',
#   'flights',
#   'from',
#   'dallas',
#   'to',
#   'san',
#   'francisco',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'the',
#   'flights',
#   'from',
#   'san',
#   'diego',
#   'to',
#   'newark',
#   'by',
#   'way',
#   'of',
#   'houston',
#   'EOS'],
#  ['BOS', 'what', "'s", 'the', 'airport', 'at', 'orlando', 'EOS'],
#  ['BOS',
#   'what',
#   'is',
#   'the',
#   'cheapest',
#   'flight',
#   'from',
#   'boston',
#   'to',
#   'bwi',
#   'EOS'],
#  ['BOS', 'all', 'flights', 'to', 'baltimore', 'after', '6', 'pm', 'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'the',
#   'first',
#   'class',
#   'fares',
#   'from',
#   'boston',
#   'to',
#   'denver',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'the',
#   'ground',
#   'transportation',
#   'in',
#   'denver',
#   'EOS'],
#  ['BOS',
#   'all',
#   'flights',
#   'from',
#   'denver',
#   'to',
#   'pittsburgh',
#   'leaving',
#   'after',
#   '6',
#   'pm',
#   'and',
#   'before',
#   '7',
#   'pm',
#   'EOS'],
#  ['BOS',
#   'i',
#   'need',
#   'information',
#   'on',
#   'flights',
#   'for',
#   'tuesday',
#   'leaving',
#   'baltimore',
#   'for',
#   'dallas',
#   'dallas',
#   'to',
#   'boston',
#   'and',
#   'boston',
#   'to',
#   'baltimore',
#   'EOS'],
#  ['BOS',
#   'please',
#   'give',
#   'me',
#   'the',
#   'flights',
#   'from',
#   'boston',
#   'to',
#   'pittsburgh',
#   'on',
#   'thursday',
#   'of',
#   'next',
#   'week',
#   'EOS'],
#  ['BOS',
#   'i',
#   'would',
#   'like',
#   'to',
#   'fly',
#   'from',
#   'denver',
#   'to',
#   'pittsburgh',
#   'on',
#   'united',
#   'airlines',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'the',
#   'flights',
#   'from',
#   'san',
#   'diego',
#   'to',
#   'newark',
#   'EOS'],
#  ['BOS',
#   'please',
#   'list',
#   'all',
#   'first',
#   'class',
#   'flights',
#   'on',
#   'united',
#   'from',
#   'denver',
#   'to',
#   'baltimore',
#   'EOS'],
#  ['BOS',
#   'what',
#   'kinds',
#   'of',
#   'planes',
#   'are',
#   'used',
#   'by',
#   'american',
#   'airlines',
#   'EOS'],
#  ['BOS',
#   'i',
#   "'d",
#   'like',
#   'to',
#   'have',
#   'some',
#   'information',
#   'on',
#   'a',
#   'ticket',
#   'from',
#   'denver',
#   'to',
#   'pittsburgh',
#   'and',
#   'atlanta',
#   'EOS'],
#  ['BOS',
#   'i',
#   "'d",
#   'like',
#   'to',
#   'book',
#   'a',
#   'flight',
#   'from',
#   'atlanta',
#   'to',
#   'denver',
#   'EOS'],
#  ['BOS',
#   'which',
#   'airline',
#   'serves',
#   'denver',
#   'pittsburgh',
#   'and',
#   'atlanta',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'all',
#   'flights',
#   'from',
#   'boston',
#   'to',
#   'pittsburgh',
#   'on',
#   'wednesday',
#   'of',
#   'next',
#   'week',
#   'which',
#   'leave',
#   'boston',
#   'after',
#   '2',
#   "o'clock",
#   'pm',
#   'EOS'],
#  ['BOS', 'atlanta', 'ground', 'transportation', 'EOS'],
#  ['BOS',
#   'i',
#   'also',
#   'need',
#   'service',
#   'from',
#   'dallas',
#   'to',
#   'boston',
#   'arriving',
#   'by',
#   'noon',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'the',
#   'cheapest',
#   'round',
#   'trip',
#   'fare',
#   'from',
#   'baltimore',
#   'to',
#   'dallas',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'all',
#   'flights',
#   'from',
#   'new',
#   'york',
#   'to',
#   'milwaukee',
#   'on',
#   'northwest',
#   'airlines',
#   'departing',
#   'at',
#   '720',
#   'am',
#   'EOS'],
#  ['BOS', 'flights', 'from', 'new', 'york', 'to', 'miami', 'EOS'],
#  ['BOS',
#   'please',
#   'find',
#   'a',
#   'flight',
#   'on',
#   'delta',
#   'from',
#   'philadelphia',
#   'to',
#   'san',
#   'francisco',
#   'and',
#   'give',
#   'me',
#   'the',
#   'flight',
#   'numbers',
#   'EOS'],
#  ['BOS',
#   'i',
#   'need',
#   'a',
#   'flight',
#   'from',
#   'dallas',
#   'to',
#   'san',
#   'francisco',
#   'EOS'],
#  ['BOS',
#   'fares',
#   'and',
#   'flights',
#   'from',
#   'pittsburgh',
#   'to',
#   'philadelphia',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'the',
#   'airlines',
#   'with',
#   'first',
#   'class',
#   'flights',
#   'EOS'],
#  ['BOS',
#   'what',
#   'are',
#   'the',
#   'flights',
#   'from',
#   'st.',
#   'louis',
#   'to',
#   'burbank',
#   'sunday',
#   'evening',
#   'EOS'],
#  ['BOS',
#   'i',
#   "'d",
#   'like',
#   'to',
#   'arrange',
#   'a',
#   'flight',
#   'from',
#   'pittsburgh',
#   'to',
#   'atlanta',
#   'EOS'],
#  ['BOS',
#   'show',
#   'flights',
#   'from',
#   'baltimore',
#   'to',
#   'san',
#   'francisco',
#   'between',
#   '6',
#   'pm',
#   'and',
#   '8',
#   'pm',
#   'on',
#   'friday',
#   'EOS'],
#  ['BOS',
#   'how',
#   'far',
#   'is',
#   'it',
#   'from',
#   'orlando',
#   'airport',
#   'to',
#   'orlando',
#   'EOS'],
#  ['BOS',
#   'i',
#   'would',
#   'like',
#   'a',
#   'list',
#   'of',
#   'round',
#   'trip',
#   'flights',
#   'between',
#   'indianapolis',
#   'and',
#   'orlando',
#   'florida',
#   'for',
#   'the',
#   'twenty',
#   'seventh',
#   'and',
#   'the',
#   'twenty',
#   'eighth',
#   'of',
#   'december',
#   'EOS'],
#  ['BOS',
#   'which',
#   'airline',
#   'has',
#   'the',
#   'most',
#   'arrivals',
#   'in',
#   'atlanta',
#   'EOS'],
#  ['BOS',
#   'what',
#   'airlines',
#   'fly',
#   'from',
#   'new',
#   'york',
#   'to',
#   'milwaukee',
#   'to',
#   'los',
#   'angeles',
#   'EOS'],
#  ['BOS', 'pittsburgh', 'to', 'denver', 'EOS'],
#  ['BOS', 'which', 'airlines', 'serve', 'atlanta', 'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'information',
#   'on',
#   'ground',
#   'transportation',
#   'for',
#   'dallas',
#   'EOS'],
#  ['BOS', 'what', 'is', 'fare', 'code', 'h', 'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'all',
#   'flights',
#   'from',
#   'boston',
#   'to',
#   'dallas',
#   'fort',
#   'worth',
#   'both',
#   'direct',
#   'and',
#   'connecting',
#   'that',
#   'arrive',
#   'before',
#   'noon',
#   'EOS'],
#  ['BOS',
#   'i',
#   'need',
#   'a',
#   'flight',
#   'from',
#   'charlotte',
#   'to',
#   'newark',
#   'leaving',
#   'today',
#   'evening',
#   'EOS'],
#  ['BOS',
#   'what',
#   'are',
#   'the',
#   'times',
#   'that',
#   'you',
#   'have',
#   'planes',
#   'leaving',
#   'from',
#   'san',
#   'francisco',
#   'going',
#   'to',
#   'pittsburgh',
#   'on',
#   'july',
#   'seventh',
#   'EOS'],
#  ['BOS', 'flights', 'from', 'newark', 'to', 'cleveland', 'EOS'],
#  ['BOS',
#   'what',
#   'flights',
#   'go',
#   'from',
#   'boston',
#   'to',
#   'pittsburgh',
#   'after',
#   '6',
#   "o'clock",
#   'next',
#   'tuesday',
#   'EOS'],
#  ['BOS',
#   'how',
#   'much',
#   'does',
#   'the',
#   'limousine',
#   'service',
#   'cost',
#   'within',
#   'pittsburgh',
#   'EOS'],
#  ['BOS',
#   'does',
#   'us',
#   'air',
#   'have',
#   'any',
#   'flights',
#   'out',
#   'of',
#   'atlanta',
#   'to',
#   'denver',
#   'EOS'],
#  ['BOS', 'what', 'is', 'booking', 'class', 'c', 'EOS'],
#  ['BOS',
#   'i',
#   "'d",
#   'like',
#   'to',
#   'know',
#   'the',
#   'shortest',
#   'trip',
#   'between',
#   'boston',
#   'and',
#   'san',
#   'francisco',
#   'EOS'],
#  ['BOS',
#   'i',
#   'would',
#   'like',
#   'to',
#   'see',
#   'information',
#   'for',
#   'flights',
#   'from',
#   'san',
#   'francisco',
#   'leaving',
#   'after',
#   '12',
#   'pm',
#   'to',
#   'pittsburgh',
#   'on',
#   'monday',
#   'EOS'],
#  ['BOS',
#   'what',
#   'is',
#   'the',
#   'least',
#   'expensive',
#   'flight',
#   'from',
#   'denver',
#   'to',
#   'atlanta',
#   'EOS'],
#  ['BOS',
#   'i',
#   'need',
#   'to',
#   'know',
#   'information',
#   'for',
#   'flights',
#   'leaving',
#   'dallas',
#   'on',
#   'tuesday',
#   'evening',
#   'and',
#   'returning',
#   'to',
#   'atlanta',
#   'EOS'],
#  ['BOS',
#   'what',
#   'flight',
#   'goes',
#   'from',
#   'denver',
#   'to',
#   'baltimore',
#   'first',
#   'class',
#   'on',
#   'united',
#   'airlines',
#   'arriving',
#   'on',
#   'may',
#   'seventh',
#   'EOS'],
#  ['BOS',
#   'could',
#   'you',
#   'please',
#   'tell',
#   'me',
#   'the',
#   'airlines',
#   'that',
#   'fly',
#   'from',
#   'toronto',
#   'to',
#   'san',
#   'diego',
#   'EOS'],
#  ['BOS',
#   'what',
#   'flights',
#   'do',
#   'you',
#   'have',
#   'from',
#   'burbank',
#   'to',
#   'tacoma',
#   'washington',
#   'EOS'],
#  ['BOS',
#   'what',
#   'is',
#   'the',
#   'ground',
#   'transportation',
#   'from',
#   'philadelphia',
#   'airport',
#   'to',
#   'the',
#   'city',
#   'proper',
#   'EOS'],
#  ['BOS',
#   'which',
#   'airlines',
#   'have',
#   'first',
#   'class',
#   'flights',
#   'today',
#   'EOS'],
#  ['BOS',
#   'find',
#   'the',
#   'latest',
#   'flight',
#   'from',
#   'san',
#   'francisco',
#   'to',
#   'atlanta',
#   'that',
#   'serves',
#   'a',
#   'meal',
#   'EOS'],
#  ['BOS',
#   'i',
#   'would',
#   'like',
#   'to',
#   'make',
#   'a',
#   'reservation',
#   'for',
#   'a',
#   'flight',
#   'to',
#   'denver',
#   'from',
#   'philadelphia',
#   'on',
#   'this',
#   'coming',
#   'sunday',
#   'EOS'],
#  ['BOS',
#   'give',
#   'me',
#   'a',
#   'list',
#   'of',
#   'airports',
#   'in',
#   'baltimore',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'flights',
#   'from',
#   'boston',
#   'to',
#   'denver',
#   'on',
#   'wednesday',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'the',
#   'flights',
#   'from',
#   'boston',
#   'to',
#   'baltimore',
#   'EOS'],
#  ['BOS', 'what', 'does', 'fare', 'code', 'q', 'mean', 'EOS'],
#  ['BOS',
#   'please',
#   'give',
#   'me',
#   'the',
#   'flights',
#   'from',
#   'san',
#   'francisco',
#   'to',
#   'washington',
#   'dc',
#   'EOS'],
#  ['BOS',
#   'i',
#   'need',
#   'information',
#   'from',
#   'denver',
#   'to',
#   'pittsburgh',
#   'EOS'],
#  ['BOS', 'from', 'seattle', 'to', 'salt', 'lake', 'city', 'EOS'],
#  ['BOS',
#   'what',
#   'is',
#   'the',
#   'earliest',
#   'flight',
#   'from',
#   'boston',
#   'to',
#   'bwi',
#   'that',
#   'serves',
#   'a',
#   'snack',
#   'EOS'],
#  ['BOS', 'what', 'types', 'of', 'aircraft', 'does', 'delta', 'fly', 'EOS'],
#  ['BOS',
#   'what',
#   'is',
#   'the',
#   'cost',
#   'of',
#   'a',
#   'round',
#   'trip',
#   'flight',
#   'from',
#   'pittsburgh',
#   'to',
#   'atlanta',
#   'beginning',
#   'on',
#   'april',
#   'twenty',
#   'fifth',
#   'and',
#   'returning',
#   'on',
#   'may',
#   'sixth',
#   'EOS'],
#  ['BOS',
#   'give',
#   'me',
#   'the',
#   'flights',
#   'leaving',
#   'denver',
#   'august',
#   'ninth',
#   'coming',
#   'back',
#   'to',
#   'boston',
#   'EOS'],
#  ['BOS',
#   'list',
#   'all',
#   'the',
#   'flights',
#   'that',
#   'fly',
#   'into',
#   'general',
#   'mitchell',
#   'international',
#   'EOS'],
#  ['BOS',
#   'what',
#   'flights',
#   'fly',
#   'from',
#   'denver',
#   'to',
#   'san',
#   'francisco',
#   'on',
#   'monday',
#   'tuesday',
#   'wednesday',
#   'thursday',
#   'and',
#   'friday',
#   'EOS'],
#  ['BOS',
#   'list',
#   'all',
#   'flights',
#   'from',
#   'indianapolis',
#   'to',
#   'seattle',
#   'EOS'],
#  ['BOS',
#   'in',
#   'flight',
#   'meal',
#   'oakland',
#   'to',
#   'philadelphia',
#   'saturday',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'the',
#   'flights',
#   'on',
#   'twa',
#   'from',
#   'atlanta',
#   'in',
#   'the',
#   'morning',
#   'EOS'],
#  ['BOS',
#   'i',
#   'want',
#   'to',
#   'find',
#   'the',
#   'first',
#   'flight',
#   'from',
#   'baltimore',
#   'to',
#   'boston',
#   'that',
#   'serves',
#   'a',
#   'meal',
#   'EOS'],
#  ['BOS',
#   'of',
#   'all',
#   'airlines',
#   'which',
#   'airline',
#   'has',
#   'the',
#   'most',
#   'arrivals',
#   'in',
#   'atlanta',
#   'EOS'],
#  ['BOS',
#   'display',
#   'all',
#   'flights',
#   'from',
#   'baltimore',
#   'to',
#   'boston',
#   'on',
#   'july',
#   'twenty',
#   'ninth',
#   'EOS'],
#  ['BOS',
#   'i',
#   'want',
#   'to',
#   'travel',
#   'from',
#   'atlanta',
#   'to',
#   'baltimore',
#   'early',
#   'in',
#   'the',
#   'morning',
#   'first',
#   'flight',
#   'EOS'],
#  ['BOS',
#   'i',
#   'now',
#   'need',
#   'a',
#   'flight',
#   'from',
#   'san',
#   'jose',
#   'to',
#   'houston',
#   'leaving',
#   'on',
#   'sunday',
#   'the',
#   'fourth',
#   'EOS'],
#  ['BOS',
#   'what',
#   'are',
#   'the',
#   'flights',
#   'available',
#   'after',
#   '6',
#   'pm',
#   'between',
#   'san',
#   'francisco',
#   'and',
#   'boston',
#   'EOS'],
#  ['BOS',
#   'what',
#   'flights',
#   'depart',
#   'baltimore',
#   'on',
#   'friday',
#   'and',
#   'arrive',
#   'in',
#   'san',
#   'francisco',
#   'by',
#   '8',
#   'pm',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'flights',
#   'from',
#   'boston',
#   'to',
#   'san',
#   'francisco',
#   'EOS'],
#  ['BOS',
#   'list',
#   'the',
#   'delta',
#   'airlines',
#   'flights',
#   'from',
#   'boston',
#   'to',
#   'philadelphia',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'the',
#   'fares',
#   'from',
#   'dallas',
#   'to',
#   'san',
#   'francisco',
#   'EOS'],
#  ['BOS',
#   'what',
#   'nonstop',
#   'flights',
#   'between',
#   'boston',
#   'and',
#   'washington',
#   'arrive',
#   'after',
#   '4',
#   "o'clock",
#   'pm',
#   'EOS'],
#  ['BOS',
#   'what',
#   'is',
#   'the',
#   'distance',
#   'from',
#   'los',
#   'angeles',
#   'international',
#   'airport',
#   'to',
#   'los',
#   'angeles',
#   'EOS'],
#  ['BOS', 'ground', 'transportation', 'in', 'san', 'jose', 'EOS'],
#  ['BOS',
#   'please',
#   'tell',
#   'me',
#   'how',
#   'many',
#   'nonstop',
#   'flights',
#   'there',
#   'are',
#   'from',
#   'boston',
#   'to',
#   'atlanta',
#   'EOS'],
#  ['BOS',
#   'on',
#   'the',
#   'earliest',
#   'flight',
#   'from',
#   'san',
#   'francisco',
#   'to',
#   'atlanta',
#   'on',
#   'delta',
#   'is',
#   'a',
#   'meal',
#   'being',
#   'served',
#   'EOS'],
#  ['BOS',
#   'where',
#   'does',
#   'canadian',
#   'airlines',
#   'international',
#   'fly',
#   'EOS'],
#  ['BOS',
#   'what',
#   'flights',
#   'from',
#   'denver',
#   'to',
#   'pittsburgh',
#   'arrive',
#   'before',
#   '8',
#   'in',
#   'the',
#   'morning',
#   'EOS'],
#  ['BOS',
#   'find',
#   'me',
#   'the',
#   'earliest',
#   'flight',
#   'from',
#   'boston',
#   'to',
#   'atlanta',
#   'EOS'],
#  ['BOS',
#   'list',
#   'nonstop',
#   'flights',
#   'from',
#   'houston',
#   'to',
#   'dallas',
#   'which',
#   'arrive',
#   'before',
#   'midnight',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'the',
#   'flights',
#   'from',
#   'boston',
#   'to',
#   'san',
#   'francisco',
#   'that',
#   'stop',
#   'in',
#   'atlanta',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'flights',
#   'to',
#   'san',
#   'francisco',
#   'from',
#   'philadelphia',
#   'stopping',
#   'in',
#   'dallas',
#   'EOS'],
#  ['BOS', 'what', 'city', 'is', 'the', 'airport', 'mco', 'in', 'EOS'],
#  ['BOS',
#   'how',
#   'much',
#   'does',
#   'it',
#   'cost',
#   'to',
#   'rent',
#   'a',
#   'car',
#   'in',
#   'tacoma',
#   'EOS'],
#  ['BOS', 'show', 'me', 'flights', 'from', 'baltimore', 'to', 'dallas', 'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'a',
#   'list',
#   'of',
#   'ground',
#   'transportation',
#   'at',
#   'denver',
#   'EOS'],
#  ['BOS',
#   'i',
#   "'d",
#   'like',
#   'a',
#   'flight',
#   'from',
#   'columbus',
#   'to',
#   'phoenix',
#   'stopping',
#   'in',
#   'cincinnati',
#   'and',
#   'serving',
#   'dinner',
#   'what',
#   "'s",
#   'available',
#   'EOS'],
#  ['BOS',
#   'also',
#   'show',
#   'me',
#   'flights',
#   'from',
#   'san',
#   'francisco',
#   'to',
#   'pittsburgh',
#   'on',
#   'tuesday',
#   'EOS'],
#  ['BOS', 'show', 'flights', 'from', 'dallas', 'to', 'oakland', 'EOS'],
#  ['BOS',
#   'give',
#   'me',
#   'the',
#   'cheapest',
#   'flight',
#   'from',
#   'charlotte',
#   'to',
#   'long',
#   'beach',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'all',
#   'flights',
#   'from',
#   'san',
#   'francisco',
#   'to',
#   'pittsburgh',
#   'EOS'],
#  ['BOS',
#   'find',
#   'me',
#   'a',
#   'flight',
#   'on',
#   'united',
#   'from',
#   'boston',
#   'to',
#   'san',
#   'francisco',
#   'with',
#   'a',
#   'stopover',
#   'in',
#   'denver',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'the',
#   'last',
#   'flight',
#   'from',
#   'love',
#   'field',
#   'EOS'],
#  ['BOS',
#   'what',
#   'flights',
#   'go',
#   'from',
#   'newark',
#   'to',
#   'boston',
#   'after',
#   '5',
#   'pm',
#   'EOS'],
#  ['BOS',
#   'what',
#   'are',
#   'all',
#   'the',
#   'flights',
#   'from',
#   'boston',
#   'to',
#   'dallas',
#   'EOS'],
#  ['BOS',
#   'what',
#   'is',
#   'the',
#   'earliest',
#   'flight',
#   'departing',
#   'san',
#   'francisco',
#   'and',
#   'arriving',
#   'in',
#   'boston',
#   'on',
#   'november',
#   'ninth',
#   'EOS'],
#  ['BOS',
#   'what',
#   'is',
#   'the',
#   'earliest',
#   'flight',
#   'flying',
#   'from',
#   'pittsburgh',
#   'to',
#   'atlanta',
#   'on',
#   'july',
#   'fifth',
#   'EOS'],
#  ['BOS',
#   'please',
#   'list',
#   'available',
#   'flights',
#   'for',
#   'next',
#   'saturday',
#   'from',
#   'philadelphia',
#   'to',
#   'dallas',
#   'EOS'],
#  ['BOS',
#   'what',
#   'flights',
#   'leave',
#   'pittsburgh',
#   'and',
#   'arrive',
#   'in',
#   'los',
#   'angeles',
#   'after',
#   '5',
#   'pm',
#   'on',
#   'thursday',
#   'EOS'],
#  ['BOS',
#   'what',
#   'is',
#   'the',
#   'transportation',
#   'time',
#   'from',
#   'the',
#   'airport',
#   'to',
#   'boston',
#   'EOS'],
#  ['BOS',
#   'which',
#   'airline',
#   'has',
#   'the',
#   'smallest',
#   'plane',
#   'leaving',
#   'pittsburgh',
#   'and',
#   'arriving',
#   'in',
#   'baltimore',
#   'on',
#   'july',
#   'fourth',
#   'EOS'],
#  ['BOS',
#   'what',
#   'are',
#   'the',
#   'nonstop',
#   'flights',
#   'on',
#   'america',
#   'west',
#   'or',
#   'southwest',
#   'air',
#   'from',
#   'kansas',
#   'city',
#   'to',
#   'burbank',
#   'on',
#   'saturday',
#   'may',
#   'twenty',
#   'two',
#   'EOS'],
#  ['BOS',
#   'what',
#   'are',
#   'the',
#   'classes',
#   'of',
#   'service',
#   'for',
#   'american',
#   'airlines',
#   'EOS'],
#  ['BOS',
#   'i',
#   'would',
#   'like',
#   'to',
#   'find',
#   'out',
#   'what',
#   'flights',
#   'there',
#   'are',
#   'on',
#   'friday',
#   'june',
#   'eleventh',
#   'from',
#   'st.',
#   'petersburg',
#   'to',
#   'milwaukee',
#   'and',
#   'then',
#   'from',
#   'milwaukee',
#   'to',
#   'tacoma',
#   'thank',
#   'you',
#   'EOS'],
#  ['BOS',
#   'all',
#   'flights',
#   'from',
#   'boston',
#   'to',
#   'washington',
#   'dc',
#   'on',
#   'november',
#   'tenth',
#   'EOS'],
#  ['BOS',
#   'what',
#   'are',
#   'the',
#   'flights',
#   'from',
#   'denver',
#   'to',
#   'san',
#   'francisco',
#   'EOS'],
#  ['BOS',
#   'on',
#   'the',
#   '8',
#   'am',
#   'flight',
#   'from',
#   'san',
#   'francisco',
#   'to',
#   'atlanta',
#   'what',
#   'type',
#   'of',
#   'aircraft',
#   'is',
#   'used',
#   'EOS'],
#  ['BOS',
#   'which',
#   'flight',
#   'is',
#   'a',
#   'one',
#   'way',
#   'fare',
#   'at',
#   '329',
#   'dollars',
#   'from',
#   'denver',
#   'to',
#   'pittsburgh',
#   'EOS'],
#  ['BOS',
#   'what',
#   'flights',
#   'leave',
#   'baltimore',
#   'for',
#   'boston',
#   'after',
#   '6',
#   "o'clock",
#   'on',
#   'friday',
#   'EOS'],
#  ['BOS',
#   'okay',
#   'i',
#   'need',
#   'to',
#   'get',
#   'a',
#   'flight',
#   'from',
#   'houston',
#   'to',
#   'seattle',
#   'EOS'],
#  ['BOS',
#   'please',
#   'list',
#   'flights',
#   'between',
#   'denver',
#   'and',
#   'boston',
#   'EOS'],
#  ['BOS',
#   'find',
#   'me',
#   'the',
#   'flights',
#   'that',
#   'are',
#   'nonstop',
#   'between',
#   'boston',
#   'and',
#   'dallas',
#   'that',
#   'leave',
#   'between',
#   '12',
#   'and',
#   '2',
#   'in',
#   'the',
#   'afternoon',
#   'EOS'],
#  ['BOS',
#   'i',
#   'would',
#   'like',
#   'some',
#   'information',
#   'on',
#   'flights',
#   'leaving',
#   'boston',
#   'to',
#   'atlanta',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'the',
#   'latest',
#   'nonstop',
#   'flight',
#   'from',
#   'denver',
#   'to',
#   'washington',
#   'dc',
#   'EOS'],
#  ['BOS',
#   'what',
#   'are',
#   'the',
#   'flights',
#   'from',
#   'dallas',
#   'to',
#   'baltimore',
#   'EOS'],
#  ['BOS',
#   'i',
#   'would',
#   'like',
#   'a',
#   'nonstop',
#   'flight',
#   'from',
#   'new',
#   'york',
#   'to',
#   'las',
#   'vegas',
#   'on',
#   'march',
#   'second',
#   'EOS'],
#  ['BOS',
#   'no',
#   'i',
#   'want',
#   'to',
#   'go',
#   'from',
#   'denver',
#   'to',
#   'oakland',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'all',
#   'the',
#   'night',
#   'fares',
#   'between',
#   'philadelphia',
#   'and',
#   'san',
#   'francisco',
#   'EOS'],
#  ['BOS',
#   'what',
#   'kinds',
#   'of',
#   'ground',
#   'transportation',
#   'is',
#   'available',
#   'in',
#   'dallas',
#   'fort',
#   'worth',
#   'EOS'],
#  ['BOS',
#   'can',
#   'you',
#   'show',
#   'me',
#   'economy',
#   'class',
#   'one',
#   'way',
#   'fares',
#   'for',
#   'flights',
#   'from',
#   'oakland',
#   'to',
#   'dallas',
#   'on',
#   'december',
#   'sixteenth',
#   'EOS'],
#  ['BOS', 'what', 'is', 'fare', 'code', 'qw', 'EOS'],
#  ['BOS',
#   'i',
#   "'d",
#   'like',
#   'a',
#   'flight',
#   'on',
#   'july',
#   'ninth',
#   'from',
#   'orlando',
#   'to',
#   'kansas',
#   'city',
#   'in',
#   'the',
#   'afternoon',
#   'EOS'],
#  ['BOS',
#   'what',
#   'are',
#   'the',
#   'coach',
#   'fares',
#   'from',
#   'charlotte',
#   'to',
#   'la',
#   'wednesday',
#   'night',
#   'EOS'],
#  ['BOS',
#   'is',
#   'there',
#   'ground',
#   'transportation',
#   'available',
#   'in',
#   'denver',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'flights',
#   'from',
#   'philadelphia',
#   'to',
#   'oakland',
#   'on',
#   'friday',
#   'EOS'],
#  ['BOS',
#   'i',
#   'would',
#   'like',
#   'to',
#   'know',
#   'the',
#   'flights',
#   'available',
#   'from',
#   'boston',
#   'to',
#   'denver',
#   'arriving',
#   'in',
#   'denver',
#   'by',
#   '8',
#   "o'clock",
#   'wednesday',
#   'morning',
#   'EOS'],
#  ['BOS',
#   'i',
#   'would',
#   'like',
#   'to',
#   'fly',
#   'the',
#   'cheapest',
#   'rate',
#   'available',
#   'from',
#   'pittsburgh',
#   'to',
#   'atlanta',
#   'on',
#   'wednesday',
#   'morning',
#   'EOS'],
#  ['BOS',
#   'list',
#   'the',
#   'flight',
#   'from',
#   'philadelphia',
#   'to',
#   'san',
#   'francisco',
#   'on',
#   'american',
#   'airlines',
#   'EOS'],
#  ['BOS',
#   'flights',
#   'from',
#   'memphis',
#   'to',
#   'las',
#   'vegas',
#   'on',
#   'sunday',
#   'EOS'],
#  ['BOS',
#   'what',
#   'is',
#   'the',
#   'first',
#   'flight',
#   'from',
#   'atlanta',
#   'to',
#   'boston',
#   'on',
#   'thursday',
#   'september',
#   'fifth',
#   'that',
#   'leaves',
#   'after',
#   '8',
#   'am',
#   'EOS'],
#  ['BOS',
#   'what',
#   'is',
#   'the',
#   'first',
#   'class',
#   'fare',
#   'on',
#   'united',
#   'flight',
#   '352',
#   'from',
#   'denver',
#   'to',
#   'boston',
#   'EOS'],
#  ['BOS',
#   'flight',
#   'from',
#   'philadelphia',
#   'to',
#   'dallas',
#   'arriving',
#   'before',
#   '4',
#   'pm',
#   'on',
#   'saturday',
#   'EOS'],
#  ['BOS',
#   'list',
#   'flights',
#   'tomorrow',
#   'from',
#   'san',
#   'diego',
#   'to',
#   'phoenix',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'all',
#   'flights',
#   'from',
#   'san',
#   'francisco',
#   'to',
#   'washington',
#   'dc',
#   'area',
#   'EOS'],
#  ['BOS',
#   'sure',
#   'i',
#   'want',
#   'to',
#   'go',
#   'from',
#   'philadelphia',
#   'to',
#   'dallas',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'all',
#   'the',
#   'united',
#   'airlines',
#   'flights',
#   'leaving',
#   'dallas',
#   'EOS'],
#  ['BOS',
#   'can',
#   'you',
#   'list',
#   'all',
#   'the',
#   'flights',
#   'between',
#   'phoenix',
#   'and',
#   'las',
#   'vegas',
#   'EOS'],
#  ['BOS',
#   'list',
#   'all',
#   'flights',
#   'from',
#   'baltimore',
#   'to',
#   'philadelphia',
#   'EOS'],
#  ['BOS',
#   'round',
#   'trip',
#   'flights',
#   'from',
#   'minneapolis',
#   'to',
#   'san',
#   'diego',
#   'coach',
#   'economy',
#   'fare',
#   'EOS'],
#  ['BOS',
#   'i',
#   'want',
#   'to',
#   'fly',
#   'from',
#   'boston',
#   'to',
#   'denver',
#   'and',
#   'i',
#   'don',
#   "'t",
#   'want',
#   'any',
#   'stopovers',
#   'and',
#   'i',
#   "'d",
#   'like',
#   'to',
#   'fly',
#   'only',
#   'during',
#   'the',
#   'afternoon',
#   'EOS'],
#  ['BOS',
#   'flights',
#   'from',
#   'denver',
#   'to',
#   'baltimore',
#   'between',
#   '10',
#   'am',
#   'and',
#   '2',
#   'pm',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'the',
#   'flights',
#   'from',
#   'denver',
#   'to',
#   'atlanta',
#   'EOS'],
#  ['BOS',
#   'what',
#   'flights',
#   'are',
#   'there',
#   'on',
#   'delta',
#   'from',
#   'boston',
#   'to',
#   'dallas',
#   'EOS'],
#  ['BOS',
#   'what',
#   'kind',
#   'of',
#   'ground',
#   'transportation',
#   'can',
#   'you',
#   'offer',
#   'me',
#   'in',
#   'seattle',
#   'EOS'],
#  ['BOS',
#   'leaving',
#   'washington',
#   'going',
#   'to',
#   'san',
#   'francisco',
#   'the',
#   'latest',
#   'flight',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'the',
#   'flights',
#   'available',
#   'from',
#   'atlanta',
#   'to',
#   'baltimore',
#   'leaving',
#   'atlanta',
#   'in',
#   'the',
#   'morning',
#   'EOS'],
#  ['BOS', 'round', 'trip', 'fares', 'new', 'york', 'to', 'san', 'jose', 'EOS'],
#  ['BOS',
#   'which',
#   'flights',
#   'are',
#   'serviced',
#   'by',
#   'american',
#   'airlines',
#   'EOS'],
#  ['BOS',
#   'how',
#   'do',
#   'i',
#   'get',
#   'from',
#   'pittsburgh',
#   'airport',
#   'to',
#   'downtown',
#   'pittsburgh',
#   'EOS'],
#  ['BOS', 'does', 'midwest', 'express', 'serve', 'charlotte', 'EOS'],
#  ['BOS',
#   'what',
#   'flights',
#   'from',
#   'houston',
#   'to',
#   'milwaukee',
#   'on',
#   'friday',
#   'in',
#   'the',
#   'evening',
#   'on',
#   'american',
#   'airlines',
#   'EOS'],
#  ['BOS',
#   'what',
#   'is',
#   'the',
#   'earliest',
#   'flight',
#   'going',
#   'from',
#   'san',
#   'francisco',
#   'to',
#   'dallas',
#   'on',
#   'monday',
#   'august',
#   'nineteenth',
#   'EOS'],
#  ['BOS',
#   'what',
#   'flights',
#   'from',
#   'atlanta',
#   'to',
#   'st.',
#   'louis',
#   'on',
#   'tuesday',
#   'arriving',
#   'around',
#   '230',
#   'pm',
#   'EOS'],
#  ['BOS',
#   'i',
#   'need',
#   'a',
#   'flight',
#   'from',
#   'kansas',
#   'city',
#   'to',
#   'chicago',
#   'that',
#   'leaves',
#   'wednesday',
#   'and',
#   'arrives',
#   'in',
#   'chicago',
#   'around',
#   '7',
#   'pm',
#   'EOS'],
#  ['BOS',
#   'i',
#   'would',
#   'like',
#   'information',
#   'on',
#   'any',
#   'flights',
#   'from',
#   'pittsburgh',
#   'to',
#   'san',
#   'francisco',
#   'leaving',
#   'thursday',
#   'evening',
#   'EOS'],
#  ['BOS',
#   'i',
#   'need',
#   'a',
#   'cheap',
#   'flight',
#   'from',
#   'baltimore',
#   'to',
#   'san',
#   'francisco',
#   'EOS'],
#  ['BOS',
#   'what',
#   'is',
#   'the',
#   'cost',
#   'of',
#   'a',
#   'first',
#   'class',
#   'ticket',
#   'from',
#   'baltimore',
#   'to',
#   'dallas',
#   'EOS'],
#  ['BOS',
#   'what',
#   'is',
#   'the',
#   'economy',
#   'thrift',
#   'fare',
#   'from',
#   'boston',
#   'to',
#   'washington',
#   'EOS'],
#  ['BOS',
#   'list',
#   'the',
#   'nonstop',
#   'flights',
#   'early',
#   'tuesday',
#   'morning',
#   'from',
#   'dallas',
#   'to',
#   'atlanta',
#   'EOS'],
#  ['BOS',
#   'what',
#   'is',
#   'the',
#   'earliest',
#   'flight',
#   'you',
#   'have',
#   'that',
#   'leaves',
#   'philadelphia',
#   'to',
#   'dallas',
#   'EOS'],
#  ['BOS',
#   'are',
#   'there',
#   'any',
#   'flights',
#   'from',
#   'dallas',
#   'fort',
#   'worth',
#   'to',
#   'boston',
#   'leaving',
#   'before',
#   '10',
#   'am',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'all',
#   'the',
#   'flights',
#   'to',
#   'baltimore',
#   'after',
#   '6',
#   "o'clock",
#   'pm',
#   'EOS'],
#  ['BOS',
#   'i',
#   'need',
#   'a',
#   'return',
#   'flight',
#   'from',
#   'philadelphia',
#   'to',
#   'boston',
#   'EOS'],
#  ['BOS',
#   'united',
#   'airlines',
#   'flights',
#   'stopping',
#   'in',
#   'denver',
#   'before',
#   'noon',
#   'EOS'],
#  ['BOS', 'show', 'me', 'the', 'car', 'rentals', 'in', 'baltimore', 'EOS'],
#  ['BOS',
#   'what',
#   'flights',
#   'go',
#   'from',
#   'newark',
#   'to',
#   'boston',
#   'after',
#   '1024',
#   'in',
#   'the',
#   'morning',
#   'EOS'],
#  ['BOS',
#   'shortest',
#   'evening',
#   'flight',
#   'from',
#   'tampa',
#   'to',
#   'cincinnati',
#   'EOS'],
#  ['BOS',
#   'how',
#   'much',
#   'time',
#   'does',
#   'it',
#   'take',
#   'to',
#   'go',
#   'between',
#   'the',
#   'airport',
#   'and',
#   'downtown',
#   'by',
#   'ground',
#   'transportation',
#   'in',
#   'dallas',
#   'EOS'],
#  ['BOS', 'flights', 'from', 'boston', 'to', 'pittsburgh', 'EOS'],
#  ['BOS',
#   'i',
#   "'d",
#   'like',
#   'to',
#   'fly',
#   'continental',
#   'airlines',
#   'between',
#   'boston',
#   'and',
#   'philadelphia',
#   'EOS'],
#  ['BOS',
#   'i',
#   'would',
#   'like',
#   'to',
#   'book',
#   'a',
#   'flight',
#   'on',
#   'continental',
#   'airlines',
#   'from',
#   'chicago',
#   'to',
#   'seattle',
#   'on',
#   'june',
#   'first',
#   'EOS'],
#  ['BOS',
#   'all',
#   'flights',
#   'from',
#   'pittsburgh',
#   'to',
#   'dallas',
#   'round',
#   'trip',
#   'after',
#   '12',
#   'pm',
#   'less',
#   'than',
#   '100',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'flights',
#   'on',
#   'sunday',
#   'going',
#   'from',
#   'san',
#   'francisco',
#   'to',
#   'boston',
#   'nonstop',
#   'first',
#   'class',
#   'leaving',
#   'after',
#   '12',
#   'noon',
#   'EOS'],
#  ['BOS', 'from', 'las', 'vegas', 'to', 'phoenix', 'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'flights',
#   'from',
#   'pittsburgh',
#   'to',
#   'atlanta',
#   'on',
#   'monday',
#   'afternoon',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'the',
#   'flight',
#   'with',
#   'the',
#   'smallest',
#   'seating',
#   'capacity',
#   'which',
#   'leaves',
#   'pittsburgh',
#   'and',
#   'arrives',
#   'in',
#   'baltimore',
#   'on',
#   'june',
#   'fourteenth',
#   'EOS'],
#  ['BOS',
#   'show',
#   'all',
#   'flights',
#   'from',
#   'boston',
#   'to',
#   'denver',
#   'on',
#   'july',
#   'thirty',
#   'first',
#   'EOS'],
#  ['BOS',
#   'are',
#   'there',
#   'any',
#   'flights',
#   'before',
#   '12',
#   'noon',
#   'on',
#   'june',
#   'fifteenth',
#   'from',
#   'long',
#   'beach',
#   'to',
#   'columbus',
#   'EOS'],
#  ['BOS', 'list', 'daily', 'flights', 'from', 'boston', 'to', 'atlanta', 'EOS'],
#  ['BOS',
#   'on',
#   'a',
#   'flight',
#   'from',
#   'san',
#   'francisco',
#   'to',
#   'atlanta',
#   'that',
#   'leaves',
#   'before',
#   '8',
#   'am',
#   'is',
#   'there',
#   'such',
#   'a',
#   'flight',
#   'EOS'],
#  ['BOS',
#   'on',
#   'united',
#   'airlines',
#   'give',
#   'me',
#   'the',
#   'flight',
#   'times',
#   'from',
#   'boston',
#   'to',
#   'dallas',
#   'EOS'],
#  ['BOS', 'ground', 'transportation', 'minneapolis', 'EOS'],
#  ['BOS', 'show', 'me', 'airline', 'abbreviations', 'EOS'],
#  ['BOS',
#   'how',
#   'many',
#   'flights',
#   'does',
#   'delta',
#   'have',
#   'with',
#   'a',
#   'class',
#   'of',
#   'service',
#   'code',
#   'f',
#   'EOS'],
#  ['BOS',
#   'please',
#   'list',
#   'all',
#   'the',
#   'arriving',
#   'and',
#   'departing',
#   'flights',
#   'from',
#   'general',
#   'mitchell',
#   'international',
#   'EOS'],
#  ['BOS',
#   'i',
#   'would',
#   'like',
#   'to',
#   'see',
#   'the',
#   'flights',
#   'from',
#   'denver',
#   'to',
#   'philadelphia',
#   'please',
#   'EOS'],
#  ['BOS',
#   'does',
#   'eastern',
#   'airlines',
#   'fly',
#   'early',
#   'in',
#   'the',
#   'morning',
#   'between',
#   'logan',
#   'and',
#   'bwi',
#   'EOS'],
#  ['BOS',
#   'what',
#   'flights',
#   'leave',
#   'phoenix',
#   'on',
#   'american',
#   'airlines',
#   'EOS'],
#  ['BOS',
#   'can',
#   'you',
#   'list',
#   'all',
#   'the',
#   'airlines',
#   'that',
#   'have',
#   'flights',
#   'from',
#   'boston',
#   'to',
#   'san',
#   'francisco',
#   'EOS'],
#  ['BOS', 'flights', 'from', 'nashville', 'to', 'orlando', 'daily', 'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'first',
#   'class',
#   'flights',
#   'from',
#   'pittsburgh',
#   'to',
#   'san',
#   'francisco',
#   'on',
#   'friday',
#   'EOS'],
#  ['BOS',
#   'i',
#   'need',
#   'the',
#   'earliest',
#   'flight',
#   'from',
#   'denver',
#   'to',
#   'boston',
#   'that',
#   'serves',
#   'dinner',
#   'EOS'],
#  ['BOS', 'from', 'toronto', 'to', 'atlanta', 'in', 'the', 'afternoon', 'EOS'],
#  ['BOS',
#   'please',
#   'list',
#   'the',
#   'friday',
#   'afternoon',
#   'flights',
#   'from',
#   'san',
#   'jose',
#   'to',
#   'dallas',
#   'on',
#   'american',
#   'airlines',
#   'EOS'],
#  ['BOS',
#   'is',
#   'there',
#   'ground',
#   'transportation',
#   'in',
#   'boston',
#   'from',
#   'the',
#   'airport',
#   'EOS'],
#  ['BOS',
#   'show',
#   'first',
#   'flight',
#   'from',
#   'pittsburgh',
#   'to',
#   'atlanta',
#   'on',
#   'wednesday',
#   'EOS'],
#  ['BOS',
#   'i',
#   "'m",
#   'sorry',
#   'i',
#   'wanted',
#   'to',
#   'fly',
#   'twa',
#   'is',
#   'there',
#   'a',
#   'flight',
#   'between',
#   'oakland',
#   'and',
#   'boston',
#   'with',
#   'a',
#   'stopover',
#   'in',
#   'dallas',
#   'fort',
#   'worth',
#   'on',
#   'twa',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'all',
#   'flights',
#   'from',
#   'san',
#   'francisco',
#   'to',
#   'la',
#   'guardia',
#   'nonstop',
#   'EOS'],
#  ['BOS',
#   'what',
#   'flights',
#   'are',
#   'there',
#   'from',
#   'pittsburgh',
#   'to',
#   'los',
#   'angeles',
#   'EOS'],
#  ['BOS',
#   'what',
#   'kind',
#   'of',
#   'ground',
#   'transportation',
#   'is',
#   'there',
#   'in',
#   'washington',
#   'dc',
#   'EOS'],
#  ['BOS',
#   'what',
#   'is',
#   'the',
#   'least',
#   'expensive',
#   'flight',
#   'available',
#   'from',
#   'dallas',
#   'fort',
#   'worth',
#   'to',
#   'san',
#   'francisco',
#   'EOS'],
#  ['BOS', 'what', 'does', 'the', 'fare', 'code', 'f', 'mean', 'EOS'],
#  ['BOS',
#   'what',
#   "'s",
#   'the',
#   'most',
#   'expensive',
#   'way',
#   'i',
#   'can',
#   'fly',
#   'to',
#   'washington',
#   'EOS'],
#  ['BOS',
#   'what',
#   'flights',
#   'from',
#   'houston',
#   'to',
#   'milwaukee',
#   'on',
#   'friday',
#   'on',
#   'american',
#   'airlines',
#   'EOS'],
#  ['BOS',
#   'what',
#   'is',
#   'the',
#   'schedule',
#   'of',
#   'ground',
#   'transportation',
#   'from',
#   'the',
#   'airport',
#   'in',
#   'philadelphia',
#   'into',
#   'downtown',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'a',
#   'list',
#   'of',
#   'flights',
#   'from',
#   'san',
#   'francisco',
#   'to',
#   'boston',
#   'for',
#   'august',
#   'thirtieth',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'the',
#   'least',
#   'expensive',
#   'flight',
#   'from',
#   'miami',
#   'to',
#   'cleveland',
#   'on',
#   'sunday',
#   'after',
#   'noon',
#   'EOS'],
#  ['BOS',
#   'how',
#   'much',
#   'does',
#   'it',
#   'cost',
#   'to',
#   'go',
#   'from',
#   'downtown',
#   'to',
#   'logan',
#   'airport',
#   'EOS'],
#  ['BOS',
#   'what',
#   'flights',
#   'are',
#   'there',
#   'from',
#   'newark',
#   'to',
#   'tampa',
#   'EOS'],
#  ['BOS',
#   'i',
#   'want',
#   'a',
#   'flight',
#   'from',
#   'philadelphia',
#   'to',
#   'dallas',
#   'that',
#   'at',
#   'least',
#   'has',
#   'one',
#   'stop',
#   'EOS'],
#  ['BOS',
#   'show',
#   'flights',
#   'from',
#   'denver',
#   'to',
#   'oakland',
#   'arriving',
#   'between',
#   '12',
#   'and',
#   '1',
#   "o'clock",
#   'EOS'],
#  ['BOS',
#   'what',
#   'is',
#   'the',
#   'fare',
#   'from',
#   'san',
#   'francisco',
#   'to',
#   'dallas',
#   'fort',
#   'worth',
#   'on',
#   'delta',
#   'flight',
#   '852',
#   'EOS'],
#  ['BOS',
#   'flights',
#   'from',
#   'newark',
#   'new',
#   'jersey',
#   'to',
#   'cleveland',
#   'ohio',
#   'EOS'],
#  ['BOS', 'give', 'me', 'flights', 'from', 'denver', 'to', 'baltimore', 'EOS'],
#  ['BOS',
#   'show',
#   'the',
#   'flights',
#   'from',
#   'denver',
#   'to',
#   'san',
#   'francisco',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'flights',
#   'denver',
#   'to',
#   'washington',
#   'dc',
#   'on',
#   'thursday',
#   'EOS'],
#  ['BOS',
#   'please',
#   'list',
#   'the',
#   'thursday',
#   'morning',
#   'flights',
#   'from',
#   'st.',
#   'louis',
#   'to',
#   'st.',
#   'paul',
#   'EOS'],
#  ['BOS',
#   'what',
#   'flight',
#   'do',
#   'you',
#   'have',
#   'from',
#   'pittsburgh',
#   'to',
#   'san',
#   'francisco',
#   'on',
#   'the',
#   'morning',
#   'of',
#   'august',
#   'twenty',
#   'seventh',
#   'EOS'],
#  ['BOS',
#   'what',
#   'are',
#   'the',
#   'flights',
#   'from',
#   'boston',
#   'to',
#   'atlanta',
#   'EOS'],
#  ['BOS',
#   'what',
#   'flights',
#   'from',
#   'baltimore',
#   'to',
#   'san',
#   'francisco',
#   'arrive',
#   'before',
#   '8',
#   'pm',
#   'in',
#   'san',
#   'francisco',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'the',
#   'flights',
#   'from',
#   'pittsburgh',
#   'to',
#   'san',
#   'francisco',
#   'for',
#   'thursday',
#   'night',
#   'or',
#   'friday',
#   'EOS'],
#  ['BOS',
#   'get',
#   'me',
#   'a',
#   'first',
#   'class',
#   'flight',
#   'on',
#   'american',
#   'to',
#   'san',
#   'francisco',
#   'on',
#   'tuesday',
#   'next',
#   'week',
#   'EOS'],
#  ['BOS', 'ground', 'transportation', 'in', 'westchester', 'county', 'EOS'],
#  ['BOS',
#   'what',
#   'flights',
#   'are',
#   'there',
#   'from',
#   'atlanta',
#   'to',
#   'baltimore',
#   'EOS'],
#  ['BOS',
#   'i',
#   "'d",
#   'like',
#   'to',
#   'fly',
#   'from',
#   'dallas',
#   'to',
#   'san',
#   'francisco',
#   'at',
#   'approximately',
#   '615',
#   'pm',
#   'EOS'],
#  ['BOS',
#   'list',
#   'the',
#   'fares',
#   'of',
#   'us',
#   'air',
#   'flights',
#   'from',
#   'boston',
#   'to',
#   'philadelphia',
#   'EOS'],
#  ['BOS',
#   'list',
#   'flights',
#   'from',
#   'phoenix',
#   'to',
#   'detroit',
#   'on',
#   'thursday',
#   'june',
#   'twenty',
#   'fourth',
#   'EOS'],
#  ['BOS',
#   'what',
#   'flights',
#   'from',
#   'miami',
#   'to',
#   'indianapolis',
#   'on',
#   'sunday',
#   'EOS'],
#  ['BOS',
#   'now',
#   'show',
#   'me',
#   'the',
#   'flights',
#   'from',
#   'memphis',
#   'to',
#   'cleveland',
#   'EOS'],
#  ['BOS',
#   'can',
#   'you',
#   'give',
#   'me',
#   'information',
#   'on',
#   'all',
#   'the',
#   'flights',
#   'from',
#   'san',
#   'francisco',
#   'no',
#   'from',
#   'pittsburgh',
#   'to',
#   'san',
#   'francisco',
#   'on',
#   'monday',
#   'EOS'],
#  ['BOS',
#   'could',
#   'you',
#   'find',
#   'me',
#   'a',
#   'flight',
#   'from',
#   'boston',
#   'to',
#   'san',
#   'francisco',
#   'that',
#   'stops',
#   'in',
#   'denver',
#   'EOS'],
#  ['BOS', 'flights', 'from', 'cleveland', 'to', 'miami', 'EOS'],
#  ['BOS',
#   'give',
#   'me',
#   'the',
#   'flights',
#   'from',
#   'pittsburgh',
#   'to',
#   'los',
#   'angeles',
#   'thursday',
#   'evening',
#   'EOS'],
#  ['BOS',
#   'please',
#   'list',
#   'all',
#   'of',
#   'the',
#   'flights',
#   'leaving',
#   'atlanta',
#   'heading',
#   'to',
#   'baltimore',
#   'after',
#   '8',
#   'pm',
#   'wednesday',
#   'and',
#   'before',
#   '9',
#   'am',
#   'thursday',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'flights',
#   'from',
#   'seattle',
#   'to',
#   'san',
#   'francisco',
#   'that',
#   'leave',
#   'after',
#   '5',
#   'pm',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'the',
#   'flights',
#   'that',
#   'go',
#   'from',
#   'tacoma',
#   'to',
#   'miami',
#   'EOS'],
#  ['BOS',
#   'which',
#   'airline',
#   'can',
#   'fly',
#   'me',
#   'from',
#   'atlanta',
#   'to',
#   'denver',
#   'to',
#   'san',
#   'francisco',
#   'EOS'],
#  ['BOS',
#   'are',
#   'there',
#   'any',
#   'flights',
#   'from',
#   'denver',
#   'to',
#   'pittsburgh',
#   'with',
#   'stops',
#   'in',
#   'atlanta',
#   'EOS'],
#  ['BOS',
#   'list',
#   'all',
#   'the',
#   'flights',
#   'that',
#   'arrive',
#   'at',
#   'general',
#   'mitchell',
#   'international',
#   'EOS'],
#  ['BOS', 'what', 'is', 'fare', 'code', 'h', 'EOS'],
#  ['BOS',
#   'what',
#   'flights',
#   'from',
#   'salt',
#   'lake',
#   'city',
#   'to',
#   'new',
#   'york',
#   'city',
#   'arrive',
#   'next',
#   'saturday',
#   'before',
#   '6',
#   'pm',
#   'EOS'],
#  ['BOS', 'flights', 'from', 'nashville', 'to', 'seattle', 'EOS'],
#  ['BOS', 'show', 'me', 'fares', 'from', 'seattle', 'to', 'minneapolis', 'EOS'],
#  ['BOS',
#   'i',
#   'need',
#   'a',
#   'flight',
#   'from',
#   'boston',
#   'to',
#   'san',
#   'francisco',
#   'via',
#   'dallas',
#   'fort',
#   'worth',
#   'EOS'],
#  ['BOS',
#   'i',
#   "'d",
#   'like',
#   'an',
#   'afternoon',
#   'flight',
#   'from',
#   'atlanta',
#   'to',
#   'san',
#   'francisco',
#   'with',
#   'a',
#   'stopover',
#   'in',
#   'denver',
#   'arriving',
#   'i',
#   "'d",
#   'say',
#   'about',
#   'mealtime',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'the',
#   'most',
#   'expensive',
#   'one',
#   'way',
#   'flight',
#   'from',
#   'detroit',
#   'to',
#   'westchester',
#   'county',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'the',
#   'flights',
#   'from',
#   'baltimore',
#   'to',
#   'philadelphia',
#   'EOS'],
#  ['BOS',
#   'from',
#   'denver',
#   'to',
#   'washington',
#   'dc',
#   'on',
#   'monday',
#   'november',
#   'eleventh',
#   '1991',
#   'EOS'],
#  ['BOS',
#   'please',
#   'list',
#   'all',
#   'the',
#   'flights',
#   'from',
#   'boston',
#   'to',
#   'denver',
#   'which',
#   'serve',
#   'meals',
#   'EOS'],
#  ['BOS',
#   'list',
#   'aircraft',
#   'types',
#   'that',
#   'fly',
#   'between',
#   'boston',
#   'and',
#   'san',
#   'francisco',
#   'EOS'],
#  ['BOS', 'what', 'does', 'fare', 'code', 'qw', 'mean', 'EOS'],
#  ['BOS',
#   'i',
#   "'m",
#   'interested',
#   'in',
#   'a',
#   'flight',
#   'on',
#   'american',
#   'airlines',
#   'from',
#   'dallas',
#   'to',
#   'washington',
#   'EOS'],
#  ['BOS',
#   'give',
#   'me',
#   'flights',
#   'from',
#   'pittsburgh',
#   'to',
#   'baltimore',
#   'EOS'],
#  ['BOS',
#   'how',
#   'much',
#   'is',
#   'a',
#   'round',
#   'trip',
#   'fare',
#   'from',
#   'indianapolis',
#   'to',
#   'seattle',
#   'EOS'],
#  ['BOS',
#   'what',
#   'is',
#   'the',
#   'cheapest',
#   'flight',
#   'from',
#   'long',
#   'beach',
#   'to',
#   'memphis',
#   'EOS'],
#  ['BOS',
#   'which',
#   'airline',
#   'provides',
#   'business',
#   'class',
#   'flights',
#   'EOS'],
#  ['BOS', 'pittsburgh', 'to', 'denver', 'EOS'],
#  ['BOS',
#   'which',
#   'airlines',
#   'fly',
#   'between',
#   'boston',
#   'and',
#   'pittsburgh',
#   'EOS'],
#  ['BOS',
#   'list',
#   'the',
#   'flights',
#   'arriving',
#   'in',
#   'atlanta',
#   'from',
#   'baltimore',
#   'before',
#   'noon',
#   'on',
#   'august',
#   'fourth',
#   'EOS'],
#  ['BOS',
#   'give',
#   'me',
#   'the',
#   'flights',
#   'for',
#   'american',
#   'airline',
#   'from',
#   'philadelphia',
#   'to',
#   'dallas',
#   'EOS'],
#  ['BOS',
#   'i',
#   'need',
#   'a',
#   'flight',
#   'this',
#   'sunday',
#   'from',
#   'miami',
#   'to',
#   'las',
#   'vegas',
#   'and',
#   'i',
#   'would',
#   'prefer',
#   'a',
#   'morning',
#   'flight',
#   'EOS'],
#  ['BOS', 'flights', 'from', 'boston', 'to', 'pittsburgh', 'EOS'],
#  ['BOS',
#   'which',
#   'flights',
#   'go',
#   'from',
#   'pittsburgh',
#   'to',
#   'atlanta',
#   'in',
#   'the',
#   'evening',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'the',
#   'fares',
#   'from',
#   'dallas',
#   'to',
#   'san',
#   'francisco',
#   'EOS'],
#  ['BOS',
#   'give',
#   'me',
#   'american',
#   'airlines',
#   'flights',
#   'from',
#   'milwaukee',
#   'to',
#   'phoenix',
#   'on',
#   'saturday',
#   'and',
#   'on',
#   'sunday',
#   'EOS'],
#  ['BOS',
#   'list',
#   'all',
#   'flights',
#   'that',
#   'leave',
#   'from',
#   'baltimore',
#   'or',
#   'denver',
#   'or',
#   'pittsburgh',
#   'and',
#   'arrive',
#   'in',
#   'philadelphia',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'the',
#   'flights',
#   'from',
#   'baltimore',
#   'to',
#   'oakland',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'the',
#   'earliest',
#   'flight',
#   'from',
#   'denver',
#   'to',
#   'las',
#   'vegas',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'flights',
#   'from',
#   'milwaukee',
#   'to',
#   'orlando',
#   'on',
#   'wednesday',
#   'night',
#   'EOS'],
#  ['BOS',
#   'may',
#   'i',
#   'have',
#   'a',
#   'listing',
#   'of',
#   'flights',
#   'from',
#   'milwaukee',
#   'to',
#   'tacoma',
#   'washington',
#   'departing',
#   'in',
#   'the',
#   'evening',
#   'EOS'],
#  ['BOS',
#   'what',
#   'morning',
#   'flights',
#   'do',
#   'you',
#   'have',
#   'between',
#   'oakland',
#   'and',
#   'denver',
#   'EOS'],
#  ['BOS',
#   'i',
#   "'d",
#   'like',
#   'a',
#   'flight',
#   'from',
#   'washington',
#   'that',
#   'stops',
#   'in',
#   'denver',
#   'and',
#   'goes',
#   'on',
#   'to',
#   'san',
#   'francisco',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'all',
#   'flights',
#   'from',
#   'pittsburgh',
#   'to',
#   'baltimore',
#   'tomorrow',
#   'EOS'],
#  ['BOS',
#   'all',
#   'one',
#   'way',
#   'flights',
#   'between',
#   'boston',
#   'and',
#   'philadelphia',
#   'EOS'],
#  ['BOS',
#   'what',
#   'flights',
#   'go',
#   'to',
#   'san',
#   'francisco',
#   'from',
#   'boston',
#   'EOS'],
#  ['BOS',
#   'what',
#   'flights',
#   'are',
#   'there',
#   'from',
#   'san',
#   'francisco',
#   'to',
#   'philadelphia',
#   'daily',
#   'with',
#   'economy',
#   'class',
#   'EOS'],
#  ['BOS',
#   'first',
#   'flights',
#   'from',
#   'pittsburgh',
#   'to',
#   'atlanta',
#   'on',
#   'a',
#   'thursday',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'the',
#   'flights',
#   'from',
#   'baltimore',
#   'to',
#   'atlanta',
#   'EOS'],
#  ['BOS',
#   'tell',
#   'me',
#   'about',
#   'flights',
#   'from',
#   'toronto',
#   'to',
#   'salt',
#   'lake',
#   'city',
#   'leaving',
#   'after',
#   '530',
#   'pm',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'the',
#   'flights',
#   'from',
#   'indianapolis',
#   'to',
#   'orlando',
#   'with',
#   'round',
#   'trip',
#   'fares',
#   'less',
#   'than',
#   '1288',
#   'EOS'],
#  ['BOS',
#   'i',
#   'need',
#   'a',
#   'flight',
#   'from',
#   'boston',
#   'to',
#   'pittsburgh',
#   'that',
#   'leaves',
#   'early',
#   'in',
#   'the',
#   'morning',
#   'EOS'],
#  ['BOS',
#   'what',
#   'is',
#   'the',
#   'first',
#   'flight',
#   'from',
#   'atlanta',
#   'to',
#   'baltimore',
#   'that',
#   'serves',
#   'lunch',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'the',
#   'flights',
#   'from',
#   'pittsburgh',
#   'to',
#   'baltimore',
#   'EOS'],
#  ['BOS', 'all', 'flights', 'from', 'denver', 'to', 'philadelphia', 'EOS'],
#  ['BOS', 'oakland', 'to', 'philadelphia', 'saturday', 'EOS'],
#  ['BOS',
#   'give',
#   'me',
#   'the',
#   'earliest',
#   'flight',
#   'tomorrow',
#   'on',
#   'united',
#   'airlines',
#   'from',
#   'st.',
#   'petersburg',
#   'to',
#   'milwaukee',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'flights',
#   'on',
#   'monday',
#   'from',
#   'philadelphia',
#   'to',
#   'boston',
#   'after',
#   '7',
#   'am',
#   'EOS'],
#  ['BOS', 'show', 'me', 'all', 'the', 'flights', 'leaving', 'baltimore', 'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'the',
#   'flights',
#   'from',
#   'philadelphia',
#   'to',
#   'boston',
#   'EOS'],
#  ['BOS',
#   'is',
#   'there',
#   'a',
#   'plane',
#   'from',
#   'boston',
#   'to',
#   'washington',
#   'EOS'],
#  ['BOS',
#   'i',
#   'need',
#   'to',
#   'go',
#   'from',
#   'boston',
#   'to',
#   'atlanta',
#   'and',
#   'back',
#   'in',
#   'the',
#   'same',
#   'day',
#   'find',
#   'me',
#   'the',
#   'earliest',
#   'flight',
#   'from',
#   'boston',
#   'EOS'],
#  ['BOS',
#   'what',
#   'are',
#   'flights',
#   'between',
#   'boston',
#   'and',
#   'pittsburgh',
#   'on',
#   'august',
#   'tenth',
#   'EOS'],
#  ['BOS',
#   'what',
#   'are',
#   'the',
#   'schedule',
#   'of',
#   'flights',
#   'from',
#   'boston',
#   'to',
#   'san',
#   'francisco',
#   'for',
#   'august',
#   'first',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'one',
#   'way',
#   'flights',
#   'from',
#   'milwaukee',
#   'to',
#   'orlando',
#   'wednesday',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'all',
#   'flights',
#   'from',
#   'pittsburgh',
#   'to',
#   'baltimore',
#   'tomorrow',
#   'which',
#   'serve',
#   'a',
#   'meal',
#   'EOS'],
#  ['BOS',
#   'give',
#   'me',
#   'flights',
#   'on',
#   'american',
#   'airlines',
#   'from',
#   'milwaukee',
#   'to',
#   'phoenix',
#   'EOS'],
#  ['BOS',
#   'show',
#   'all',
#   'flights',
#   'from',
#   'pittsburgh',
#   'to',
#   'san',
#   'francisco',
#   'EOS'],
#  ['BOS',
#   'i',
#   'wish',
#   'to',
#   'fly',
#   'from',
#   'boston',
#   'to',
#   'washington',
#   'please',
#   'find',
#   'an',
#   'airline',
#   'for',
#   'me',
#   'EOS'],
#  ['BOS',
#   'please',
#   'list',
#   'the',
#   'flights',
#   'from',
#   'dallas',
#   'fort',
#   'worth',
#   'to',
#   'dc',
#   'baltimore',
#   'on',
#   'july',
#   'twenty',
#   'third',
#   'EOS'],
#  ['BOS',
#   'which',
#   'flights',
#   'from',
#   'memphis',
#   'to',
#   'tacoma',
#   'also',
#   'stop',
#   'in',
#   'los',
#   'angeles',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'the',
#   'flights',
#   'on',
#   'tuesday',
#   'morning',
#   'from',
#   'charlotte',
#   'to',
#   'baltimore',
#   'EOS'],
#  ['BOS',
#   'i',
#   'need',
#   '2',
#   'first',
#   'class',
#   'tickets',
#   'from',
#   'dallas',
#   'fort',
#   'worth',
#   'to',
#   'san',
#   'francisco',
#   'EOS'],
#  ['BOS',
#   'are',
#   'there',
#   'any',
#   'flights',
#   'from',
#   'philadelphia',
#   'to',
#   'dallas',
#   'which',
#   'stop',
#   'in',
#   'atlanta',
#   'EOS'],
#  ['BOS', 'flights', 'to', 'baltimore', 'EOS'],
#  ['BOS', 'what', 'does', 'mco', 'stand', 'for', 'EOS'],
#  ['BOS',
#   'what',
#   'is',
#   'the',
#   'least',
#   'expensive',
#   'way',
#   'to',
#   'fly',
#   'from',
#   'philadelphia',
#   'to',
#   'san',
#   'francisco',
#   'EOS'],
#  ['BOS',
#   'list',
#   'all',
#   'nonstop',
#   'flights',
#   'from',
#   'los',
#   'angeles',
#   'to',
#   'pittsburgh',
#   'before',
#   '5',
#   'pm',
#   'on',
#   'tuesday',
#   'EOS'],
#  ['BOS', 'how', 'many', 'booking', 'classes', 'are', 'there', 'EOS'],
#  ['BOS',
#   'flight',
#   'numbers',
#   'from',
#   'columbus',
#   'to',
#   'minneapolis',
#   'tomorrow',
#   'EOS'],
#  ['BOS',
#   'give',
#   'me',
#   'the',
#   'continental',
#   'flights',
#   'from',
#   'chicago',
#   'to',
#   'seattle',
#   'on',
#   'friday',
#   'EOS'],
#  ['BOS',
#   'what',
#   'are',
#   'the',
#   'united',
#   'airlines',
#   'flights',
#   'between',
#   'baltimore',
#   'and',
#   'denver',
#   'on',
#   'august',
#   'twelfth',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'the',
#   'flights',
#   'next',
#   'tuesday',
#   'between',
#   'philadelphia',
#   'and',
#   'san',
#   'francisco',
#   'EOS'],
#  ['BOS',
#   'find',
#   'a',
#   'flight',
#   'on',
#   'american',
#   'airlines',
#   'from',
#   'boston',
#   'to',
#   'san',
#   'francisco',
#   'that',
#   'makes',
#   'a',
#   'stopover',
#   'in',
#   'denver',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'the',
#   'fares',
#   'on',
#   'all',
#   'flights',
#   'round',
#   'trip',
#   'from',
#   'pittsburgh',
#   'to',
#   'oakland',
#   'EOS'],
#  ['BOS',
#   'what',
#   "'s",
#   'the',
#   'difference',
#   'between',
#   'fare',
#   'code',
#   'q',
#   'and',
#   'fare',
#   'code',
#   'f',
#   'EOS'],
#  ['BOS', 'flights', 'from', 'cincinnati', 'to', 'salt', 'lake', 'city', 'EOS'],
#  ['BOS', 'ground', 'transportation', 'denver', 'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'flights',
#   'from',
#   'denver',
#   'to',
#   'washington',
#   'dc',
#   'on',
#   'wednesdays',
#   'EOS'],
#  ['BOS',
#   'find',
#   'a',
#   'flight',
#   'between',
#   'denver',
#   'and',
#   'oakland',
#   'the',
#   'flight',
#   'should',
#   'be',
#   'in',
#   'the',
#   'afternoon',
#   'and',
#   'arrive',
#   'close',
#   'to',
#   '5',
#   'pm',
#   'the',
#   'flight',
#   'should',
#   'be',
#   'nonstop',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'all',
#   'flights',
#   'from',
#   'atlanta',
#   'to',
#   'washington',
#   'with',
#   'prices',
#   'EOS'],
#  ['BOS', 'flights', 'between', 'new', 'york', 'and', 'miami', 'EOS'],
#  ['BOS',
#   'please',
#   'list',
#   'the',
#   'monday',
#   'morning',
#   'flights',
#   'from',
#   'kansas',
#   'city',
#   'to',
#   'atlanta',
#   'EOS'],
#  ['BOS',
#   'list',
#   'all',
#   'american',
#   'airlines',
#   'flights',
#   'from',
#   'phoenix',
#   'to',
#   'milwaukee',
#   'which',
#   'arrive',
#   'on',
#   'wednesday',
#   'after',
#   '4',
#   'pm',
#   'EOS'],
#  ['BOS',
#   'what',
#   'round',
#   'trip',
#   'tickets',
#   'are',
#   'there',
#   'from',
#   'cleveland',
#   'to',
#   'miami',
#   'on',
#   'us',
#   'air',
#   'that',
#   'arrive',
#   'before',
#   '4',
#   'pm',
#   'EOS'],
#  ['BOS',
#   'i',
#   "'d",
#   'like',
#   'to',
#   'go',
#   'from',
#   'boston',
#   'to',
#   'denver',
#   'at',
#   '9',
#   "o'clock",
#   'saturday',
#   'night',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'the',
#   'northwest',
#   'flights',
#   'from',
#   'detroit',
#   'to',
#   'st.',
#   'petersburg',
#   'EOS'],
#  ['BOS',
#   'what',
#   'is',
#   'the',
#   'available',
#   'ground',
#   'transportation',
#   'between',
# ...
#   'night',
#   'EOS'],
#  ['BOS',
#   'is',
#   'there',
#   'ground',
#   'transportation',
#   'from',
#   'atlanta',
#   'airport',
#   'to',
#   'downtown',
#   'atlanta',
#   'EOS'],
#  ['BOS',
#   'are',
#   'there',
#   'any',
#   'limousines',
#   'or',
#   'taxi',
#   'services',
#   'available',
#   'at',
#   'the',
#   'boston',
#   'airport',
#   'EOS'],
#  ['BOS',
#   'on',
#   'eastern',
#   'flight',
#   '825',
#   'flying',
#   'from',
#   'atlanta',
#   'to',
#   'denver',
#   'can',
#   'you',
#   'tell',
#   'me',
#   'what',
#   'type',
#   'of',
#   'aircraft',
#   'is',
#   'used',
#   'on',
#   'a',
#   'flight',
#   'when',
#   'it',
#   'leaves',
#   'at',
#   '555',
#   'EOS'],
#  ['BOS',
#   'how',
#   'do',
#   'i',
#   'get',
#   'from',
#   'the',
#   'airport',
#   'to',
#   'downtown',
#   'in',
#   'tacoma',
#   'EOS'],
#  ['BOS',
#   'tuesday',
#   'morning',
#   'flights',
#   'between',
#   'charlotte',
#   'and',
#   'baltimore',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'flights',
#   'from',
#   'atlanta',
#   'to',
#   'washington',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'all',
#   'flights',
#   'from',
#   'atlanta',
#   'to',
#   'san',
#   'francisco',
#   'which',
#   'leave',
#   'atlanta',
#   'after',
#   '5',
#   "o'clock",
#   'pm',
#   'tomorrow',
#   'EOS'],
#  ['BOS',
#   'round',
#   'trip',
#   'fares',
#   'from',
#   'denver',
#   'to',
#   'philadelphia',
#   'less',
#   'than',
#   '1000',
#   'dollars',
#   'EOS'],
#  ['BOS',
#   'i',
#   'want',
#   'to',
#   'fly',
#   'from',
#   'milwaukee',
#   'to',
#   'orlando',
#   'on',
#   'wednesday',
#   'evening',
#   'EOS'],
#  ['BOS',
#   'how',
#   'many',
#   'daily',
#   'us',
#   'air',
#   'flights',
#   'are',
#   'there',
#   'between',
#   'philadelphia',
#   'and',
#   'pittsburgh',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'all',
#   'the',
#   'northwest',
#   'flights',
#   'from',
#   'new',
#   'york',
#   'to',
#   'milwaukee',
#   'that',
#   'leave',
#   'at',
#   '720',
#   'am',
#   'EOS'],
#  ['BOS',
#   'how',
#   'long',
#   'does',
#   'it',
#   'take',
#   'to',
#   'get',
#   'from',
#   'atlanta',
#   'airport',
#   'into',
#   'the',
#   'city',
#   'of',
#   'atlanta',
#   'EOS'],
#  ['BOS',
#   'what',
#   "'s",
#   'the',
#   'cheapest',
#   'way',
#   'to',
#   'fly',
#   'between',
#   'atlanta',
#   'and',
#   'denver',
#   'EOS'],
#  ['BOS',
#   'what',
#   'are',
#   'the',
#   'fares',
#   'for',
#   'flights',
#   'from',
#   'la',
#   'to',
#   'newark',
#   'leaving',
#   'monday',
#   'morning',
#   'EOS'],
#  ['BOS',
#   'give',
#   'me',
#   'the',
#   'list',
#   'of',
#   'flights',
#   'for',
#   'continental',
#   'airlines',
#   'between',
#   'boston',
#   'and',
#   'denver',
#   'EOS'],
#  ['BOS',
#   'can',
#   'i',
#   'see',
#   'ground',
#   'transportation',
#   'from',
#   'long',
#   'beach',
#   'airport',
#   'to',
#   'downtown',
#   'EOS'],
#  ['BOS',
#   'i',
#   'want',
#   'a',
#   'flight',
#   'from',
#   'atlanta',
#   'to',
#   'pittsburgh',
#   'EOS'],
#  ['BOS', 'us', '201', 'EOS'],
#  ['BOS',
#   'what',
#   'flights',
#   'are',
#   'available',
#   'from',
#   'pittsburgh',
#   'to',
#   'oakland',
#   'airport',
#   'EOS'],
#  ['BOS',
#   'afternoon',
#   'flight',
#   'from',
#   'denver',
#   'to',
#   'san',
#   'francisco',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'all',
#   'the',
#   'flights',
#   'from',
#   'charlotte',
#   'to',
#   'cleveland',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'the',
#   'flights',
#   'on',
#   'twa',
#   'to',
#   'atlanta',
#   'in',
#   'the',
#   'morning',
#   'EOS'],
#  ['BOS',
#   'do',
#   'all',
#   'the',
#   'flights',
#   'to',
#   'oakland',
#   'land',
#   'at',
#   'the',
#   'same',
#   'place',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'the',
#   'flights',
#   'from',
#   'st.',
#   'petersburg',
#   'to',
#   'toronto',
#   'that',
#   'arrive',
#   'before',
#   'noon',
#   'EOS'],
#  ['BOS',
#   'how',
#   'much',
#   'is',
#   'a',
#   'first',
#   'class',
#   'ticket',
#   'from',
#   'baltimore',
#   'to',
#   'san',
#   'francisco',
#   'EOS'],
#  ['BOS',
#   'please',
#   'give',
#   'me',
#   'all',
#   'flights',
#   'from',
#   'long',
#   'beach',
#   'to',
#   'memphis',
#   'EOS'],
#  ['BOS',
#   'i',
#   'want',
#   'to',
#   'fly',
#   'nonstop',
#   'from',
#   'denver',
#   'to',
#   'dallas',
#   'EOS'],
#  ['BOS',
#   'what',
#   'is',
#   'the',
#   'earliest',
#   'flight',
#   'leaving',
#   'boston',
#   'on',
#   'july',
#   'first',
#   'to',
#   'dallas',
#   'on',
#   'july',
#   'first',
#   'EOS'],
#  ['BOS',
#   'i',
#   "'d",
#   'like',
#   'a',
#   'flight',
#   'tomorrow',
#   'evening',
#   'from',
#   'nashville',
#   'to',
#   'houston',
#   'that',
#   'includes',
#   'dinner',
#   'for',
#   'tomorrow',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'the',
#   'flights',
#   'from',
#   'denver',
#   'to',
#   'san',
#   'diego',
#   'leaving',
#   'after',
#   '5',
#   'pm',
#   'EOS'],
#  ['BOS',
#   'what',
#   'flights',
#   'go',
#   'from',
#   'san',
#   'francisco',
#   'to',
#   'washington',
#   'via',
#   'indianapolis',
#   'EOS'],
#  ['BOS',
#   'can',
#   'you',
#   'help',
#   'me',
#   'with',
#   'ground',
#   'transportation',
#   'information',
#   'i',
#   'need',
#   'to',
#   'get',
#   'from',
#   'the',
#   'airport',
#   'in',
#   'philadelphia',
#   'to',
#   'downtown',
#   'philadelphia',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'the',
#   'earliest',
#   'flight',
#   'on',
#   'wednesday',
#   'from',
#   'baltimore',
#   'to',
#   'newark',
#   'EOS'],
#  ['BOS',
#   'could',
#   'you',
#   'please',
#   'give',
#   'me',
#   'the',
#   'round',
#   'trip',
#   'fare',
#   'from',
#   'denver',
#   'to',
#   'atlanta',
#   'EOS'],
#  ['BOS',
#   'show',
#   'sunday',
#   'flights',
#   'from',
#   'seattle',
#   'to',
#   'chicago',
#   'EOS'],
#  ['BOS',
#   'what',
#   'flights',
#   'depart',
#   'from',
#   'pittsburgh',
#   'and',
#   'arrive',
#   'in',
#   'oakland',
#   'california',
#   'EOS'],
#  ['BOS',
#   'flights',
#   'from',
#   'houston',
#   'to',
#   'los',
#   'angeles',
#   'departing',
#   'after',
#   '1026',
#   'EOS'],
#  ['BOS',
#   'i',
#   'would',
#   'like',
#   'a',
#   'flight',
#   'from',
#   'pittsburgh',
#   'to',
#   'san',
#   'francisco',
#   'on',
#   'august',
#   'twentieth',
#   'EOS'],
#  ['BOS', 'show', 'me', 'flights', 'from', 'dallas', 'to', 'atlanta', 'EOS'],
#  ['BOS',
#   'please',
#   'give',
#   'all',
#   'flights',
#   'from',
#   'dallas',
#   'to',
#   'oakland',
#   'california',
#   'monday',
#   'EOS'],
#  ['BOS',
#   'what',
#   'flights',
#   'are',
#   'available',
#   'wednesday',
#   'morning',
#   'from',
#   'boston',
#   'to',
#   'denver',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'the',
#   'flights',
#   'from',
#   'pittsburgh',
#   'to',
#   'baltimore',
#   'arriving',
#   'in',
#   'baltimore',
#   'on',
#   'june',
#   'fourteenth',
#   'EOS'],
#  ['BOS',
#   'list',
#   'the',
#   'morning',
#   'flights',
#   'at',
#   'a',
#   '124',
#   'dollars',
#   'from',
#   'atlanta',
#   'to',
#   'boston',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'the',
#   'flights',
#   'from',
#   'denver',
#   'to',
#   'philadelphia',
#   'on',
#   'a',
#   'saturday',
#   'EOS'],
#  ['BOS',
#   'i',
#   'need',
#   'to',
#   'fly',
#   'from',
#   'boston',
#   'to',
#   'denver',
#   'and',
#   'then',
#   'to',
#   'san',
#   'francisco',
#   'and',
#   'back',
#   'to',
#   'boston',
#   'EOS'],
#  ['BOS',
#   'what',
#   'is',
#   'the',
#   'cheapest',
#   'flight',
#   'on',
#   'american',
#   'airlines',
#   'from',
#   'cleveland',
#   'to',
#   'miami',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'flights',
#   'available',
#   'from',
#   'atlanta',
#   'to',
#   'baltimore',
#   'leaving',
#   'on',
#   'monday',
#   'morning',
#   'EOS'],
#  ['BOS',
#   'what',
#   "'s",
#   'the',
#   'earliest',
#   'flight',
#   'from',
#   'pittsburgh',
#   'to',
#   'baltimore',
#   'on',
#   'thursday',
#   'morning',
#   'EOS'],
#  ['BOS',
#   'what',
#   'ground',
#   'transportation',
#   'is',
#   'available',
#   'in',
#   'boston',
#   'EOS'],
#  ['BOS',
#   'what',
#   'is',
#   'the',
#   'latest',
#   'flight',
#   'leaving',
#   'pittsburgh',
#   'returning',
#   'to',
#   'denver',
#   'EOS'],
#  ['BOS',
#   'does',
#   'lufthansa',
#   'fly',
#   'between',
#   'boston',
#   'and',
#   'oakland',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'flights',
#   'from',
#   'boston',
#   'to',
#   'washington',
#   'leaving',
#   'july',
#   'fifteen',
#   'EOS'],
#  ['BOS',
#   'list',
#   'all',
#   'the',
#   'landings',
#   'at',
#   'general',
#   'mitchell',
#   'international',
#   'EOS'],
#  ['BOS',
#   'how',
#   'many',
#   'first',
#   'class',
#   'flights',
#   'does',
#   'delta',
#   'have',
#   'today',
#   'EOS'],
#  ['BOS',
#   'are',
#   'there',
#   'any',
#   'nonstop',
#   'flights',
#   'from',
#   'indianapolis',
#   'to',
#   'san',
#   'diego',
#   'on',
#   'wednesday',
#   'may',
#   'twelfth',
#   'EOS'],
#  ['BOS',
#   'what',
#   'are',
#   'the',
#   'flights',
#   'which',
#   'depart',
#   'from',
#   'san',
#   'francisco',
#   'fly',
#   'to',
#   'washington',
#   'via',
#   'indianapolis',
#   'and',
#   'arrive',
#   'by',
#   '9',
#   'pm',
#   'EOS'],
#  ['BOS',
#   'please',
#   'list',
#   'the',
#   'flights',
#   'from',
#   'dallas',
#   'fort',
#   'worth',
#   'to',
#   'boston',
#   'on',
#   'july',
#   'twenty',
#   'third',
#   'EOS'],
#  ['BOS',
#   'hello',
#   'i',
#   'would',
#   'like',
#   'to',
#   'plan',
#   'a',
#   'flight',
#   'on',
#   'american',
#   'airlines',
#   'from',
#   'boston',
#   'to',
#   'denver',
#   'EOS'],
#  ['BOS',
#   'what',
#   'are',
#   'the',
#   'two',
#   'american',
#   'airlines',
#   'flights',
#   'that',
#   'leave',
#   'from',
#   'dallas',
#   'to',
#   'san',
#   'francisco',
#   'in',
#   'the',
#   'evening',
#   'EOS'],
#  ['BOS',
#   'what',
#   'flights',
#   'do',
#   'you',
#   'have',
#   'from',
#   'baltimore',
#   'to',
#   'san',
#   'francisco',
#   'EOS'],
#  ['BOS',
#   'i',
#   "'d",
#   'like',
#   'a',
#   'nonstop',
#   'flight',
#   'from',
#   'indianapolis',
#   'to',
#   'san',
#   'diego',
#   'that',
#   'serves',
#   'dinner',
#   'what',
#   "'s",
#   'available',
#   'EOS'],
#  ['BOS',
#   'what',
#   'times',
#   'on',
#   'wednesday',
#   'could',
#   'i',
#   'take',
#   'a',
#   'plane',
#   'from',
#   'denver',
#   'to',
#   'oakland',
#   'EOS'],
#  ['BOS', 'show', 'me', 'ground', 'transportation', 'for', 'boston', 'EOS'],
#  ['BOS',
#   'are',
#   'there',
#   'any',
#   'flights',
#   'from',
#   'boston',
#   'to',
#   'san',
#   'francisco',
#   'which',
#   'stop',
#   'in',
#   'denver',
#   'EOS'],
#  ['BOS', 'what', 'airlines', 'have', 'business', 'class', 'EOS'],
#  ['BOS',
#   'please',
#   'give',
#   'me',
#   'all',
#   'flights',
#   'from',
#   'long',
#   'beach',
#   'to',
#   'memphis',
#   'EOS'],
#  ['BOS', 'flight', 'from', 'denver', 'to', 'dallas', 'fort', 'worth', 'EOS'],
#  ['BOS',
#   'list',
#   'flights',
#   'from',
#   'san',
#   'francisco',
#   'to',
#   'pittsburgh',
#   'EOS'],
#  ['BOS',
#   'i',
#   "'d",
#   'like',
#   'to',
#   'know',
#   'what',
#   'type',
#   'of',
#   'plane',
#   'flies',
#   'from',
#   'boston',
#   'to',
#   'dallas',
#   'fort',
#   'worth',
#   'after',
#   '530',
#   'EOS'],
#  ['BOS',
#   'please',
#   'tell',
#   'me',
#   'the',
#   'times',
#   'of',
#   'the',
#   'flights',
#   'between',
#   'boston',
#   'and',
#   'baltimore',
#   'EOS'],
#  ['BOS',
#   'find',
#   'a',
#   'flight',
#   'from',
#   'philadelphia',
#   'to',
#   'san',
#   'francisco',
#   'please',
#   'on',
#   'delta',
#   'EOS'],
#  ['BOS',
#   'what',
#   'is',
#   'the',
#   'cost',
#   'of',
#   'a',
#   'ticket',
#   'going',
#   'from',
#   'denver',
#   'to',
#   'boston',
#   'july',
#   'twenty',
#   'fifth',
#   '1991',
#   'EOS'],
#  ['BOS',
#   'flight',
#   'numbers',
#   'from',
#   'minneapolis',
#   'to',
#   'long',
#   'beach',
#   'on',
#   'june',
#   'twenty',
#   'six',
#   'EOS'],
#  ['BOS',
#   'i',
#   "'m",
#   'looking',
#   'for',
#   'a',
#   'flight',
#   'from',
#   'oakland',
#   'to',
#   'denver',
#   'with',
#   'a',
#   'stopover',
#   'in',
#   'dallas',
#   'fort',
#   'worth',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'first',
#   'class',
#   'airlines',
#   'from',
#   'san',
#   'francisco',
#   'to',
#   'pittsburgh',
#   'on',
#   'next',
#   'tuesday',
#   'first',
#   'class',
#   'only',
#   'EOS'],
#  ['BOS',
#   'what',
#   'flights',
#   'are',
#   'there',
#   'on',
#   'saturdays',
#   'from',
#   'philadelphia',
#   'to',
#   'denver',
#   'EOS'],
#  ['BOS',
#   'i',
#   'need',
#   'a',
#   'flight',
#   'from',
#   'denver',
#   'to',
#   'washington',
#   'dc',
#   'on',
#   'wednesday',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'the',
#   'flights',
#   'from',
#   'columbus',
#   'to',
#   'charlotte',
#   'EOS'],
#  ['BOS',
#   'oh',
#   'let',
#   "'s",
#   'see',
#   'does',
#   'eastern',
#   'airline',
#   'have',
#   'a',
#   'flight',
#   'from',
#   'atlanta',
#   'to',
#   'washington',
#   'EOS'],
#  ['BOS',
#   'what',
#   'is',
#   'the',
#   'price',
#   'of',
#   'business',
#   'class',
#   'from',
#   'boston',
#   'to',
#   'san',
#   'francisco',
#   'on',
#   'twa',
#   'EOS'],
#  ['BOS',
#   'flights',
#   'from',
#   'atlanta',
#   'to',
#   'dallas',
#   'in',
#   'the',
#   'afternoon',
#   'EOS'],
#  ['BOS',
#   'eastern',
#   'flight',
#   '825',
#   'from',
#   'atlanta',
#   'to',
#   'denver',
#   'leaving',
#   'at',
#   '555',
#   'what',
#   'type',
#   'of',
#   'aircraft',
#   'is',
#   'used',
#   'on',
#   'that',
#   'flight',
#   'EOS'],
#  ['BOS',
#   'what',
#   'are',
#   'all',
#   'the',
#   'flights',
#   'between',
#   'san',
#   'francisco',
#   'and',
#   'boston',
#   'EOS'],
#  ['BOS', 'define', 'airline', 'us', 'EOS'],
#  ['BOS',
#   'i',
#   'want',
#   'to',
#   'fly',
#   'philadelphia',
#   'to',
#   'san',
#   'francisco',
#   'on',
#   'july',
#   'eighth',
#   'EOS'],
#  ['BOS',
#   'find',
#   'a',
#   'flight',
#   'from',
#   'boston',
#   'to',
#   'washington',
#   'on',
#   'monday',
#   'EOS'],
#  ['BOS',
#   'give',
#   'me',
#   'information',
#   'on',
#   'flights',
#   'from',
#   'atlanta',
#   'to',
#   'washington',
#   'dc',
#   'on',
#   'wednesday',
#   'after',
#   '4',
#   'pm',
#   'and',
#   'thursday',
#   'before',
#   '9',
#   'am',
#   'EOS'],
#  ['BOS',
#   'find',
#   'the',
#   'flights',
#   'from',
#   'boston',
#   'to',
#   'san',
#   'francisco',
#   'leaving',
#   'after',
#   '6',
#   'pm',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'the',
#   'cheapest',
#   'fare',
#   'from',
#   'dallas',
#   'to',
#   'baltimore',
#   'EOS'],
#  ['BOS',
#   'i',
#   'live',
#   'in',
#   'denver',
#   'and',
#   'i',
#   "'d",
#   'like',
#   'to',
#   'make',
#   'a',
#   'trip',
#   'to',
#   'pittsburgh',
#   'EOS'],
#  ['BOS',
#   'give',
#   'me',
#   'flights',
#   'that',
#   'arrive',
#   'in',
#   'baltimore',
#   'from',
#   'atlanta',
#   'denver',
#   'and',
#   'pittsburgh',
#   'EOS'],
#  ['BOS',
#   'hello',
#   'i',
#   "'m",
#   'trying',
#   'to',
#   'find',
#   'a',
#   'flight',
#   'that',
#   'goes',
#   'from',
#   'pittsburgh',
#   'to',
#   'denver',
#   'after',
#   '2',
#   'pm',
#   'EOS'],
#  ['BOS',
#   'what',
#   'airlines',
#   'fly',
#   'between',
#   'boston',
#   'and',
#   'san',
#   'francisco',
#   'EOS'],
#  ['BOS', 'code', 'ff', 'EOS'],
#  ['BOS',
#   'what',
#   'is',
#   'the',
#   'earliest',
#   'flight',
#   'from',
#   'boston',
#   'to',
#   'san',
#   'francisco',
#   'on',
#   'november',
#   'seventh',
#   'EOS'],
#  ['BOS',
#   'list',
#   'all',
#   'flights',
#   'from',
#   'boston',
#   'to',
#   'san',
#   'francisco',
#   'on',
#   'us',
#   'air',
#   'EOS'],
#  ['BOS',
#   'i',
#   'would',
#   'like',
#   'a',
#   'list',
#   'of',
#   'flights',
#   'from',
#   'pittsburgh',
#   'to',
#   'dallas',
#   'EOS'],
#  ['BOS',
#   'on',
#   'november',
#   'twenty',
#   'third',
#   'of',
#   'this',
#   'year',
#   '1991',
#   'i',
#   "'d",
#   'like',
#   'to',
#   'fly',
#   'from',
#   'atlanta',
#   'to',
#   'denver',
#   'and',
#   'i',
#   "'d",
#   'like',
#   'to',
#   'fly',
#   'on',
#   'delta',
#   'EOS'],
#  ['BOS',
#   'do',
#   'you',
#   'have',
#   'any',
#   'airlines',
#   'that',
#   'would',
#   'stop',
#   'at',
#   'denver',
#   'on',
#   'the',
#   'way',
#   'from',
#   'baltimore',
#   'to',
#   'san',
#   'francisco',
#   'EOS'],
#  ['BOS',
#   'list',
#   'all',
#   'flights',
#   'from',
#   'tampa',
#   'florida',
#   'to',
#   'miami',
#   'that',
#   'are',
#   'the',
#   'cheapest',
#   'one',
#   'way',
#   'EOS'],
#  ['BOS',
#   'list',
#   'the',
#   'nonstop',
#   'flights',
#   'on',
#   'wednesday',
#   'june',
#   'second',
#   'from',
#   'miami',
#   'to',
#   'baltimore',
#   'arriving',
#   'in',
#   'baltimore',
#   'between',
#   '1115',
#   'am',
#   'and',
#   '1245',
#   'pm',
#   'EOS'],
#  ['BOS',
#   'give',
#   'me',
#   'flights',
#   'from',
#   'san',
#   'francisco',
#   'to',
#   'boston',
#   'on',
#   'thursday',
#   'afternoon',
#   'EOS'],
#  ['BOS', 'denver', 'to', 'atlanta', 'EOS'],
#  ['BOS',
#   'what',
#   "'s",
#   'the',
#   'last',
#   'flight',
#   'leaving',
#   'from',
#   'pittsburgh',
#   'to',
#   'oakland',
#   'EOS'],
#  ['BOS',
#   'does',
#   'any',
#   'airline',
#   'have',
#   'an',
#   'afternoon',
#   'flight',
#   'from',
#   'boston',
#   'to',
#   'oakland',
#   'EOS'],
#  ['BOS',
#   'do',
#   'you',
#   'have',
#   'a',
#   'flight',
#   'from',
#   'philadelphia',
#   'to',
#   'san',
#   'francisco',
#   'with',
#   'a',
#   'stopover',
#   'in',
#   'dallas',
#   'EOS'],
#  ['BOS',
#   'i',
#   'want',
#   'to',
#   'make',
#   'a',
#   'trip',
#   'from',
#   'washington',
#   'to',
#   'san',
#   'francisco',
#   'EOS'],
#  ['BOS',
#   'i',
#   'would',
#   'like',
#   'information',
#   'on',
#   'flights',
#   'leaving',
#   'atlanta',
#   'in',
#   'the',
#   'afternoon',
#   'arriving',
#   'in',
#   'dallas',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'all',
#   'flights',
#   'from',
#   'san',
#   'diego',
#   'to',
#   'new',
#   'york',
#   'nonstop',
#   'EOS'],
#  ['BOS',
#   'show',
#   'me',
#   'all',
#   'flights',
#   'with',
#   'fares',
#   'from',
#   'pittsburgh',
#   'to',
#   'san',
#   'francisco',
#   'EOS'],
#  ['BOS',
#   'what',
#   'are',
#   'the',
#   'flights',
#   'from',
#   'milwaukee',
#   'to',
#   'tampa',
#   'EOS'],
#  ...]

# %%
def build_classification_model(embeddings):
    # Точка входа в граф задаётся при помощи специальных тензоров типа Input
    # Первая координата соответсвует длине текста, так как тексты в датасете имеют разную длину
    # значение считается переменным
    text_input = keras.layers.Input(shape=(None,), dtype='int32') ## batch, num sentence = None, last = 1 - индексы из glove
    
    # Создаём специальный слой для работы с embedding, 
    # Его функция -- заменять индентификатор вектором из Glove
    # Указываем trainable = False, чтобы векторы embedding'ов не изменялись в процессе обучения
    embedding_layer = keras.layers.Embedding(input_dim = embeddings.shape[0], 
                                       output_dim = embeddings.shape[1], 
                                       weights=[embeddings],
                                       trainable = False) ## хорошая практика учить с замороженными embedding, а потом их разморозить
    
    x = embedding_layer(text_input)
    
    # Создаём рекуррентную ячейку
    # Первый параметр отвечает за размер внутреннего состояния (памяти ячейки)
    # По умолчанию такой слой возвращает только последнее состояние (см. картинку),
    # Если мы хотим получить состояния на каждом шаге необходимо указать return_sequences = True
    x = keras.layers.LSTM(128, recurrent_dropout=0.25)(x)
    
    # Полученный результат направляем в полносвязный слой, который будет осуществлять классификацию
    output = keras.layers.Dense(26, activation='softmax')(x)
    
    model = keras.models.Model(inputs=[text_input], outputs=[output], name = 'LSTM_classifier')
    
    return model

# %%
keras.backend.clear_session()
model = build_classification_model(vocab.embeddings)

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, None)              0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, None, 50)          20000050
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 128)               91648
# _________________________________________________________________
# dense_1 (Dense)              (None, 26)                3354
# =================================================================
# Total params: 20,095,052
# Trainable params: 95,002
# Non-trainable params: 20,000,050
# _________________________________________________________________

# %%
adam = keras.optimizers.Adam(lr=0.0001)

model.compile(adam, keras.losses.sparse_categorical_crossentropy, metrics = ['acc'])

# %%
from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val = train_test_split(atis_train_queries, atis_train_intents, test_size = 0.1)

# %%
def generate_batches(x,y,batch_size = 64):
    i=0
    while True:
        i = i %len(x)
        yield keras.preprocessing.sequence.pad_sequences(x[i:i+batch_size]),y[i:i+batch_size]
        i += batch_size

# %%
train_generator = generate_batches(x_train, y_train)
val_generator = generate_batches(x_val,y_val)

train_steps  =len(x_train)/64
val_steps  =len(x_val)/64

# %%
model.fit_generator(generator=train_generator,
                    validation_data=val_generator,
                    steps_per_epoch = train_steps,
                    validation_steps  = val_steps,
                    workers=6)
# Out:
# Epoch 1/1
# 70/70 [==============================] - 5s 66ms/step - loss: 2.3023 - acc: 0.5549 - val_loss: 1.4488 - val_acc: 0.7249

# %%
def model_predict(val_generator):
    y_pred = model.predict_generator(val_generator,steps=val_steps)
    return y_pred

y_pred = model_predict(val_generator)
preds = [np.argmax(i) for i in y_pred]

# %%
# Out:
# [14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14]
